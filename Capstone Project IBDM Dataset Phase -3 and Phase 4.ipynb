# %% [markdown]
# # Phase -3

# %%
#Importing required libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings("ignore")
import requests
import pandas as pd

# %%
#Fetching saved datasets

id1 = pd.read_csv('IMDBDataset1.csv')
id2 = pd.read_csv('IMDBDataset2.csv')

# %%
id1.head()
# Out:
#    Sno                                         Movie_Name          Director_1  \
# 0    1                                    The Dark Knight  Christopher Nolan
# 1    2      The Lord of the Rings: The Return of the King      Peter Jackson
# 2    3                Spider-Man: Across the Spider-Verse  Joaquim Dos Santos
# 3    4                                          Inception  Christopher Nolan
# 4    5  The Lord of the Rings: The Fellowship of the Ring      Peter Jackson
#
#       Director_2            Director_3 Duration  Year  Ratings Metascore
# 0  Not Available         Not Available  152 min  2008      9.0        84
# 1  Not Available         Not Available  201 min  2003      9.0        94
# 2    Kemp Powers   Justin K. Thompson   140 min  2023      8.9        86
# 3  Not Available         Not Available  148 min  2010      8.8        74
# 4  Not Available         Not Available  178 min  2001      8.8        92

# %%
id1.shape
# Out:
# (1800, 9)

# %%
id2.head()
# Out:
#                                           Movie_Name              Star_1  \
# 0                                    The Dark Knight      Christian Bale
# 1      The Lord of the Rings: The Return of the King         Elijah Wood
# 2                Spider-Man: Across the Spider-Verse       Shameik Moore
# 3                                          Inception   Leonardo DiCaprio
# 4  The Lord of the Rings: The Fellowship of the Ring         Elijah Wood
#
#                   Star_2              Star_3              Star_4      Votes  \
# 0           Heath Ledger       Aaron Eckhart       Michael Caine  2,747,164
# 1        Viggo Mortensen        Ian McKellen       Orlando Bloom  1,901,366
# 2       Hailee Steinfeld   Brian Tyree Henry   Luna Lauren Velez    191,706
# 3   Joseph Gordon-Levitt         Elliot Page        Ken Watanabe  2,438,027
# 4           Ian McKellen       Orlando Bloom           Sean Bean  1,929,701
#
#      Genre_1     Genre_2     Genre_3 Gross Collection Certification
# 0     Action       Crime       Drama           534.86        PG-13
# 1     Action   Adventure       Drama           377.85        PG-13
# 2  Animation      Action   Adventure    Not Available           PG
# 3     Action   Adventure      Sci-Fi           292.58        PG-13
# 4     Action   Adventure       Drama           315.54        PG-13

# %%
id1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1800 entries, 0 to 1799
# Data columns (total 9 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Sno         1800 non-null   int64
#  1   Movie_Name  1800 non-null   object
#  2   Director_1  1800 non-null   object
#  3   Director_2  1800 non-null   object
#  4   Director_3  1800 non-null   object
#  5   Duration    1800 non-null   object
#  6   Year        1800 non-null   int64
#  7   Ratings     1800 non-null   float64
#  8   Metascore   1800 non-null   object
# dtypes: float64(1), int64(2), object(6)
# memory usage: 126.7+ KB

# %%
id2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1800 entries, 0 to 1799
# Data columns (total 11 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Movie_Name        1800 non-null   object
#  1   Star_1            1800 non-null   object
#  2   Star_2            1800 non-null   object
#  3   Star_3            1800 non-null   object
#  4   Star_4            1800 non-null   object
#  5   Votes             1800 non-null   object
#  6   Genre_1           1800 non-null   object
#  7   Genre_2           1800 non-null   object
#  8   Genre_3           1800 non-null   object
#  9   Gross Collection  1800 non-null   object
#  10  Certification     1800 non-null   object
# dtypes: object(11)
# memory usage: 154.8+ KB

# %%
# seprating the common column from the second dataset
id2 = id2.drop('Movie_Name', axis=1)

# %%
# Join the dataframe based on the index
df = id1.join(id2)

# %%
df.head()
# Out:
#    Sno                                         Movie_Name          Director_1  \
# 0    1                                    The Dark Knight  Christopher Nolan
# 1    2      The Lord of the Rings: The Return of the King      Peter Jackson
# 2    3                Spider-Man: Across the Spider-Verse  Joaquim Dos Santos
# 3    4                                          Inception  Christopher Nolan
# 4    5  The Lord of the Rings: The Fellowship of the Ring      Peter Jackson
#
#       Director_2            Director_3 Duration  Year  Ratings Metascore  \
# 0  Not Available         Not Available  152 min  2008      9.0        84
# 1  Not Available         Not Available  201 min  2003      9.0        94
# 2    Kemp Powers   Justin K. Thompson   140 min  2023      8.9        86
# 3  Not Available         Not Available  148 min  2010      8.8        74
# 4  Not Available         Not Available  178 min  2001      8.8        92
#
#                Star_1                 Star_2              Star_3  \
# 0      Christian Bale           Heath Ledger       Aaron Eckhart
# 1         Elijah Wood        Viggo Mortensen        Ian McKellen
# 2       Shameik Moore       Hailee Steinfeld   Brian Tyree Henry
# 3   Leonardo DiCaprio   Joseph Gordon-Levitt         Elliot Page
# 4         Elijah Wood           Ian McKellen       Orlando Bloom
#
#                Star_4      Votes    Genre_1     Genre_2     Genre_3  \
# 0       Michael Caine  2,747,164     Action       Crime       Drama
# 1       Orlando Bloom  1,901,366     Action   Adventure       Drama
# 2   Luna Lauren Velez    191,706  Animation      Action   Adventure
# 3        Ken Watanabe  2,438,027     Action   Adventure      Sci-Fi
# 4           Sean Bean  1,929,701     Action   Adventure       Drama
#
#   Gross Collection Certification
# 0           534.86        PG-13
# 1           377.85        PG-13
# 2    Not Available           PG
# 3           292.58        PG-13
# 4           315.54        PG-13

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1800 entries, 0 to 1799
# Data columns (total 19 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Sno               1800 non-null   int64
#  1   Movie_Name        1800 non-null   object
#  2   Director_1        1800 non-null   object
#  3   Director_2        1800 non-null   object
#  4   Director_3        1800 non-null   object
#  5   Duration          1800 non-null   object
#  6   Year              1800 non-null   int64
#  7   Ratings           1800 non-null   float64
#  8   Metascore         1800 non-null   object
#  9   Star_1            1800 non-null   object
#  10  Star_2            1800 non-null   object
#  11  Star_3            1800 non-null   object
#  12  Star_4            1800 non-null   object
#  13  Votes             1800 non-null   object
#  14  Genre_1           1800 non-null   object
#  15  Genre_2           1800 non-null   object
#  16  Genre_3           1800 non-null   object
#  17  Gross Collection  1800 non-null   object
#  18  Certification     1800 non-null   object
# dtypes: float64(1), int64(2), object(16)
# memory usage: 267.3+ KB

# %%
# Reset index of the joined dataframe
df = df.reset_index(drop=True)

# %%
df.head()
# Out:
#    Sno                                         Movie_Name          Director_1  \
# 0    1                                    The Dark Knight  Christopher Nolan
# 1    2      The Lord of the Rings: The Return of the King      Peter Jackson
# 2    3                Spider-Man: Across the Spider-Verse  Joaquim Dos Santos
# 3    4                                          Inception  Christopher Nolan
# 4    5  The Lord of the Rings: The Fellowship of the Ring      Peter Jackson
#
#       Director_2            Director_3 Duration  Year  Ratings Metascore  \
# 0  Not Available         Not Available  152 min  2008      9.0        84
# 1  Not Available         Not Available  201 min  2003      9.0        94
# 2    Kemp Powers   Justin K. Thompson   140 min  2023      8.9        86
# 3  Not Available         Not Available  148 min  2010      8.8        74
# 4  Not Available         Not Available  178 min  2001      8.8        92
#
#                Star_1                 Star_2              Star_3  \
# 0      Christian Bale           Heath Ledger       Aaron Eckhart
# 1         Elijah Wood        Viggo Mortensen        Ian McKellen
# 2       Shameik Moore       Hailee Steinfeld   Brian Tyree Henry
# 3   Leonardo DiCaprio   Joseph Gordon-Levitt         Elliot Page
# 4         Elijah Wood           Ian McKellen       Orlando Bloom
#
#                Star_4      Votes    Genre_1     Genre_2     Genre_3  \
# 0       Michael Caine  2,747,164     Action       Crime       Drama
# 1       Orlando Bloom  1,901,366     Action   Adventure       Drama
# 2   Luna Lauren Velez    191,706  Animation      Action   Adventure
# 3        Ken Watanabe  2,438,027     Action   Adventure      Sci-Fi
# 4           Sean Bean  1,929,701     Action   Adventure       Drama
#
#   Gross Collection Certification
# 0           534.86        PG-13
# 1           377.85        PG-13
# 2    Not Available           PG
# 3           292.58        PG-13
# 4           315.54        PG-13

# %%
df
# Out:
#       Sno                                         Movie_Name  \
# 0       1                                    The Dark Knight
# 1       2      The Lord of the Rings: The Return of the King
# 2       3                Spider-Man: Across the Spider-Verse
# 3       4                                          Inception
# 4       5  The Lord of the Rings: The Fellowship of the Ring
# ...   ...                                                ...
# 1795   46                Demon Slayer the Movie: Mugen Train
# 1796   47                        Baahubali 2: The Conclusion
# 1797   48                                 Gangs of Wasseypur
# 1798   49                                            Yojimbo
# 1799   50                           Uri: The Surgical Strike
#
#               Director_1     Director_2            Director_3 Duration  Year  \
# 0     Christopher Nolan   Not Available         Not Available  152 min  2008
# 1         Peter Jackson   Not Available         Not Available  201 min  2003
# 2     Joaquim Dos Santos    Kemp Powers   Justin K. Thompson   140 min  2023
# 3     Christopher Nolan   Not Available         Not Available  148 min  2010
# 4         Peter Jackson   Not Available         Not Available  178 min  2001
# ...                  ...            ...                   ...      ...   ...
# 1795     Haruo Sotozaki   Not Available         Not Available  117 min  2020
# 1796     S.S. Rajamouli   Not Available         Not Available  167 min  2017
# 1797     Anurag Kashyap   Not Available         Not Available  321 min  2012
# 1798     Akira Kurosawa   Not Available         Not Available  110 min  1961
# 1799        Aditya Dhar   Not Available         Not Available  138 min  2019
#
#       Ratings      Metascore              Star_1                 Star_2  \
# 0         9.0             84      Christian Bale           Heath Ledger
# 1         9.0             94         Elijah Wood        Viggo Mortensen
# 2         8.9             86       Shameik Moore       Hailee Steinfeld
# 3         8.8             74   Leonardo DiCaprio   Joseph Gordon-Levitt
# 4         8.8             92         Elijah Wood           Ian McKellen
# ...       ...            ...                 ...                    ...
# 1795      8.2             72       Natsuki Hanae             Akari Kitô
# 1796      8.2  Not Available             Prabhas         Rana Daggubati
# 1797      8.2             89      Manoj Bajpayee    Nawazuddin Siddiqui
# 1798      8.2             93      Toshirô Mifune            Eijirô Tôno
# 1799      8.2  Not Available       Vicky Kaushal           Paresh Rawal
#
#                     Star_3              Star_4      Votes    Genre_1  \
# 0            Aaron Eckhart       Michael Caine  2,747,164     Action
# 1             Ian McKellen       Orlando Bloom  1,901,366     Action
# 2        Brian Tyree Henry   Luna Lauren Velez    191,706  Animation
# 3              Elliot Page        Ken Watanabe  2,438,027     Action
# 4            Orlando Bloom           Sean Bean  1,929,701     Action
# ...                    ...                 ...        ...        ...
# 1795   Yoshitsugu Matsuoka        Hiro Shimono     66,289  Animation
# 1796        Anushka Shetty    Tamannaah Bhatia    108,208     Action
# 1797      Tigmanshu Dhulia        Richa Chadha     99,965     Action
# 1798       Tatsuya Nakadai        Yôko Tsukasa    126,874     Action
# 1799           Mohit Raina         Yami Gautam     68,406     Action
#
#          Genre_2        Genre_3 Gross Collection Certification
# 0          Crime          Drama           534.86        PG-13
# 1      Adventure          Drama           377.85        PG-13
# 2         Action      Adventure    Not Available           PG
# 3      Adventure         Sci-Fi           292.58        PG-13
# 4      Adventure          Drama           315.54        PG-13
# ...          ...            ...              ...           ...
# 1795      Action      Adventure            47.70            R
# 1796       Drama  Not Available            20.19    Not Rated
# 1797      Comedy          Crime    Not Available    Not Rated
# 1798       Drama       Thriller    Not Available    Not Rated
# 1799       Drama        History             4.19    Not Rated
#
# [1800 rows x 19 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1800 entries, 0 to 1799
# Data columns (total 19 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Sno               1800 non-null   int64
#  1   Movie_Name        1800 non-null   object
#  2   Director_1        1800 non-null   object
#  3   Director_2        1800 non-null   object
#  4   Director_3        1800 non-null   object
#  5   Duration          1800 non-null   object
#  6   Year              1800 non-null   int64
#  7   Ratings           1800 non-null   float64
#  8   Metascore         1800 non-null   object
#  9   Star_1            1800 non-null   object
#  10  Star_2            1800 non-null   object
#  11  Star_3            1800 non-null   object
#  12  Star_4            1800 non-null   object
#  13  Votes             1800 non-null   object
#  14  Genre_1           1800 non-null   object
#  15  Genre_2           1800 non-null   object
#  16  Genre_3           1800 non-null   object
#  17  Gross Collection  1800 non-null   object
#  18  Certification     1800 non-null   object
# dtypes: float64(1), int64(2), object(16)
# memory usage: 267.3+ KB

# %%
#checking for duplicates
df.duplicated().sum()
# Out:
# 1750

# %%
# Checking Null Values

df.isnull().sum()
# Out:
# Sno                 0
# Movie_Name          0
# Director_1          0
# Director_2          0
# Director_3          0
# Duration            0
# Year                0
# Ratings             0
# Metascore           0
# Star_1              0
# Star_2              0
# Star_3              0
# Star_4              0
# Votes               0
# Genre_1             0
# Genre_2             0
# Genre_3             0
# Gross Collection    0
# Certification       0
# dtype: int64

# %%
df.dtypes
# Out:
# Sno                   int64
# Movie_Name           object
# Director_1           object
# Director_2           object
# Director_3           object
# Duration             object
# Year                  int64
# Ratings             float64
# Metascore            object
# Star_1               object
# Star_2               object
# Star_3               object
# Star_4               object
# Votes                object
# Genre_1              object
# Genre_2              object
# Genre_3              object
# Gross Collection     object
# Certification        object
# dtype: object

# %% [markdown]
# # CONVERTING OBJECT DATAS INTO FLOAT DATA OR INT DATA

# %%
from sklearn.preprocessing import OrdinalEncoder
ordin=OrdinalEncoder()

# %%
for i in df.columns:
    if df[i].dtypes=='object':
        df[i]=ordin.fit_transform(df[i].values.reshape(-1,1))

# %%
df.dtypes
# Out:
# Sno                   int64
# Movie_Name          float64
# Director_1          float64
# Director_2          float64
# Director_3          float64
# Duration            float64
# Year                  int64
# Ratings             float64
# Metascore           float64
# Star_1              float64
# Star_2              float64
# Star_3              float64
# Star_4              float64
# Votes               float64
# Genre_1             float64
# Genre_2             float64
# Genre_3             float64
# Gross Collection    float64
# Certification       float64
# dtype: object

# %%
df.isnull().sum()
# Out:
# Sno                 0
# Movie_Name          0
# Director_1          0
# Director_2          0
# Director_3          0
# Duration            0
# Year                0
# Ratings             0
# Metascore           0
# Star_1              0
# Star_2              0
# Star_3              0
# Star_4              0
# Votes               0
# Genre_1             0
# Genre_2             0
# Genre_3             0
# Gross Collection    0
# Certification       0
# dtype: int64

# %% [markdown]
# # DATA VISUALIZATION

# %%
collist=df.columns.values
ncol=50
nrows=50
plt.figure(figsize=(ncol,3*ncol))
for i in range(0,len(collist)):
    plt.subplot(nrows,ncol,i+1) 
    sns.boxplot(df[collist[i]],color='green')
    plt.tight_layout()

# %% [markdown]
# THE ABOVE GIVES A CLEAR PICTURE OF THE DISTRIBUTION OF THE DATASET

# %%
sns.histplot(data=df,bins=20)
# Out:
# <Axes: ylabel='Count'>

# %% [markdown]
# THE ABOVE SHOWS HIST DISTRIBUTION OF THE DATASET

# %%
sns.jointplot(data=df,x='Director_1',y='Director_2',hue='Movie_Name')

# %% [markdown]
# THE ABOVE SHOWS THE JOINT OF DIRECTOR_1, DIRECTOR_2 AND MOVIE_NAME

# %%
sns.catplot(data=df,x='Duration',y='Year')

# %%
sns.boxplot(data=df,x='Ratings',y='Metascore')
# Out:
# <Axes: xlabel='Ratings', ylabel='Metascore'>

# %% [markdown]
# THE ABOVE SHOWS THE DISTRIBUTION OF RATINGS AND METASCORE

# %%
plt.bar(df['Star_1'],df['Star_2'])
# Out:
# <BarContainer object of 1800 artists>

# %% [markdown]
# THE ABOVE SHOWS THE DISTRIBUTION OF STAR_1 AND STAR_2

# %%
plt.figure(figsize=(10,5))
sns.histplot(df['Star_3'], bins=30)
# Out:
# <Axes: xlabel='Star_3', ylabel='Count'>

# %% [markdown]
# THE ABOVE SHOWS THE HIST DISTRIBUTION OF STAR_3

# %%
plt.figure(figsize=(10,5))
sns.histplot(df['Star_4'], bins=20)
# Out:
# <Axes: xlabel='Star_4', ylabel='Count'>

# %% [markdown]
# THE ABOVE SHOWS THE HIST FISTRIBUTION OF STAR_4

# %%
sns.violinplot(df['Votes'])
# Out:
# <Axes: >

# %% [markdown]
# THE ABOVE SHOWS THE DISTRIBUTION OF VOTES

# %%
sns.violinplot(df['Gross Collection'])
# Out:
# <Axes: >

# %% [markdown]
# THE ABOVE SHOWS THE DISTRIBUTION OF GROSS_COLLECTION

# %%
sns.histplot(data=df,x='Gross Collection',y='Votes',color='red')
# Out:
# <Axes: xlabel='Gross Collection', ylabel='Votes'>

# %% [markdown]
# THE ABOVE SHOWS THE DISTRIBUTION OF GROSS_COLLECTION AND VOTES

# %%
sns.displot(df['Certification'],kde=True)

# %% [markdown]
# THE ABOVE SHOWS THE DISTRIBUTION OF CERTIFICATION

# %%
df.plot(figsize=(18,12),kind='density',subplots=True,layout=(2,10),legend=True,sharex=False ) 
plt.show()

# %% [markdown]
# THE ABOVE SHOWS THE DISTRIBUTION OF COMPLETE DATASET DENSITY WISE

# %%
df.plot(kind='box',subplots=True,layout=(2,10))
# Out:
# Sno                    Axes(0.125,0.53;0.065678x0.35)
# Movie_Name          Axes(0.203814,0.53;0.065678x0.35)
# Director_1          Axes(0.282627,0.53;0.065678x0.35)
# Director_2          Axes(0.361441,0.53;0.065678x0.35)
# Director_3          Axes(0.440254,0.53;0.065678x0.35)
# Duration            Axes(0.519068,0.53;0.065678x0.35)
# Year                Axes(0.597881,0.53;0.065678x0.35)
# Ratings             Axes(0.676695,0.53;0.065678x0.35)
# Metascore           Axes(0.755508,0.53;0.065678x0.35)
# Star_1              Axes(0.834322,0.53;0.065678x0.35)
# Star_2                 Axes(0.125,0.11;0.065678x0.35)
# Star_3              Axes(0.203814,0.11;0.065678x0.35)
# Star_4              Axes(0.282627,0.11;0.065678x0.35)
# Votes               Axes(0.361441,0.11;0.065678x0.35)
# Genre_1             Axes(0.440254,0.11;0.065678x0.35)
# Genre_2             Axes(0.519068,0.11;0.065678x0.35)
# Genre_3             Axes(0.597881,0.11;0.065678x0.35)
# Gross Collection    Axes(0.676695,0.11;0.065678x0.35)
# Certification       Axes(0.755508,0.11;0.065678x0.35)
# dtype: object

# %% [markdown]
# THE ABOVE CLEARLY STATES THE PRESENCE OF OUTLIERS IN SOME COLUMNS

# %%
sns.countplot(df['Votes'])
# Out:
# <Axes: ylabel='count'>

# %% [markdown]
# THE ABOVE SHOWS THE COUNT OF VOTES COLUMN

# %%
sns.countplot(df['Gross Collection'])
# Out:
# <Axes: ylabel='count'>

# %% [markdown]
# THE ABOVE GIVES THE DISTRIBUTION OF GROSS_COLLECTION

# %% [markdown]
# # MORE EDA

# %%
df.describe()
# Out:
#               Sno  Movie_Name   Director_1   Director_2  Director_3  \
# count  1800.00000  1800.00000  1800.000000  1800.000000  1800.00000
# mean     25.50000    24.50000    17.500000     3.720000     1.94000
# std      14.43488    14.43488    11.359652     0.917643     0.31057
# min       1.00000     0.00000     0.000000     0.000000     0.00000
# 25%      13.00000    12.00000     6.000000     4.000000     2.00000
# 50%      25.50000    24.50000    17.500000     4.000000     2.00000
# 75%      38.00000    37.00000    27.000000     4.000000     2.00000
# max      50.00000    49.00000    37.000000     4.000000     2.00000
#
#           Duration         Year      Ratings   Metascore       Star_1  \
# count  1800.000000  1800.000000  1800.000000  1800.00000  1800.000000
# mean     18.540000  2002.700000     8.422000    17.36000    18.680000
# std      11.198128    18.633381     0.227475     8.90362    10.848179
# min       0.000000  1954.000000     8.200000     0.00000     0.000000
# 25%       9.000000  1991.000000     8.200000    10.00000    10.000000
# 50%      18.000000  2005.000000     8.350000    17.50000    19.000000
# 75%      28.000000  2019.000000     8.600000    27.00000    28.000000
# max      39.000000  2023.000000     9.000000    28.00000    38.000000
#
#             Star_2       Star_3       Star_4       Votes      Genre_1  \
# count  1800.000000  1800.000000  1800.000000  1800.00000  1800.000000
# mean     22.180000    22.580000    23.120000    24.50000     0.080000
# std      13.003136    13.421761    13.913056    14.43488     0.271369
# min       0.000000     0.000000     0.000000     0.00000     0.000000
# 25%      12.000000    10.000000    11.000000    12.00000     0.000000
# 50%      21.500000    22.500000    23.500000    24.50000     0.000000
# 75%      33.000000    34.000000    35.000000    37.00000     0.000000
# max      45.000000    46.000000    47.000000    49.00000     1.000000
#
#            Genre_2      Genre_3  Gross Collection  Certification
# count  1800.000000  1800.000000       1800.000000    1800.000000
# mean      2.920000     4.600000         23.180000       2.880000
# std       2.038605     3.053716         12.682151       1.608427
# min       0.000000     0.000000          0.000000       0.000000
# 25%       1.000000     2.000000         12.000000       1.000000
# 50%       3.500000     4.500000         24.500000       3.000000
# 75%       5.000000     7.000000         37.000000       4.000000
# max       7.000000     9.000000         38.000000       8.000000

# %% [markdown]
# THE ABOVE SHOWS SOME MILDLY SKEWED DATAS THAT TOO MOSTLY BY THE RIGHT

# %%
df.corr()
# Out:
#                        Sno  Movie_Name  Director_1  Director_2  Director_3  \
# Sno               1.000000   -0.247923    0.009580    0.217544    0.234346
# Movie_Name       -0.247923    1.000000   -0.175307    0.148051   -0.104898
# Director_1        0.009580   -0.175307    1.000000    0.264918    0.110607
# Director_2        0.217544    0.148051    0.264918    1.000000    0.432533
# Director_3        0.234346   -0.104898    0.110607    0.432533    1.000000
# Duration         -0.173998   -0.012937   -0.082982   -0.117700    0.089877
# Year              0.119447   -0.097128    0.212100   -0.228447   -0.193300
# Ratings          -0.928469    0.334883   -0.051499   -0.171792   -0.264561
# Metascore        -0.038147    0.124094   -0.003166    0.161748   -0.042842
# Star_1            0.218012    0.093160   -0.079245   -0.117557   -0.130433
# Star_2            0.022016    0.141742    0.138523    0.279265    0.131512
# Star_3            0.195782   -0.008934   -0.116090    0.034315    0.142772
# Star_4            0.117177    0.176563    0.129527    0.298869    0.038716
# Votes             0.296807   -0.184154   -0.094762    0.237183   -0.046869
# Genre_1          -0.030651   -0.005109   -0.207729   -0.231436   -0.655332
# Genre_2           0.208088    0.121045   -0.031108    0.223355    0.276875
# Genre_3           0.104414    0.029054    0.134411    0.102833    0.291181
# Gross Collection  0.174734    0.039079    0.010209   -0.129789   -0.073466
# Certification    -0.103428    0.154280    0.106237    0.004339    0.105758
#
#                   Duration      Year   Ratings  Metascore    Star_1    Star_2  \
# Sno              -0.173998  0.119447 -0.928469  -0.038147  0.218012  0.022016
# Movie_Name       -0.012937 -0.097128  0.334883   0.124094  0.093160  0.141742
# Director_1       -0.082982  0.212100 -0.051499  -0.003166 -0.079245  0.138523
# Director_2       -0.117700 -0.228447 -0.171792   0.161748 -0.117557  0.279265
# Director_3        0.089877 -0.193300 -0.264561  -0.042842 -0.130433  0.131512
# Duration          1.000000  0.253866  0.259290   0.445622 -0.034982  0.312120
# Year              0.253866  1.000000 -0.068315   0.140930  0.024769  0.218510
# Ratings           0.259290 -0.068315  1.000000   0.136388 -0.177982 -0.051403
# Metascore         0.445622  0.140930  0.136388   1.000000  0.128402  0.162951
# Star_1           -0.034982  0.024769 -0.177982   0.128402  1.000000 -0.109109
# Star_2            0.312120  0.218510 -0.051403   0.162951 -0.109109  1.000000
# Star_3            0.067548 -0.060355 -0.174594   0.087505  0.149570 -0.099436
# Star_4            0.251456  0.051933  0.006121   0.434034  0.207351  0.170775
# Votes             0.100957  0.185811 -0.248953   0.296143  0.072841  0.207096
# Genre_1          -0.231534  0.186794  0.036308  -0.069902  0.239819 -0.094820
# Genre_2           0.031697 -0.051205 -0.151551   0.111836 -0.122409  0.076789
# Genre_3          -0.154607 -0.259894 -0.148648  -0.038125 -0.088436  0.053722
# Gross Collection  0.200953  0.340054 -0.079063   0.225735  0.294670 -0.144479
# Certification    -0.013066  0.255861  0.083791  -0.237325 -0.176526  0.112979
#
#                     Star_3    Star_4     Votes   Genre_1   Genre_2   Genre_3  \
# Sno               0.195782  0.117177  0.296807 -0.030651  0.208088  0.104414
# Movie_Name       -0.008934  0.176563 -0.184154 -0.005109  0.121045  0.029054
# Director_1       -0.116090  0.129527 -0.094762 -0.207729 -0.031108  0.134411
# Director_2        0.034315  0.298869  0.237183 -0.231436  0.223355  0.102833
# Director_3        0.142772  0.038716 -0.046869 -0.655332  0.276875  0.291181
# Duration          0.067548  0.251456  0.100957 -0.231534  0.031697 -0.154607
# Year             -0.060355  0.051933  0.185811  0.186794 -0.051205 -0.259894
# Ratings          -0.174594  0.006121 -0.248953  0.036308 -0.151551 -0.148648
# Metascore         0.087505  0.434034  0.296143 -0.069902  0.111836 -0.038125
# Star_1            0.149570  0.207351  0.072841  0.239819 -0.122409 -0.088436
# Star_2           -0.099436  0.170775  0.207096 -0.094820  0.076789  0.053722
# Star_3            1.000000  0.205270  0.006249  0.163067  0.038996 -0.242362
# Star_4            0.205270  1.000000  0.194199 -0.209250  0.434240  0.210254
# Votes             0.006249  0.194199  1.000000  0.178800  0.095884 -0.078537
# Genre_1           0.163067 -0.209250  0.178800  1.000000 -0.422495 -0.444325
# Genre_2           0.038996  0.434240  0.095884 -0.422495  1.000000  0.599178
# Genre_3          -0.242362  0.210254 -0.078537 -0.444325  0.599178  1.000000
# Gross Collection  0.128117  0.284993  0.228406 -0.062332  0.077958 -0.077197
# Certification    -0.024583 -0.093250 -0.030166 -0.023840  0.198467  0.193931
#
#                   Gross Collection  Certification
# Sno                       0.174734      -0.103428
# Movie_Name                0.039079       0.154280
# Director_1                0.010209       0.106237
# Director_2               -0.129789       0.004339
# Director_3               -0.073466       0.105758
# Duration                  0.200953      -0.013066
# Year                      0.340054       0.255861
# Ratings                  -0.079063       0.083791
# Metascore                 0.225735      -0.237325
# Star_1                    0.294670      -0.176526
# Star_2                   -0.144479       0.112979
# Star_3                    0.128117      -0.024583
# Star_4                    0.284993      -0.093250
# Votes                     0.228406      -0.030166
# Genre_1                  -0.062332      -0.023840
# Genre_2                   0.077958       0.198467
# Genre_3                  -0.077197       0.193931
# Gross Collection          1.000000       0.134478
# Certification             0.134478       1.000000

# %%
plt.figure(figsize=(20,20))
sns.heatmap(df.corr(),annot=True)
plt.show()

# %%
df.skew()
# Out:
# Sno                 0.000000
# Movie_Name          0.000000
# Director_1          0.093151
# Director_2         -3.306981
# Director_3         -5.431480
# Duration            0.110188
# Year               -0.924298
# Ratings             0.983413
# Metascore          -0.283622
# Star_1              0.059086
# Star_2              0.065005
# Star_3              0.058641
# Star_4              0.008238
# Votes               0.000000
# Genre_1             3.098864
# Genre_2             0.080086
# Genre_3             0.178972
# Gross Collection   -0.284738
# Certification       0.744451
# dtype: float64

# %% [markdown]
# MOST OF THE SKEW IS REMOVED EXCEPT FOR DIRECTOR_2 COLUMNS OF WHICH IT CAN BE REMOVED DUE TO HEAVILY SKEWED DATAS

# %%
dfnew2=df.drop(['Director_2'],axis=1)

# %% [markdown]
# # REMOVING OUTLIERS

# %%
from scipy.stats import zscore
z=np.abs(zscore(df))

# %%
new=df[(z<3).all(axis=1)]
new.head()
# Out:
#    Sno  Movie_Name  Director_1  Director_2  Director_3  Duration  Year  \
# 0    1        39.0         6.0         4.0         2.0      23.0  2008
# 1    2        42.0        25.0         4.0         2.0      37.0  2003
# 3    4        14.0         6.0         4.0         2.0      21.0  2010
# 4    5        41.0        25.0         4.0         2.0      34.0  2001
# 5    6        43.0        25.0         4.0         2.0      35.0  2002
#
#    Ratings  Metascore  Star_1  Star_2  Star_3  Star_4  Votes  Genre_1  \
# 0      9.0       17.0     6.0    14.0     0.0    22.0   27.0      0.0
# 1      9.0       25.0    10.0    41.0    21.0    26.0   15.0      0.0
# 3      8.8       11.0    17.0    19.0    17.0    17.0   26.0      0.0
# 4      8.8       23.0    10.0    15.0    32.0    37.0   16.0      0.0
# 5      8.8       20.0    10.0    15.0    44.0    26.0   13.0      0.0
#
#    Genre_2  Genre_3  Gross Collection  Certification
# 0      4.0      2.0              27.0            3.0
# 1      1.0      2.0              21.0            3.0
# 3      1.0      6.0              16.0            3.0
# 4      1.0      2.0              18.0            3.0
# 5      1.0      2.0              20.0            3.0

# %%
new.skew()
# Out:
# Sno                -0.006208
# Movie_Name         -0.021754
# Director_1         -0.117748
# Director_2         -6.332575
# Director_3          0.000000
# Duration            0.097931
# Year               -0.783800
# Ratings             0.906832
# Metascore          -0.360002
# Star_1              0.174369
# Star_2             -0.038635
# Star_3              0.043837
# Star_4             -0.138539
# Votes               0.089838
# Genre_1             0.000000
# Genre_2            -0.053916
# Genre_3             0.201800
# Gross Collection   -0.235482
# Certification       0.356718
# dtype: float64

# %%
new.shape
# Out:
# (1548, 19)

# %%
collist=new.columns.values
ncol=50
nrows=50
plt.figure(figsize=(ncol,3*ncol))
for i in range(0,len(collist)):
    plt.subplot(nrows,ncol,i+1) 
    sns.boxplot(new[collist[i]],color='blue')
    plt.tight_layout()

# %% [markdown]
# # SPLITTING X AND Y

# %%
x=new.drop('Votes',axis=1)
y=new['Votes']

# %%
x.shape
# Out:
# (1548, 18)

# %%
y.shape
# Out:
# (1548,)

# %% [markdown]
# # TRAINING AND TESTING

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
lr=LinearRegression()
from sklearn.metrics import r2_score,mean_absolute_error,mean_squared_error

# %%
maxR2=0
maxRS=0
for i in range(0,1000):
    x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.20,random_state=i)
    lr.fit(x_train,y_train)
    predlr=lr.predict(x_test)
    score=r2_score(y_test,predlr)
    print('R2_score of LinearRegression ' ,score, 'at random_state ' ,i)
    if score > maxR2:
        maxR2=score
        maxRS=i
    print('R2 score of lr ' ,maxR2*100, 'at random_state ' ,maxRS)
# Out:
# R2_score of LinearRegression  0.3626247966761229 at random_state  0
# R2 score of lr  36.26247966761229 at random_state  0
# R2_score of LinearRegression  0.40298928176657955 at random_state  1
# R2 score of lr  40.29892817665795 at random_state  1
# R2_score of LinearRegression  0.46328422121427437 at random_state  2
# R2 score of lr  46.32842212142744 at random_state  2
# R2_score of LinearRegression  0.4198922186247809 at random_state  3
# R2 score of lr  46.32842212142744 at random_state  2
# R2_score of LinearRegression  0.36001511087846927 at random_state  4
# R2 score of lr  46.32842212142744 at random_state  2
# R2_score of LinearRegression  0.368263155422888 at random_state  5
# R2 score of lr  46.32842212142744 at random_state  2
# R2_score of LinearRegression  0.38412365377932245 at random_state  6
# R2 score of lr  46.32842212142744 at random_state  2
# R2_score of LinearRegression  0.4299735762659511 at random_state  7
# R2 score of lr  46.32842212142744 at random_state  2
# R2_score of LinearRegression  0.44290015829082907 at random_state  8
# R2 score of lr  46.32842212142744 at random_state  2
# R2_score of LinearRegression  0.4095134378357702 at random_state  9
# R2 score of lr  46.32842212142744 at random_state  2
# R2_score of LinearRegression  0.43929182098985886 at random_state  10
# R2 score of lr  46.32842212142744 at random_state  2
# R2_score of LinearRegression  0.3694201434223858 at random_state  11
# R2 score of lr  46.32842212142744 at random_state  2
# R2_score of LinearRegression  0.3523450841405883 at random_state  12
# R2 score of lr  46.32842212142744 at random_state  2
# R2_score of LinearRegression  0.4079156130955395 at random_state  13
# R2 score of lr  46.32842212142744 at random_state  2
# R2_score of LinearRegression  0.3875324902123648 at random_state  14
# R2 score of lr  46.32842212142744 at random_state  2
# R2_score of LinearRegression  0.41303969440584276 at random_state  15
# R2 score of lr  46.32842212142744 at random_state  2
# R2_score of LinearRegression  0.34294256608967844 at random_state  16
# R2 score of lr  46.32842212142744 at random_state  2
# R2_score of LinearRegression  0.40519354823176246 at random_state  17
# R2 score of lr  46.32842212142744 at random_state  2
# R2_score of LinearRegression  0.35238173737335776 at random_state  18
# R2 score of lr  46.32842212142744 at random_state  2
# R2_score of LinearRegression  0.3658122410891277 at random_state  19
# R2 score of lr  46.32842212142744 at random_state  2
# R2_score of LinearRegression  0.3921519397771456 at random_state  20
# R2 score of lr  46.32842212142744 at random_state  2
# R2_score of LinearRegression  0.38158583158479287 at random_state  21
# R2 score of lr  46.32842212142744 at random_state  2
# R2_score of LinearRegression  0.4396835710645767 at random_state  22
# R2 score of lr  46.32842212142744 at random_state  2
# R2_score of LinearRegression  0.36574611397928225 at random_state  23
# R2 score of lr  46.32842212142744 at random_state  2
# R2_score of LinearRegression  0.36155817698892656 at random_state  24
# R2 score of lr  46.32842212142744 at random_state  2
# R2_score of LinearRegression  0.3677880588578394 at random_state  25
# R2 score of lr  46.32842212142744 at random_state  2
# R2_score of LinearRegression  0.3702098395169906 at random_state  26
# R2 score of lr  46.32842212142744 at random_state  2
# R2_score of LinearRegression  0.38337482449932836 at random_state  27
# R2 score of lr  46.32842212142744 at random_state  2
# R2_score of LinearRegression  0.4280561207379301 at random_state  28
# R2 score of lr  46.32842212142744 at random_state  2
# R2_score of LinearRegression  0.45272170085650854 at random_state  29
# R2 score of lr  46.32842212142744 at random_state  2
# R2_score of LinearRegression  0.3418010341116242 at random_state  30
# R2 score of lr  46.32842212142744 at random_state  2
# R2_score of LinearRegression  0.37262843842963445 at random_state  31
# R2 score of lr  46.32842212142744 at random_state  2
# R2_score of LinearRegression  0.3945776168298486 at random_state  32
# R2 score of lr  46.32842212142744 at random_state  2
# R2_score of LinearRegression  0.3783596442108599 at random_state  33
# R2 score of lr  46.32842212142744 at random_state  2
# R2_score of LinearRegression  0.4011892619701284 at random_state  34
# R2 score of lr  46.32842212142744 at random_state  2
# R2_score of LinearRegression  0.43315458261895423 at random_state  35
# R2 score of lr  46.32842212142744 at random_state  2
# R2_score of LinearRegression  0.2773654815426563 at random_state  36
# R2 score of lr  46.32842212142744 at random_state  2
# R2_score of LinearRegression  0.3815445616815344 at random_state  37
# R2 score of lr  46.32842212142744 at random_state  2
# R2_score of LinearRegression  0.37951701571312324 at random_state  38
# R2 score of lr  46.32842212142744 at random_state  2
# R2_score of LinearRegression  0.3992112786155907 at random_state  39
# R2 score of lr  46.32842212142744 at random_state  2
# R2_score of LinearRegression  0.4340728687115587 at random_state  40
# R2 score of lr  46.32842212142744 at random_state  2
# R2_score of LinearRegression  0.3962342785745524 at random_state  41
# R2 score of lr  46.32842212142744 at random_state  2
# R2_score of LinearRegression  0.3680567509049609 at random_state  42
# R2 score of lr  46.32842212142744 at random_state  2
# R2_score of LinearRegression  0.414829702644932 at random_state  43
# R2 score of lr  46.32842212142744 at random_state  2
# R2_score of LinearRegression  0.40184802826307386 at random_state  44
# R2 score of lr  46.32842212142744 at random_state  2
# R2_score of LinearRegression  0.3873203597639754 at random_state  45
# R2 score of lr  46.32842212142744 at random_state  2
# R2_score of LinearRegression  0.3882224228448512 at random_state  46
# R2 score of lr  46.32842212142744 at random_state  2
# R2_score of LinearRegression  0.43666034764054473 at random_state  47
# R2 score of lr  46.32842212142744 at random_state  2
# R2_score of LinearRegression  0.4831077623458917 at random_state  48
# R2 score of lr  48.31077623458917 at random_state  48
# R2_score of LinearRegression  0.38349070759700776 at random_state  49
# R2 score of lr  48.31077623458917 at random_state  48
# R2_score of LinearRegression  0.31348921912169814 at random_state  50
# R2 score of lr  48.31077623458917 at random_state  48
# R2_score of LinearRegression  0.3745168924644018 at random_state  51
# R2 score of lr  48.31077623458917 at random_state  48
# R2_score of LinearRegression  0.4173944530795305 at random_state  52
# R2 score of lr  48.31077623458917 at random_state  48
# R2_score of LinearRegression  0.3814366227699262 at random_state  53
# R2 score of lr  48.31077623458917 at random_state  48
# R2_score of LinearRegression  0.4336980322813102 at random_state  54
# R2 score of lr  48.31077623458917 at random_state  48
# R2_score of LinearRegression  0.40159024101770835 at random_state  55
# R2 score of lr  48.31077623458917 at random_state  48
# R2_score of LinearRegression  0.3630688149083646 at random_state  56
# R2 score of lr  48.31077623458917 at random_state  48
# R2_score of LinearRegression  0.3769586404445304 at random_state  57
# R2 score of lr  48.31077623458917 at random_state  48
# R2_score of LinearRegression  0.36711125094087926 at random_state  58
# R2 score of lr  48.31077623458917 at random_state  48
# R2_score of LinearRegression  0.35247463446067884 at random_state  59
# R2 score of lr  48.31077623458917 at random_state  48
# R2_score of LinearRegression  0.4069826334162827 at random_state  60
# R2 score of lr  48.31077623458917 at random_state  48
# R2_score of LinearRegression  0.41193092654680563 at random_state  61
# R2 score of lr  48.31077623458917 at random_state  48
# R2_score of LinearRegression  0.4298617152816132 at random_state  62
# R2 score of lr  48.31077623458917 at random_state  48
# R2_score of LinearRegression  0.32244373524434267 at random_state  63
# R2 score of lr  48.31077623458917 at random_state  48
# R2_score of LinearRegression  0.3928807179910311 at random_state  64
# R2 score of lr  48.31077623458917 at random_state  48
# R2_score of LinearRegression  0.4206378259057074 at random_state  65
# R2 score of lr  48.31077623458917 at random_state  48
# R2_score of LinearRegression  0.42045179100439367 at random_state  66
# R2 score of lr  48.31077623458917 at random_state  48
# R2_score of LinearRegression  0.36081327187803636 at random_state  67
# R2 score of lr  48.31077623458917 at random_state  48
# R2_score of LinearRegression  0.3687301892498749 at random_state  68
# R2 score of lr  48.31077623458917 at random_state  48
# R2_score of LinearRegression  0.417458387389554 at random_state  69
# R2 score of lr  48.31077623458917 at random_state  48
# R2_score of LinearRegression  0.4232118888516647 at random_state  70
# R2 score of lr  48.31077623458917 at random_state  48
# R2_score of LinearRegression  0.3244864064209967 at random_state  71
# R2 score of lr  48.31077623458917 at random_state  48
# R2_score of LinearRegression  0.31849808594170614 at random_state  72
# R2 score of lr  48.31077623458917 at random_state  48
# R2_score of LinearRegression  0.3949678120404686 at random_state  73
# R2 score of lr  48.31077623458917 at random_state  48
# R2_score of LinearRegression  0.3820967733406895 at random_state  74
# R2 score of lr  48.31077623458917 at random_state  48
# R2_score of LinearRegression  0.33215720580673624 at random_state  75
# R2 score of lr  48.31077623458917 at random_state  48
# R2_score of LinearRegression  0.3512416762268218 at random_state  76
# R2 score of lr  48.31077623458917 at random_state  48
# R2_score of LinearRegression  0.3466033726990817 at random_state  77
# R2 score of lr  48.31077623458917 at random_state  48
# R2_score of LinearRegression  0.4232963987918139 at random_state  78
# R2 score of lr  48.31077623458917 at random_state  48
# R2_score of LinearRegression  0.3966283017652946 at random_state  79
# R2 score of lr  48.31077623458917 at random_state  48
# R2_score of LinearRegression  0.31486072907203544 at random_state  80
# R2 score of lr  48.31077623458917 at random_state  48
# R2_score of LinearRegression  0.389215687642644 at random_state  81
# R2 score of lr  48.31077623458917 at random_state  48
# R2_score of LinearRegression  0.41612862905762804 at random_state  82
# R2 score of lr  48.31077623458917 at random_state  48
# R2_score of LinearRegression  0.2968129944305895 at random_state  83
# R2 score of lr  48.31077623458917 at random_state  48
# R2_score of LinearRegression  0.3863684815914884 at random_state  84
# R2 score of lr  48.31077623458917 at random_state  48
# R2_score of LinearRegression  0.31968181512661265 at random_state  85
# R2 score of lr  48.31077623458917 at random_state  48
# R2_score of LinearRegression  0.4434345808837683 at random_state  86
# R2 score of lr  48.31077623458917 at random_state  48
# R2_score of LinearRegression  0.3875153965549253 at random_state  87
# R2 score of lr  48.31077623458917 at random_state  48
# R2_score of LinearRegression  0.3722024327045589 at random_state  88
# R2 score of lr  48.31077623458917 at random_state  48
# R2_score of LinearRegression  0.3366961644130567 at random_state  89
# R2 score of lr  48.31077623458917 at random_state  48
# R2_score of LinearRegression  0.4270321467834606 at random_state  90
# R2 score of lr  48.31077623458917 at random_state  48
# R2_score of LinearRegression  0.33351064362873095 at random_state  91
# R2 score of lr  48.31077623458917 at random_state  48
# R2_score of LinearRegression  0.3866894082572704 at random_state  92
# R2 score of lr  48.31077623458917 at random_state  48
# R2_score of LinearRegression  0.3292075681855011 at random_state  93
# R2 score of lr  48.31077623458917 at random_state  48
# R2_score of LinearRegression  0.38514533792244177 at random_state  94
# R2 score of lr  48.31077623458917 at random_state  48
# R2_score of LinearRegression  0.3995446475048615 at random_state  95
# R2 score of lr  48.31077623458917 at random_state  48
# R2_score of LinearRegression  0.35912365111751676 at random_state  96
# R2 score of lr  48.31077623458917 at random_state  48
# R2_score of LinearRegression  0.406390443515807 at random_state  97
# R2 score of lr  48.31077623458917 at random_state  48
# R2_score of LinearRegression  0.395573210056001 at random_state  98
# R2 score of lr  48.31077623458917 at random_state  48
# R2_score of LinearRegression  0.3116422649140862 at random_state  99
# R2 score of lr  48.31077623458917 at random_state  48
# R2_score of LinearRegression  0.3759736996559194 at random_state  100
# R2 score of lr  48.31077623458917 at random_state  48
# R2_score of LinearRegression  0.42069287987421045 at random_state  101
# R2 score of lr  48.31077623458917 at random_state  48
# R2_score of LinearRegression  0.36866603681290455 at random_state  102
# R2 score of lr  48.31077623458917 at random_state  48
# R2_score of LinearRegression  0.4368325411854713 at random_state  103
# R2 score of lr  48.31077623458917 at random_state  48
# R2_score of LinearRegression  0.3613366588625717 at random_state  104
# R2 score of lr  48.31077623458917 at random_state  48
# R2_score of LinearRegression  0.40641843938069333 at random_state  105
# R2 score of lr  48.31077623458917 at random_state  48
# R2_score of LinearRegression  0.36787320544153923 at random_state  106
# R2 score of lr  48.31077623458917 at random_state  48
# R2_score of LinearRegression  0.42567670352506837 at random_state  107
# R2 score of lr  48.31077623458917 at random_state  48
# R2_score of LinearRegression  0.3868050480708036 at random_state  108
# R2 score of lr  48.31077623458917 at random_state  48
# R2_score of LinearRegression  0.4046329684155947 at random_state  109
# R2 score of lr  48.31077623458917 at random_state  48
# R2_score of LinearRegression  0.3938655061295643 at random_state  110
# R2 score of lr  48.31077623458917 at random_state  48
# R2_score of LinearRegression  0.4601556205891836 at random_state  111
# R2 score of lr  48.31077623458917 at random_state  48
# R2_score of LinearRegression  0.40949088428691405 at random_state  112
# R2 score of lr  48.31077623458917 at random_state  48
# R2_score of LinearRegression  0.35686591475572893 at random_state  113
# R2 score of lr  48.31077623458917 at random_state  48
# R2_score of LinearRegression  0.39632399921627903 at random_state  114
# R2 score of lr  48.31077623458917 at random_state  48
# R2_score of LinearRegression  0.4306289138800453 at random_state  115
# R2 score of lr  48.31077623458917 at random_state  48
# R2_score of LinearRegression  0.3981909461262968 at random_state  116
# R2 score of lr  48.31077623458917 at random_state  48
# R2_score of LinearRegression  0.40008759263945415 at random_state  117
# R2 score of lr  48.31077623458917 at random_state  48
# R2_score of LinearRegression  0.4249942200240051 at random_state  118
# R2 score of lr  48.31077623458917 at random_state  48
# R2_score of LinearRegression  0.3268184614664913 at random_state  119
# R2 score of lr  48.31077623458917 at random_state  48
# R2_score of LinearRegression  0.3929581851940941 at random_state  120
# R2 score of lr  48.31077623458917 at random_state  48
# R2_score of LinearRegression  0.39414638399401514 at random_state  121
# R2 score of lr  48.31077623458917 at random_state  48
# R2_score of LinearRegression  0.4131652261237402 at random_state  122
# R2 score of lr  48.31077623458917 at random_state  48
# R2_score of LinearRegression  0.36270621149496696 at random_state  123
# R2 score of lr  48.31077623458917 at random_state  48
# R2_score of LinearRegression  0.38900260239273066 at random_state  124
# R2 score of lr  48.31077623458917 at random_state  48
# R2_score of LinearRegression  0.4044197542177179 at random_state  125
# R2 score of lr  48.31077623458917 at random_state  48
# R2_score of LinearRegression  0.3785421281789829 at random_state  126
# R2 score of lr  48.31077623458917 at random_state  48
# R2_score of LinearRegression  0.4179205050143684 at random_state  127
# R2 score of lr  48.31077623458917 at random_state  48
# R2_score of LinearRegression  0.398174768542758 at random_state  128
# R2 score of lr  48.31077623458917 at random_state  48
# R2_score of LinearRegression  0.4627791219853359 at random_state  129
# R2 score of lr  48.31077623458917 at random_state  48
# R2_score of LinearRegression  0.40290065813474474 at random_state  130
# R2 score of lr  48.31077623458917 at random_state  48
# R2_score of LinearRegression  0.3764009236678052 at random_state  131
# R2 score of lr  48.31077623458917 at random_state  48
# R2_score of LinearRegression  0.38973214281657687 at random_state  132
# R2 score of lr  48.31077623458917 at random_state  48
# R2_score of LinearRegression  0.35179069201690927 at random_state  133
# R2 score of lr  48.31077623458917 at random_state  48
# R2_score of LinearRegression  0.44357016006567374 at random_state  134
# R2 score of lr  48.31077623458917 at random_state  48
# R2_score of LinearRegression  0.3789694589479904 at random_state  135
# R2 score of lr  48.31077623458917 at random_state  48
# R2_score of LinearRegression  0.3376574688433709 at random_state  136
# R2 score of lr  48.31077623458917 at random_state  48
# R2_score of LinearRegression  0.40327995059246746 at random_state  137
# R2 score of lr  48.31077623458917 at random_state  48
# R2_score of LinearRegression  0.4558585525657858 at random_state  138
# R2 score of lr  48.31077623458917 at random_state  48
# R2_score of LinearRegression  0.40867680823942276 at random_state  139
# R2 score of lr  48.31077623458917 at random_state  48
# R2_score of LinearRegression  0.37352745585715696 at random_state  140
# R2 score of lr  48.31077623458917 at random_state  48
# R2_score of LinearRegression  0.3905009418014793 at random_state  141
# R2 score of lr  48.31077623458917 at random_state  48
# R2_score of LinearRegression  0.32752938945573473 at random_state  142
# R2 score of lr  48.31077623458917 at random_state  48
# R2_score of LinearRegression  0.41807446719577424 at random_state  143
# R2 score of lr  48.31077623458917 at random_state  48
# R2_score of LinearRegression  0.3774670283201902 at random_state  144
# R2 score of lr  48.31077623458917 at random_state  48
# R2_score of LinearRegression  0.3537974219368757 at random_state  145
# R2 score of lr  48.31077623458917 at random_state  48
# R2_score of LinearRegression  0.4163750947400553 at random_state  146
# R2 score of lr  48.31077623458917 at random_state  48
# R2_score of LinearRegression  0.38539327564771586 at random_state  147
# R2 score of lr  48.31077623458917 at random_state  48
# R2_score of LinearRegression  0.37791853886485727 at random_state  148
# R2 score of lr  48.31077623458917 at random_state  48
# R2_score of LinearRegression  0.36114855339175966 at random_state  149
# R2 score of lr  48.31077623458917 at random_state  48
# R2_score of LinearRegression  0.33885154005692864 at random_state  150
# R2 score of lr  48.31077623458917 at random_state  48
# R2_score of LinearRegression  0.43668019283918547 at random_state  151
# R2 score of lr  48.31077623458917 at random_state  48
# R2_score of LinearRegression  0.35156009642435904 at random_state  152
# R2 score of lr  48.31077623458917 at random_state  48
# R2_score of LinearRegression  0.342521668103008 at random_state  153
# R2 score of lr  48.31077623458917 at random_state  48
# R2_score of LinearRegression  0.36138400597734466 at random_state  154
# R2 score of lr  48.31077623458917 at random_state  48
# R2_score of LinearRegression  0.25780823564801125 at random_state  155
# R2 score of lr  48.31077623458917 at random_state  48
# R2_score of LinearRegression  0.46155474002609487 at random_state  156
# R2 score of lr  48.31077623458917 at random_state  48
# R2_score of LinearRegression  0.36653686768521676 at random_state  157
# R2 score of lr  48.31077623458917 at random_state  48
# R2_score of LinearRegression  0.4227278245894698 at random_state  158
# R2 score of lr  48.31077623458917 at random_state  48
# R2_score of LinearRegression  0.3642370603630638 at random_state  159
# R2 score of lr  48.31077623458917 at random_state  48
# R2_score of LinearRegression  0.4187231285254125 at random_state  160
# R2 score of lr  48.31077623458917 at random_state  48
# R2_score of LinearRegression  0.369684111812536 at random_state  161
# R2 score of lr  48.31077623458917 at random_state  48
# R2_score of LinearRegression  0.3817479420193133 at random_state  162
# R2 score of lr  48.31077623458917 at random_state  48
# R2_score of LinearRegression  0.35763812309495846 at random_state  163
# R2 score of lr  48.31077623458917 at random_state  48
# R2_score of LinearRegression  0.40516675320516127 at random_state  164
# R2 score of lr  48.31077623458917 at random_state  48
# R2_score of LinearRegression  0.4453825550291439 at random_state  165
# R2 score of lr  48.31077623458917 at random_state  48
# R2_score of LinearRegression  0.4184899585872479 at random_state  166
# R2 score of lr  48.31077623458917 at random_state  48
# R2_score of LinearRegression  0.4057816060094954 at random_state  167
# R2 score of lr  48.31077623458917 at random_state  48
# R2_score of LinearRegression  0.35632130096124326 at random_state  168
# R2 score of lr  48.31077623458917 at random_state  48
# R2_score of LinearRegression  0.4118475312403229 at random_state  169
# R2 score of lr  48.31077623458917 at random_state  48
# R2_score of LinearRegression  0.4039324012855008 at random_state  170
# R2 score of lr  48.31077623458917 at random_state  48
# R2_score of LinearRegression  0.3650545323736818 at random_state  171
# R2 score of lr  48.31077623458917 at random_state  48
# R2_score of LinearRegression  0.40173362130206425 at random_state  172
# R2 score of lr  48.31077623458917 at random_state  48
# R2_score of LinearRegression  0.40528317255388047 at random_state  173
# R2 score of lr  48.31077623458917 at random_state  48
# R2_score of LinearRegression  0.4139311262477806 at random_state  174
# R2 score of lr  48.31077623458917 at random_state  48
# R2_score of LinearRegression  0.3655848889767661 at random_state  175
# R2 score of lr  48.31077623458917 at random_state  48
# R2_score of LinearRegression  0.399367532033053 at random_state  176
# R2 score of lr  48.31077623458917 at random_state  48
# R2_score of LinearRegression  0.45260672958004744 at random_state  177
# R2 score of lr  48.31077623458917 at random_state  48
# R2_score of LinearRegression  0.2946063157824904 at random_state  178
# R2 score of lr  48.31077623458917 at random_state  48
# R2_score of LinearRegression  0.4433533527739496 at random_state  179
# R2 score of lr  48.31077623458917 at random_state  48
# R2_score of LinearRegression  0.4334724606340351 at random_state  180
# R2 score of lr  48.31077623458917 at random_state  48
# R2_score of LinearRegression  0.3960845634703716 at random_state  181
# R2 score of lr  48.31077623458917 at random_state  48
# R2_score of LinearRegression  0.32467841537799147 at random_state  182
# R2 score of lr  48.31077623458917 at random_state  48
# R2_score of LinearRegression  0.40597865347536544 at random_state  183
# R2 score of lr  48.31077623458917 at random_state  48
# R2_score of LinearRegression  0.3709401603106405 at random_state  184
# R2 score of lr  48.31077623458917 at random_state  48
# R2_score of LinearRegression  0.36210553270944257 at random_state  185
# R2 score of lr  48.31077623458917 at random_state  48
# R2_score of LinearRegression  0.3748979195633735 at random_state  186
# R2 score of lr  48.31077623458917 at random_state  48
# R2_score of LinearRegression  0.3965765111064039 at random_state  187
# R2 score of lr  48.31077623458917 at random_state  48
# R2_score of LinearRegression  0.44121285834819124 at random_state  188
# R2 score of lr  48.31077623458917 at random_state  48
# R2_score of LinearRegression  0.3580752183420176 at random_state  189
# R2 score of lr  48.31077623458917 at random_state  48
# R2_score of LinearRegression  0.4003487667132206 at random_state  190
# R2 score of lr  48.31077623458917 at random_state  48
# R2_score of LinearRegression  0.42546659729011416 at random_state  191
# R2 score of lr  48.31077623458917 at random_state  48
# R2_score of LinearRegression  0.36110508106846906 at random_state  192
# R2 score of lr  48.31077623458917 at random_state  48
# R2_score of LinearRegression  0.33293178780316324 at random_state  193
# R2 score of lr  48.31077623458917 at random_state  48
# R2_score of LinearRegression  0.39257626070331975 at random_state  194
# R2 score of lr  48.31077623458917 at random_state  48
# R2_score of LinearRegression  0.4181515280028668 at random_state  195
# R2 score of lr  48.31077623458917 at random_state  48
# R2_score of LinearRegression  0.35361834755846144 at random_state  196
# R2 score of lr  48.31077623458917 at random_state  48
# R2_score of LinearRegression  0.3819226961466947 at random_state  197
# R2 score of lr  48.31077623458917 at random_state  48
# R2_score of LinearRegression  0.4390867682507883 at random_state  198
# R2 score of lr  48.31077623458917 at random_state  48
# R2_score of LinearRegression  0.44544266853292136 at random_state  199
# R2 score of lr  48.31077623458917 at random_state  48
# R2_score of LinearRegression  0.3882007740689275 at random_state  200
# R2 score of lr  48.31077623458917 at random_state  48
# R2_score of LinearRegression  0.38463804916586275 at random_state  201
# R2 score of lr  48.31077623458917 at random_state  48
# R2_score of LinearRegression  0.4036290540624222 at random_state  202
# R2 score of lr  48.31077623458917 at random_state  48
# R2_score of LinearRegression  0.3864891773727296 at random_state  203
# R2 score of lr  48.31077623458917 at random_state  48
# R2_score of LinearRegression  0.3868245647219827 at random_state  204
# R2 score of lr  48.31077623458917 at random_state  48
# R2_score of LinearRegression  0.4191902955295801 at random_state  205
# R2 score of lr  48.31077623458917 at random_state  48
# R2_score of LinearRegression  0.40095057914606835 at random_state  206
# R2 score of lr  48.31077623458917 at random_state  48
# R2_score of LinearRegression  0.40750360451185563 at random_state  207
# R2 score of lr  48.31077623458917 at random_state  48
# R2_score of LinearRegression  0.3801399344625469 at random_state  208
# R2 score of lr  48.31077623458917 at random_state  48
# R2_score of LinearRegression  0.47101410686224576 at random_state  209
# R2 score of lr  48.31077623458917 at random_state  48
# R2_score of LinearRegression  0.4130051715280846 at random_state  210
# R2 score of lr  48.31077623458917 at random_state  48
# R2_score of LinearRegression  0.42998775496449637 at random_state  211
# R2 score of lr  48.31077623458917 at random_state  48
# R2_score of LinearRegression  0.38763424147410164 at random_state  212
# R2 score of lr  48.31077623458917 at random_state  48
# R2_score of LinearRegression  0.35346904210326946 at random_state  213
# R2 score of lr  48.31077623458917 at random_state  48
# R2_score of LinearRegression  0.41298593240102177 at random_state  214
# R2 score of lr  48.31077623458917 at random_state  48
# R2_score of LinearRegression  0.41605017159967705 at random_state  215
# R2 score of lr  48.31077623458917 at random_state  48
# R2_score of LinearRegression  0.3430631086475828 at random_state  216
# R2 score of lr  48.31077623458917 at random_state  48
# R2_score of LinearRegression  0.3985751505116957 at random_state  217
# R2 score of lr  48.31077623458917 at random_state  48
# R2_score of LinearRegression  0.32301951335374757 at random_state  218
# R2 score of lr  48.31077623458917 at random_state  48
# R2_score of LinearRegression  0.3365631355083938 at random_state  219
# R2 score of lr  48.31077623458917 at random_state  48
# R2_score of LinearRegression  0.426279891111058 at random_state  220
# R2 score of lr  48.31077623458917 at random_state  48
# R2_score of LinearRegression  0.38552114406876437 at random_state  221
# R2 score of lr  48.31077623458917 at random_state  48
# R2_score of LinearRegression  0.3435121477541061 at random_state  222
# R2 score of lr  48.31077623458917 at random_state  48
# R2_score of LinearRegression  0.45643016155877014 at random_state  223
# R2 score of lr  48.31077623458917 at random_state  48
# R2_score of LinearRegression  0.42715748560463207 at random_state  224
# R2 score of lr  48.31077623458917 at random_state  48
# R2_score of LinearRegression  0.39151297932967233 at random_state  225
# R2 score of lr  48.31077623458917 at random_state  48
# R2_score of LinearRegression  0.3969022280433089 at random_state  226
# R2 score of lr  48.31077623458917 at random_state  48
# R2_score of LinearRegression  0.3658238515075998 at random_state  227
# R2 score of lr  48.31077623458917 at random_state  48
# R2_score of LinearRegression  0.42637177029647944 at random_state  228
# R2 score of lr  48.31077623458917 at random_state  48
# R2_score of LinearRegression  0.3943296457780905 at random_state  229
# R2 score of lr  48.31077623458917 at random_state  48
# R2_score of LinearRegression  0.40892832494826914 at random_state  230
# R2 score of lr  48.31077623458917 at random_state  48
# R2_score of LinearRegression  0.43135445634756553 at random_state  231
# R2 score of lr  48.31077623458917 at random_state  48
# R2_score of LinearRegression  0.3627075426537737 at random_state  232
# R2 score of lr  48.31077623458917 at random_state  48
# R2_score of LinearRegression  0.436795182555069 at random_state  233
# R2 score of lr  48.31077623458917 at random_state  48
# R2_score of LinearRegression  0.38629527548943643 at random_state  234
# R2 score of lr  48.31077623458917 at random_state  48
# R2_score of LinearRegression  0.3858803049557944 at random_state  235
# R2 score of lr  48.31077623458917 at random_state  48
# R2_score of LinearRegression  0.4107433252887642 at random_state  236
# R2 score of lr  48.31077623458917 at random_state  48
# R2_score of LinearRegression  0.35681494707996053 at random_state  237
# R2 score of lr  48.31077623458917 at random_state  48
# R2_score of LinearRegression  0.37736254079341625 at random_state  238
# R2 score of lr  48.31077623458917 at random_state  48
# R2_score of LinearRegression  0.35468885777222703 at random_state  239
# R2 score of lr  48.31077623458917 at random_state  48
# R2_score of LinearRegression  0.42012031616931067 at random_state  240
# R2 score of lr  48.31077623458917 at random_state  48
# R2_score of LinearRegression  0.3316846174563213 at random_state  241
# R2 score of lr  48.31077623458917 at random_state  48
# R2_score of LinearRegression  0.3628882259626567 at random_state  242
# R2 score of lr  48.31077623458917 at random_state  48
# R2_score of LinearRegression  0.3814925500549964 at random_state  243
# R2 score of lr  48.31077623458917 at random_state  48
# R2_score of LinearRegression  0.3833472550947272 at random_state  244
# R2 score of lr  48.31077623458917 at random_state  48
# R2_score of LinearRegression  0.36765325058219334 at random_state  245
# R2 score of lr  48.31077623458917 at random_state  48
# R2_score of LinearRegression  0.38240463024390237 at random_state  246
# R2 score of lr  48.31077623458917 at random_state  48
# R2_score of LinearRegression  0.31354111659612394 at random_state  247
# R2 score of lr  48.31077623458917 at random_state  48
# R2_score of LinearRegression  0.3867467834948707 at random_state  248
# R2 score of lr  48.31077623458917 at random_state  48
# R2_score of LinearRegression  0.37625193326431683 at random_state  249
# R2 score of lr  48.31077623458917 at random_state  48
# R2_score of LinearRegression  0.3263109401503991 at random_state  250
# R2 score of lr  48.31077623458917 at random_state  48
# R2_score of LinearRegression  0.3916050964567631 at random_state  251
# R2 score of lr  48.31077623458917 at random_state  48
# R2_score of LinearRegression  0.38995466086036357 at random_state  252
# R2 score of lr  48.31077623458917 at random_state  48
# R2_score of LinearRegression  0.3854554017509947 at random_state  253
# R2 score of lr  48.31077623458917 at random_state  48
# R2_score of LinearRegression  0.2682836312364959 at random_state  254
# R2 score of lr  48.31077623458917 at random_state  48
# R2_score of LinearRegression  0.42088124210177247 at random_state  255
# R2 score of lr  48.31077623458917 at random_state  48
# R2_score of LinearRegression  0.37155026668622215 at random_state  256
# R2 score of lr  48.31077623458917 at random_state  48
# R2_score of LinearRegression  0.3734169595504222 at random_state  257
# R2 score of lr  48.31077623458917 at random_state  48
# R2_score of LinearRegression  0.38651758810326486 at random_state  258
# R2 score of lr  48.31077623458917 at random_state  48
# R2_score of LinearRegression  0.42126394734971706 at random_state  259
# R2 score of lr  48.31077623458917 at random_state  48
# R2_score of LinearRegression  0.42717086864960097 at random_state  260
# R2 score of lr  48.31077623458917 at random_state  48
# R2_score of LinearRegression  0.441255870612722 at random_state  261
# R2 score of lr  48.31077623458917 at random_state  48
# R2_score of LinearRegression  0.3801345355333975 at random_state  262
# R2 score of lr  48.31077623458917 at random_state  48
# R2_score of LinearRegression  0.3847384221415626 at random_state  263
# R2 score of lr  48.31077623458917 at random_state  48
# R2_score of LinearRegression  0.3700356107028937 at random_state  264
# R2 score of lr  48.31077623458917 at random_state  48
# R2_score of LinearRegression  0.3906296240150017 at random_state  265
# R2 score of lr  48.31077623458917 at random_state  48
# R2_score of LinearRegression  0.3876175443306965 at random_state  266
# R2 score of lr  48.31077623458917 at random_state  48
# R2_score of LinearRegression  0.3450358031085925 at random_state  267
# R2 score of lr  48.31077623458917 at random_state  48
# R2_score of LinearRegression  0.31777520226597555 at random_state  268
# R2 score of lr  48.31077623458917 at random_state  48
# R2_score of LinearRegression  0.3860843676439307 at random_state  269
# R2 score of lr  48.31077623458917 at random_state  48
# R2_score of LinearRegression  0.37172403214094374 at random_state  270
# R2 score of lr  48.31077623458917 at random_state  48
# R2_score of LinearRegression  0.4024581655871975 at random_state  271
# R2 score of lr  48.31077623458917 at random_state  48
# R2_score of LinearRegression  0.33975207729180956 at random_state  272
# R2 score of lr  48.31077623458917 at random_state  48
# R2_score of LinearRegression  0.4102614994087086 at random_state  273
# R2 score of lr  48.31077623458917 at random_state  48
# R2_score of LinearRegression  0.35790730337429877 at random_state  274
# R2 score of lr  48.31077623458917 at random_state  48
# R2_score of LinearRegression  0.32934274995106916 at random_state  275
# R2 score of lr  48.31077623458917 at random_state  48
# R2_score of LinearRegression  0.36169832996957774 at random_state  276
# R2 score of lr  48.31077623458917 at random_state  48
# R2_score of LinearRegression  0.36057185581136586 at random_state  277
# R2 score of lr  48.31077623458917 at random_state  48
# R2_score of LinearRegression  0.2942331161418936 at random_state  278
# R2 score of lr  48.31077623458917 at random_state  48
# R2_score of LinearRegression  0.43597612637828076 at random_state  279
# R2 score of lr  48.31077623458917 at random_state  48
# R2_score of LinearRegression  0.4141162043373424 at random_state  280
# R2 score of lr  48.31077623458917 at random_state  48
# R2_score of LinearRegression  0.4155965260158898 at random_state  281
# R2 score of lr  48.31077623458917 at random_state  48
# R2_score of LinearRegression  0.4172735095135298 at random_state  282
# R2 score of lr  48.31077623458917 at random_state  48
# R2_score of LinearRegression  0.36290551976248686 at random_state  283
# R2 score of lr  48.31077623458917 at random_state  48
# R2_score of LinearRegression  0.3183987822955997 at random_state  284
# R2 score of lr  48.31077623458917 at random_state  48
# R2_score of LinearRegression  0.3941115113418572 at random_state  285
# R2 score of lr  48.31077623458917 at random_state  48
# R2_score of LinearRegression  0.424296370204328 at random_state  286
# R2 score of lr  48.31077623458917 at random_state  48
# R2_score of LinearRegression  0.40906056694555415 at random_state  287
# R2 score of lr  48.31077623458917 at random_state  48
# R2_score of LinearRegression  0.39534019389595054 at random_state  288
# R2 score of lr  48.31077623458917 at random_state  48
# R2_score of LinearRegression  0.4305925061862398 at random_state  289
# R2 score of lr  48.31077623458917 at random_state  48
# R2_score of LinearRegression  0.42546374391783326 at random_state  290
# R2 score of lr  48.31077623458917 at random_state  48
# R2_score of LinearRegression  0.3944870040463111 at random_state  291
# R2 score of lr  48.31077623458917 at random_state  48
# R2_score of LinearRegression  0.3939312798268486 at random_state  292
# R2 score of lr  48.31077623458917 at random_state  48
# R2_score of LinearRegression  0.42045726593583366 at random_state  293
# R2 score of lr  48.31077623458917 at random_state  48
# R2_score of LinearRegression  0.41506315002120997 at random_state  294
# R2 score of lr  48.31077623458917 at random_state  48
# R2_score of LinearRegression  0.36364783495726394 at random_state  295
# R2 score of lr  48.31077623458917 at random_state  48
# R2_score of LinearRegression  0.36679196260104685 at random_state  296
# R2 score of lr  48.31077623458917 at random_state  48
# R2_score of LinearRegression  0.35517916966545915 at random_state  297
# R2 score of lr  48.31077623458917 at random_state  48
# R2_score of LinearRegression  0.40750164952601164 at random_state  298
# R2 score of lr  48.31077623458917 at random_state  48
# R2_score of LinearRegression  0.3154252271139133 at random_state  299
# R2 score of lr  48.31077623458917 at random_state  48
# R2_score of LinearRegression  0.345697821965795 at random_state  300
# R2 score of lr  48.31077623458917 at random_state  48
# R2_score of LinearRegression  0.4446465079604849 at random_state  301
# R2 score of lr  48.31077623458917 at random_state  48
# R2_score of LinearRegression  0.4655255623447635 at random_state  302
# R2 score of lr  48.31077623458917 at random_state  48
# R2_score of LinearRegression  0.39548941848786645 at random_state  303
# R2 score of lr  48.31077623458917 at random_state  48
# R2_score of LinearRegression  0.4044460435079479 at random_state  304
# R2 score of lr  48.31077623458917 at random_state  48
# R2_score of LinearRegression  0.39056725690577476 at random_state  305
# R2 score of lr  48.31077623458917 at random_state  48
# R2_score of LinearRegression  0.42839043664096876 at random_state  306
# R2 score of lr  48.31077623458917 at random_state  48
# R2_score of LinearRegression  0.41604020152778665 at random_state  307
# R2 score of lr  48.31077623458917 at random_state  48
# R2_score of LinearRegression  0.42199338555103605 at random_state  308
# R2 score of lr  48.31077623458917 at random_state  48
# R2_score of LinearRegression  0.3829338584792342 at random_state  309
# R2 score of lr  48.31077623458917 at random_state  48
# R2_score of LinearRegression  0.3497168509405272 at random_state  310
# R2 score of lr  48.31077623458917 at random_state  48
# R2_score of LinearRegression  0.4108549961485427 at random_state  311
# R2 score of lr  48.31077623458917 at random_state  48
# R2_score of LinearRegression  0.4634530211817386 at random_state  312
# R2 score of lr  48.31077623458917 at random_state  48
# R2_score of LinearRegression  0.3798067551181228 at random_state  313
# R2 score of lr  48.31077623458917 at random_state  48
# R2_score of LinearRegression  0.3785525838974019 at random_state  314
# R2 score of lr  48.31077623458917 at random_state  48
# R2_score of LinearRegression  0.4460460392918377 at random_state  315
# R2 score of lr  48.31077623458917 at random_state  48
# R2_score of LinearRegression  0.42763912650251357 at random_state  316
# R2 score of lr  48.31077623458917 at random_state  48
# R2_score of LinearRegression  0.38245460071608695 at random_state  317
# R2 score of lr  48.31077623458917 at random_state  48
# R2_score of LinearRegression  0.3708661448695991 at random_state  318
# R2 score of lr  48.31077623458917 at random_state  48
# R2_score of LinearRegression  0.48842148985404943 at random_state  319
# R2 score of lr  48.84214898540494 at random_state  319
# R2_score of LinearRegression  0.3234957193428736 at random_state  320
# R2 score of lr  48.84214898540494 at random_state  319
# R2_score of LinearRegression  0.4272714952773896 at random_state  321
# R2 score of lr  48.84214898540494 at random_state  319
# R2_score of LinearRegression  0.42569312770058443 at random_state  322
# R2 score of lr  48.84214898540494 at random_state  319
# R2_score of LinearRegression  0.3783034986633521 at random_state  323
# R2 score of lr  48.84214898540494 at random_state  319
# R2_score of LinearRegression  0.4054260862302843 at random_state  324
# R2 score of lr  48.84214898540494 at random_state  319
# R2_score of LinearRegression  0.46328673820544897 at random_state  325
# R2 score of lr  48.84214898540494 at random_state  319
# R2_score of LinearRegression  0.3177553463633259 at random_state  326
# R2 score of lr  48.84214898540494 at random_state  319
# R2_score of LinearRegression  0.4324867298915446 at random_state  327
# R2 score of lr  48.84214898540494 at random_state  319
# R2_score of LinearRegression  0.38879268964713076 at random_state  328
# R2 score of lr  48.84214898540494 at random_state  319
# R2_score of LinearRegression  0.3867260817579048 at random_state  329
# R2 score of lr  48.84214898540494 at random_state  319
# R2_score of LinearRegression  0.35425765117545716 at random_state  330
# R2 score of lr  48.84214898540494 at random_state  319
# R2_score of LinearRegression  0.3914381288525923 at random_state  331
# R2 score of lr  48.84214898540494 at random_state  319
# R2_score of LinearRegression  0.41027385900792224 at random_state  332
# R2 score of lr  48.84214898540494 at random_state  319
# R2_score of LinearRegression  0.40267284719329544 at random_state  333
# R2 score of lr  48.84214898540494 at random_state  319
# R2_score of LinearRegression  0.38959722798612695 at random_state  334
# R2 score of lr  48.84214898540494 at random_state  319
# R2_score of LinearRegression  0.4266730089720514 at random_state  335
# R2 score of lr  48.84214898540494 at random_state  319
# R2_score of LinearRegression  0.3028554574505766 at random_state  336
# R2 score of lr  48.84214898540494 at random_state  319
# R2_score of LinearRegression  0.3395706014393466 at random_state  337
# R2 score of lr  48.84214898540494 at random_state  319
# R2_score of LinearRegression  0.4056429054042494 at random_state  338
# R2 score of lr  48.84214898540494 at random_state  319
# R2_score of LinearRegression  0.4128052584615681 at random_state  339
# R2 score of lr  48.84214898540494 at random_state  319
# R2_score of LinearRegression  0.3878405440911048 at random_state  340
# R2 score of lr  48.84214898540494 at random_state  319
# R2_score of LinearRegression  0.45390079050153254 at random_state  341
# R2 score of lr  48.84214898540494 at random_state  319
# R2_score of LinearRegression  0.3865441947544821 at random_state  342
# R2 score of lr  48.84214898540494 at random_state  319
# R2_score of LinearRegression  0.3558435269088469 at random_state  343
# R2 score of lr  48.84214898540494 at random_state  319
# R2_score of LinearRegression  0.46074099579216965 at random_state  344
# R2 score of lr  48.84214898540494 at random_state  319
# R2_score of LinearRegression  0.4402585459719506 at random_state  345
# R2 score of lr  48.84214898540494 at random_state  319
# R2_score of LinearRegression  0.4081861710100335 at random_state  346
# R2 score of lr  48.84214898540494 at random_state  319
# R2_score of LinearRegression  0.41162065094513045 at random_state  347
# R2 score of lr  48.84214898540494 at random_state  319
# R2_score of LinearRegression  0.4140862226854365 at random_state  348
# R2 score of lr  48.84214898540494 at random_state  319
# R2_score of LinearRegression  0.39184512616011524 at random_state  349
# R2 score of lr  48.84214898540494 at random_state  319
# R2_score of LinearRegression  0.29534143149933034 at random_state  350
# R2 score of lr  48.84214898540494 at random_state  319
# R2_score of LinearRegression  0.3907257580161303 at random_state  351
# R2 score of lr  48.84214898540494 at random_state  319
# R2_score of LinearRegression  0.38040895537103014 at random_state  352
# R2 score of lr  48.84214898540494 at random_state  319
# R2_score of LinearRegression  0.4705845040151364 at random_state  353
# R2 score of lr  48.84214898540494 at random_state  319
# R2_score of LinearRegression  0.4176475205816268 at random_state  354
# R2 score of lr  48.84214898540494 at random_state  319
# R2_score of LinearRegression  0.4267649920872637 at random_state  355
# R2 score of lr  48.84214898540494 at random_state  319
# R2_score of LinearRegression  0.4042043746239006 at random_state  356
# R2 score of lr  48.84214898540494 at random_state  319
# R2_score of LinearRegression  0.41731171594176997 at random_state  357
# R2 score of lr  48.84214898540494 at random_state  319
# R2_score of LinearRegression  0.4375135087397022 at random_state  358
# R2 score of lr  48.84214898540494 at random_state  319
# R2_score of LinearRegression  0.35777354176747767 at random_state  359
# R2 score of lr  48.84214898540494 at random_state  319
# R2_score of LinearRegression  0.40267689112437854 at random_state  360
# R2 score of lr  48.84214898540494 at random_state  319
# R2_score of LinearRegression  0.34875756259628854 at random_state  361
# R2 score of lr  48.84214898540494 at random_state  319
# R2_score of LinearRegression  0.3972453203686285 at random_state  362
# R2 score of lr  48.84214898540494 at random_state  319
# R2_score of LinearRegression  0.4179197985060439 at random_state  363
# R2 score of lr  48.84214898540494 at random_state  319
# R2_score of LinearRegression  0.37736619154840023 at random_state  364
# R2 score of lr  48.84214898540494 at random_state  319
# R2_score of LinearRegression  0.34784058556577757 at random_state  365
# R2 score of lr  48.84214898540494 at random_state  319
# R2_score of LinearRegression  0.3534441357655781 at random_state  366
# R2 score of lr  48.84214898540494 at random_state  319
# R2_score of LinearRegression  0.3547583443074609 at random_state  367
# R2 score of lr  48.84214898540494 at random_state  319
# R2_score of LinearRegression  0.40807526092452284 at random_state  368
# R2 score of lr  48.84214898540494 at random_state  319
# R2_score of LinearRegression  0.4197647437088359 at random_state  369
# R2 score of lr  48.84214898540494 at random_state  319
# R2_score of LinearRegression  0.37298528454074587 at random_state  370
# R2 score of lr  48.84214898540494 at random_state  319
# R2_score of LinearRegression  0.376942945569923 at random_state  371
# R2 score of lr  48.84214898540494 at random_state  319
# R2_score of LinearRegression  0.396156473407985 at random_state  372
# R2 score of lr  48.84214898540494 at random_state  319
# R2_score of LinearRegression  0.4227140961333615 at random_state  373
# R2 score of lr  48.84214898540494 at random_state  319
# R2_score of LinearRegression  0.346388520918508 at random_state  374
# R2 score of lr  48.84214898540494 at random_state  319
# R2_score of LinearRegression  0.42349403251466267 at random_state  375
# R2 score of lr  48.84214898540494 at random_state  319
# R2_score of LinearRegression  0.38416114387180034 at random_state  376
# R2 score of lr  48.84214898540494 at random_state  319
# R2_score of LinearRegression  0.377347299545468 at random_state  377
# R2 score of lr  48.84214898540494 at random_state  319
# R2_score of LinearRegression  0.40674556661519845 at random_state  378
# R2 score of lr  48.84214898540494 at random_state  319
# R2_score of LinearRegression  0.3709406426968357 at random_state  379
# R2 score of lr  48.84214898540494 at random_state  319
# R2_score of LinearRegression  0.3361275268463716 at random_state  380
# R2 score of lr  48.84214898540494 at random_state  319
# R2_score of LinearRegression  0.3636990896785618 at random_state  381
# R2 score of lr  48.84214898540494 at random_state  319
# R2_score of LinearRegression  0.3478049834718564 at random_state  382
# R2 score of lr  48.84214898540494 at random_state  319
# R2_score of LinearRegression  0.44754421186402427 at random_state  383
# R2 score of lr  48.84214898540494 at random_state  319
# R2_score of LinearRegression  0.43029172603755883 at random_state  384
# R2 score of lr  48.84214898540494 at random_state  319
# R2_score of LinearRegression  0.40497526108873905 at random_state  385
# R2 score of lr  48.84214898540494 at random_state  319
# R2_score of LinearRegression  0.3899683859836268 at random_state  386
# ...
# R2 score of lr  49.34092285544898 at random_state  797
# R2_score of LinearRegression  0.39220479415646614 at random_state  873
# R2 score of lr  49.34092285544898 at random_state  797
# R2_score of LinearRegression  0.29125871544770865 at random_state  874
# R2 score of lr  49.34092285544898 at random_state  797
# R2_score of LinearRegression  0.37762729215857427 at random_state  875
# R2 score of lr  49.34092285544898 at random_state  797
# R2_score of LinearRegression  0.3836831537935049 at random_state  876
# R2 score of lr  49.34092285544898 at random_state  797
# R2_score of LinearRegression  0.3969031957225916 at random_state  877
# R2 score of lr  49.34092285544898 at random_state  797
# R2_score of LinearRegression  0.43539805636470985 at random_state  878
# R2 score of lr  49.34092285544898 at random_state  797
# R2_score of LinearRegression  0.32404128287515266 at random_state  879
# R2 score of lr  49.34092285544898 at random_state  797
# R2_score of LinearRegression  0.36697682718226854 at random_state  880
# R2 score of lr  49.34092285544898 at random_state  797
# R2_score of LinearRegression  0.35592490001371835 at random_state  881
# R2 score of lr  49.34092285544898 at random_state  797
# R2_score of LinearRegression  0.3553112097732066 at random_state  882
# R2 score of lr  49.34092285544898 at random_state  797
# R2_score of LinearRegression  0.3568499488821556 at random_state  883
# R2 score of lr  49.34092285544898 at random_state  797
# R2_score of LinearRegression  0.4428464843694745 at random_state  884
# R2 score of lr  49.34092285544898 at random_state  797
# R2_score of LinearRegression  0.3924725183275012 at random_state  885
# R2 score of lr  49.34092285544898 at random_state  797
# R2_score of LinearRegression  0.36394222681958444 at random_state  886
# R2 score of lr  49.34092285544898 at random_state  797
# R2_score of LinearRegression  0.3833063852326368 at random_state  887
# R2 score of lr  49.34092285544898 at random_state  797
# R2_score of LinearRegression  0.34934506130650367 at random_state  888
# R2 score of lr  49.34092285544898 at random_state  797
# R2_score of LinearRegression  0.3629798431530551 at random_state  889
# R2 score of lr  49.34092285544898 at random_state  797
# R2_score of LinearRegression  0.38319127351009463 at random_state  890
# R2 score of lr  49.34092285544898 at random_state  797
# R2_score of LinearRegression  0.3261069063935442 at random_state  891
# R2 score of lr  49.34092285544898 at random_state  797
# R2_score of LinearRegression  0.41504785613500284 at random_state  892
# R2 score of lr  49.34092285544898 at random_state  797
# R2_score of LinearRegression  0.3438744628812651 at random_state  893
# R2 score of lr  49.34092285544898 at random_state  797
# R2_score of LinearRegression  0.4257620110142667 at random_state  894
# R2 score of lr  49.34092285544898 at random_state  797
# R2_score of LinearRegression  0.43128671707515365 at random_state  895
# R2 score of lr  49.34092285544898 at random_state  797
# R2_score of LinearRegression  0.4277943717394107 at random_state  896
# R2 score of lr  49.34092285544898 at random_state  797
# R2_score of LinearRegression  0.4228427652235418 at random_state  897
# R2 score of lr  49.34092285544898 at random_state  797
# R2_score of LinearRegression  0.36626786827935975 at random_state  898
# R2 score of lr  49.34092285544898 at random_state  797
# R2_score of LinearRegression  0.38253722721766326 at random_state  899
# R2 score of lr  49.34092285544898 at random_state  797
# R2_score of LinearRegression  0.401551095748498 at random_state  900
# R2 score of lr  49.34092285544898 at random_state  797
# R2_score of LinearRegression  0.40628002819649334 at random_state  901
# R2 score of lr  49.34092285544898 at random_state  797
# R2_score of LinearRegression  0.4300667379360631 at random_state  902
# R2 score of lr  49.34092285544898 at random_state  797
# R2_score of LinearRegression  0.39613605375773886 at random_state  903
# R2 score of lr  49.34092285544898 at random_state  797
# R2_score of LinearRegression  0.3332746144693154 at random_state  904
# R2 score of lr  49.34092285544898 at random_state  797
# R2_score of LinearRegression  0.3222346962310012 at random_state  905
# R2 score of lr  49.34092285544898 at random_state  797
# R2_score of LinearRegression  0.3791367656900928 at random_state  906
# R2 score of lr  49.34092285544898 at random_state  797
# R2_score of LinearRegression  0.3960499223463926 at random_state  907
# R2 score of lr  49.34092285544898 at random_state  797
# R2_score of LinearRegression  0.46677488640630826 at random_state  908
# R2 score of lr  49.34092285544898 at random_state  797
# R2_score of LinearRegression  0.3539463889521035 at random_state  909
# R2 score of lr  49.34092285544898 at random_state  797
# R2_score of LinearRegression  0.4121934670432369 at random_state  910
# R2 score of lr  49.34092285544898 at random_state  797
# R2_score of LinearRegression  0.38879340305492616 at random_state  911
# R2 score of lr  49.34092285544898 at random_state  797
# R2_score of LinearRegression  0.4079577879824584 at random_state  912
# R2 score of lr  49.34092285544898 at random_state  797
# R2_score of LinearRegression  0.33537533780465933 at random_state  913
# R2 score of lr  49.34092285544898 at random_state  797
# R2_score of LinearRegression  0.34640376113737403 at random_state  914
# R2 score of lr  49.34092285544898 at random_state  797
# R2_score of LinearRegression  0.37839040690064407 at random_state  915
# R2 score of lr  49.34092285544898 at random_state  797
# R2_score of LinearRegression  0.3367770533335632 at random_state  916
# R2 score of lr  49.34092285544898 at random_state  797
# R2_score of LinearRegression  0.4270674279182184 at random_state  917
# R2 score of lr  49.34092285544898 at random_state  797
# R2_score of LinearRegression  0.3927304774652913 at random_state  918
# R2 score of lr  49.34092285544898 at random_state  797
# R2_score of LinearRegression  0.3938051917197397 at random_state  919
# R2 score of lr  49.34092285544898 at random_state  797
# R2_score of LinearRegression  0.37746758390954827 at random_state  920
# R2 score of lr  49.34092285544898 at random_state  797
# R2_score of LinearRegression  0.3771163623971088 at random_state  921
# R2 score of lr  49.34092285544898 at random_state  797
# R2_score of LinearRegression  0.39863422567399054 at random_state  922
# R2 score of lr  49.34092285544898 at random_state  797
# R2_score of LinearRegression  0.4069327576866968 at random_state  923
# R2 score of lr  49.34092285544898 at random_state  797
# R2_score of LinearRegression  0.39260909639400576 at random_state  924
# R2 score of lr  49.34092285544898 at random_state  797
# R2_score of LinearRegression  0.3087599876500656 at random_state  925
# R2 score of lr  49.34092285544898 at random_state  797
# R2_score of LinearRegression  0.3781559731845938 at random_state  926
# R2 score of lr  49.34092285544898 at random_state  797
# R2_score of LinearRegression  0.3963485752652336 at random_state  927
# R2 score of lr  49.34092285544898 at random_state  797
# R2_score of LinearRegression  0.42326038885106354 at random_state  928
# R2 score of lr  49.34092285544898 at random_state  797
# R2_score of LinearRegression  0.41794898078952936 at random_state  929
# R2 score of lr  49.34092285544898 at random_state  797
# R2_score of LinearRegression  0.4665164107711369 at random_state  930
# R2 score of lr  49.34092285544898 at random_state  797
# R2_score of LinearRegression  0.34249524237621354 at random_state  931
# R2 score of lr  49.34092285544898 at random_state  797
# R2_score of LinearRegression  0.22669359931455124 at random_state  932
# R2 score of lr  49.34092285544898 at random_state  797
# R2_score of LinearRegression  0.42108917020852776 at random_state  933
# R2 score of lr  49.34092285544898 at random_state  797
# R2_score of LinearRegression  0.3218510194988794 at random_state  934
# R2 score of lr  49.34092285544898 at random_state  797
# R2_score of LinearRegression  0.2785006220324495 at random_state  935
# R2 score of lr  49.34092285544898 at random_state  797
# R2_score of LinearRegression  0.3165306491126194 at random_state  936
# R2 score of lr  49.34092285544898 at random_state  797
# R2_score of LinearRegression  0.3494623739976168 at random_state  937
# R2 score of lr  49.34092285544898 at random_state  797
# R2_score of LinearRegression  0.32724909256192625 at random_state  938
# R2 score of lr  49.34092285544898 at random_state  797
# R2_score of LinearRegression  0.38545836886616813 at random_state  939
# R2 score of lr  49.34092285544898 at random_state  797
# R2_score of LinearRegression  0.42092822307665 at random_state  940
# R2 score of lr  49.34092285544898 at random_state  797
# R2_score of LinearRegression  0.38015675005175964 at random_state  941
# R2 score of lr  49.34092285544898 at random_state  797
# R2_score of LinearRegression  0.3803655727055495 at random_state  942
# R2 score of lr  49.34092285544898 at random_state  797
# R2_score of LinearRegression  0.3896152211570355 at random_state  943
# R2 score of lr  49.34092285544898 at random_state  797
# R2_score of LinearRegression  0.3638926666920985 at random_state  944
# R2 score of lr  49.34092285544898 at random_state  797
# R2_score of LinearRegression  0.40565427179451397 at random_state  945
# R2 score of lr  49.34092285544898 at random_state  797
# R2_score of LinearRegression  0.41091260226488946 at random_state  946
# R2 score of lr  49.34092285544898 at random_state  797
# R2_score of LinearRegression  0.3838112805282796 at random_state  947
# R2 score of lr  49.34092285544898 at random_state  797
# R2_score of LinearRegression  0.38688125848323407 at random_state  948
# R2 score of lr  49.34092285544898 at random_state  797
# R2_score of LinearRegression  0.3793657699261569 at random_state  949
# R2 score of lr  49.34092285544898 at random_state  797
# R2_score of LinearRegression  0.38787667056886743 at random_state  950
# R2 score of lr  49.34092285544898 at random_state  797
# R2_score of LinearRegression  0.3610323234169325 at random_state  951
# R2 score of lr  49.34092285544898 at random_state  797
# R2_score of LinearRegression  0.42910430777323016 at random_state  952
# R2 score of lr  49.34092285544898 at random_state  797
# R2_score of LinearRegression  0.4256835319857597 at random_state  953
# R2 score of lr  49.34092285544898 at random_state  797
# R2_score of LinearRegression  0.372284942180106 at random_state  954
# R2 score of lr  49.34092285544898 at random_state  797
# R2_score of LinearRegression  0.3641015906060546 at random_state  955
# R2 score of lr  49.34092285544898 at random_state  797
# R2_score of LinearRegression  0.35057903354979625 at random_state  956
# R2 score of lr  49.34092285544898 at random_state  797
# R2_score of LinearRegression  0.3195524928019312 at random_state  957
# R2 score of lr  49.34092285544898 at random_state  797
# R2_score of LinearRegression  0.31257164241751756 at random_state  958
# R2 score of lr  49.34092285544898 at random_state  797
# R2_score of LinearRegression  0.32773937984729296 at random_state  959
# R2 score of lr  49.34092285544898 at random_state  797
# R2_score of LinearRegression  0.3934983828551991 at random_state  960
# R2 score of lr  49.34092285544898 at random_state  797
# R2_score of LinearRegression  0.39594392414374624 at random_state  961
# R2 score of lr  49.34092285544898 at random_state  797
# R2_score of LinearRegression  0.4439270652217532 at random_state  962
# R2 score of lr  49.34092285544898 at random_state  797
# R2_score of LinearRegression  0.38105762317019143 at random_state  963
# R2 score of lr  49.34092285544898 at random_state  797
# R2_score of LinearRegression  0.34289376389766935 at random_state  964
# R2 score of lr  49.34092285544898 at random_state  797
# R2_score of LinearRegression  0.36370371333974705 at random_state  965
# R2 score of lr  49.34092285544898 at random_state  797
# R2_score of LinearRegression  0.33230086681059323 at random_state  966
# R2 score of lr  49.34092285544898 at random_state  797
# R2_score of LinearRegression  0.36443069355040403 at random_state  967
# R2 score of lr  49.34092285544898 at random_state  797
# R2_score of LinearRegression  0.331950297497829 at random_state  968
# R2 score of lr  49.34092285544898 at random_state  797
# R2_score of LinearRegression  0.4112885752649521 at random_state  969
# R2 score of lr  49.34092285544898 at random_state  797
# R2_score of LinearRegression  0.41142037689203226 at random_state  970
# R2 score of lr  49.34092285544898 at random_state  797
# R2_score of LinearRegression  0.38040510705091124 at random_state  971
# R2 score of lr  49.34092285544898 at random_state  797
# R2_score of LinearRegression  0.365799712871261 at random_state  972
# R2 score of lr  49.34092285544898 at random_state  797
# R2_score of LinearRegression  0.395861742214767 at random_state  973
# R2 score of lr  49.34092285544898 at random_state  797
# R2_score of LinearRegression  0.3278403943264434 at random_state  974
# R2 score of lr  49.34092285544898 at random_state  797
# R2_score of LinearRegression  0.3223251234723521 at random_state  975
# R2 score of lr  49.34092285544898 at random_state  797
# R2_score of LinearRegression  0.43402068105388125 at random_state  976
# R2 score of lr  49.34092285544898 at random_state  797
# R2_score of LinearRegression  0.43091020403013747 at random_state  977
# R2 score of lr  49.34092285544898 at random_state  797
# R2_score of LinearRegression  0.4236564927215257 at random_state  978
# R2 score of lr  49.34092285544898 at random_state  797
# R2_score of LinearRegression  0.4085969227251435 at random_state  979
# R2 score of lr  49.34092285544898 at random_state  797
# R2_score of LinearRegression  0.37231305826086625 at random_state  980
# R2 score of lr  49.34092285544898 at random_state  797
# R2_score of LinearRegression  0.40315680490082206 at random_state  981
# R2 score of lr  49.34092285544898 at random_state  797
# R2_score of LinearRegression  0.3842793973106863 at random_state  982
# R2 score of lr  49.34092285544898 at random_state  797
# R2_score of LinearRegression  0.38102146266294423 at random_state  983
# R2 score of lr  49.34092285544898 at random_state  797
# R2_score of LinearRegression  0.34137695406285773 at random_state  984
# R2 score of lr  49.34092285544898 at random_state  797
# R2_score of LinearRegression  0.37288574713382017 at random_state  985
# R2 score of lr  49.34092285544898 at random_state  797
# R2_score of LinearRegression  0.37816616701650174 at random_state  986
# R2 score of lr  49.34092285544898 at random_state  797
# R2_score of LinearRegression  0.396177642431386 at random_state  987
# R2 score of lr  49.34092285544898 at random_state  797
# R2_score of LinearRegression  0.3011597353051063 at random_state  988
# R2 score of lr  49.34092285544898 at random_state  797
# R2_score of LinearRegression  0.3167935389784986 at random_state  989
# R2 score of lr  49.34092285544898 at random_state  797
# R2_score of LinearRegression  0.3835036404862511 at random_state  990
# R2 score of lr  49.34092285544898 at random_state  797
# R2_score of LinearRegression  0.42863996331903 at random_state  991
# R2 score of lr  49.34092285544898 at random_state  797
# R2_score of LinearRegression  0.3239127487750776 at random_state  992
# R2 score of lr  49.34092285544898 at random_state  797
# R2_score of LinearRegression  0.39362112774710023 at random_state  993
# R2 score of lr  49.34092285544898 at random_state  797
# R2_score of LinearRegression  0.3965676407798152 at random_state  994
# R2 score of lr  49.34092285544898 at random_state  797
# R2_score of LinearRegression  0.39441242432113766 at random_state  995
# R2 score of lr  49.34092285544898 at random_state  797
# R2_score of LinearRegression  0.31808175498764824 at random_state  996
# R2 score of lr  49.34092285544898 at random_state  797
# R2_score of LinearRegression  0.40949109884325674 at random_state  997
# R2 score of lr  49.34092285544898 at random_state  797
# R2_score of LinearRegression  0.21394095514124 at random_state  998
# R2 score of lr  49.34092285544898 at random_state  797
# R2_score of LinearRegression  0.3983578293905675 at random_state  999
# R2 score of lr  49.34092285544898 at random_state  797

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.20,random_state=19)
lr.fit(x_train,y_train)
predlr=lr.predict(x_test)
score=r2_score(predlr,y_test)
print('R2_score of LinearRegression ' ,score*100)
print(mean_absolute_error(predlr,y_test))
print((mean_squared_error(predlr,y_test)))
# Out:
# R2_score of LinearRegression  -61.225660976845745
# 9.85372278672584
# 138.00063558189458

# %% [markdown]
# # TESTING MORE MODELS

# %%
from sklearn.neighbors import KNeighborsRegressor
from sklearn.ensemble import GradientBoostingRegressor,AdaBoostRegressor,ExtraTreesRegressor,RandomForestRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.svm import SVR
knr=KNeighborsRegressor()
gbr=GradientBoostingRegressor()
abr=AdaBoostRegressor()
etr=ExtraTreesRegressor()
rfr=RandomForestRegressor()
dtr=DecisionTreeRegressor()
svr=SVR()

# %%
model=[knr,gbr,abr,etr,rfr,dtr,svr]
for i in model:
    i.fit(x_train,y_train)
    predi=i.predict(x_test)
    print('R2_score of model ' , i ,'is = ' ,r2_score(y_test,predi)*100)
# Out:
# R2_score of model  KNeighborsRegressor() is =  100.0
# R2_score of model  GradientBoostingRegressor() is =  99.95393159237769
# R2_score of model  AdaBoostRegressor() is =  92.39719957731187
# R2_score of model  ExtraTreesRegressor() is =  100.0
# R2_score of model  RandomForestRegressor() is =  100.0
# R2_score of model  DecisionTreeRegressor() is =  100.0
# R2_score of model  SVR() is =  -1.0017777449487397

# %% [markdown]
# # CROSS_VALIDATION

# %%
from sklearn.model_selection import cross_val_score

# %%
for i in range(2,10):
    models=[lr,knr,gbr,abr,etr,rfr,dtr,svr]
    for j in models:
        j.fit(x_train,y_train)
        predj=j.predict(x_test)
        score=r2_score(y_test,predj)
        cross=cross_val_score(j,x_train,y_train,cv=i)
        print('R2_score of model ' ,j, 'is equal = ', score*100)
        print('Cross validation of model ',i, 'is equal = ',cross.mean())
        print('Diff between r2_score and cross_validation of model ' ,j,'is equal = ',score-cross.mean())
# Out:
# R2_score of model  LinearRegression() is equal =  36.58122410891277
# Cross validation of model  2 is equal =  0.38670446258914476
# Diff between r2_score and cross_validation of model  LinearRegression() is equal =  -0.020892221500017072
# R2_score of model  KNeighborsRegressor() is equal =  100.0
# Cross validation of model  2 is equal =  1.0
# Diff between r2_score and cross_validation of model  KNeighborsRegressor() is equal =  0.0
# R2_score of model  GradientBoostingRegressor() is equal =  99.95393159237769
# Cross validation of model  2 is equal =  0.9992884761246588
# Diff between r2_score and cross_validation of model  GradientBoostingRegressor() is equal =  0.0002508397991181077
# R2_score of model  AdaBoostRegressor() is equal =  93.18431585570073
# Cross validation of model  2 is equal =  0.9340111956127679
# Diff between r2_score and cross_validation of model  AdaBoostRegressor() is equal =  -0.00216803705576063
# R2_score of model  ExtraTreesRegressor() is equal =  100.0
# Cross validation of model  2 is equal =  1.0
# Diff between r2_score and cross_validation of model  ExtraTreesRegressor() is equal =  0.0
# R2_score of model  RandomForestRegressor() is equal =  100.0
# Cross validation of model  2 is equal =  0.9999998368743742
# Diff between r2_score and cross_validation of model  RandomForestRegressor() is equal =  1.631256257850211e-07
# R2_score of model  DecisionTreeRegressor() is equal =  100.0
# Cross validation of model  2 is equal =  1.0
# Diff between r2_score and cross_validation of model  DecisionTreeRegressor() is equal =  0.0
# R2_score of model  SVR() is equal =  -1.0017777449487397
# Cross validation of model  2 is equal =  -0.00492940677482212
# Diff between r2_score and cross_validation of model  SVR() is equal =  -0.005088370674665277
# R2_score of model  LinearRegression() is equal =  36.58122410891277
# Cross validation of model  3 is equal =  0.39043807251329304
# Diff between r2_score and cross_validation of model  LinearRegression() is equal =  -0.024625831424165356
# R2_score of model  KNeighborsRegressor() is equal =  100.0
# Cross validation of model  3 is equal =  1.0
# Diff between r2_score and cross_validation of model  KNeighborsRegressor() is equal =  0.0
# R2_score of model  GradientBoostingRegressor() is equal =  99.95393159237769
# Cross validation of model  3 is equal =  0.9991967737566244
# Diff between r2_score and cross_validation of model  GradientBoostingRegressor() is equal =  0.0003425421671524598
# R2_score of model  AdaBoostRegressor() is equal =  93.93145821454955
# Cross validation of model  3 is equal =  0.9365884009095727
# Diff between r2_score and cross_validation of model  AdaBoostRegressor() is equal =  0.00272618123592272
# R2_score of model  ExtraTreesRegressor() is equal =  100.0
# Cross validation of model  3 is equal =  1.0
# Diff between r2_score and cross_validation of model  ExtraTreesRegressor() is equal =  0.0
# R2_score of model  RandomForestRegressor() is equal =  100.0
# Cross validation of model  3 is equal =  1.0
# Diff between r2_score and cross_validation of model  RandomForestRegressor() is equal =  0.0
# R2_score of model  DecisionTreeRegressor() is equal =  100.0
# Cross validation of model  3 is equal =  1.0
# Diff between r2_score and cross_validation of model  DecisionTreeRegressor() is equal =  0.0
# R2_score of model  SVR() is equal =  -1.0017777449487397
# Cross validation of model  3 is equal =  -0.011231372672922513
# Diff between r2_score and cross_validation of model  SVR() is equal =  0.0012135952234351155
# R2_score of model  LinearRegression() is equal =  36.58122410891277
# Cross validation of model  4 is equal =  0.3916070141610787
# Diff between r2_score and cross_validation of model  LinearRegression() is equal =  -0.025794773071950994
# R2_score of model  KNeighborsRegressor() is equal =  100.0
# Cross validation of model  4 is equal =  1.0
# Diff between r2_score and cross_validation of model  KNeighborsRegressor() is equal =  0.0
# R2_score of model  GradientBoostingRegressor() is equal =  99.95393159237769
# Cross validation of model  4 is equal =  0.9992852880511467
# Diff between r2_score and cross_validation of model  GradientBoostingRegressor() is equal =  0.00025402787263018034
# R2_score of model  AdaBoostRegressor() is equal =  92.83524104115655
# Cross validation of model  4 is equal =  0.9335680725759748
# Diff between r2_score and cross_validation of model  AdaBoostRegressor() is equal =  -0.005215662164409385
# R2_score of model  ExtraTreesRegressor() is equal =  100.0
# Cross validation of model  4 is equal =  1.0
# Diff between r2_score and cross_validation of model  ExtraTreesRegressor() is equal =  0.0
# R2_score of model  RandomForestRegressor() is equal =  100.0
# Cross validation of model  4 is equal =  1.0
# Diff between r2_score and cross_validation of model  RandomForestRegressor() is equal =  0.0
# R2_score of model  DecisionTreeRegressor() is equal =  100.0
# Cross validation of model  4 is equal =  1.0
# Diff between r2_score and cross_validation of model  DecisionTreeRegressor() is equal =  0.0
# R2_score of model  SVR() is equal =  -1.0017777449487397
# Cross validation of model  4 is equal =  -0.0038026682691962577
# Diff between r2_score and cross_validation of model  SVR() is equal =  -0.00621510918029114
# R2_score of model  LinearRegression() is equal =  36.58122410891277
# Cross validation of model  5 is equal =  0.3952661870834254
# Diff between r2_score and cross_validation of model  LinearRegression() is equal =  -0.029453945994297737
# R2_score of model  KNeighborsRegressor() is equal =  100.0
# Cross validation of model  5 is equal =  1.0
# Diff between r2_score and cross_validation of model  KNeighborsRegressor() is equal =  0.0
# R2_score of model  GradientBoostingRegressor() is equal =  99.95393159237769
# Cross validation of model  5 is equal =  0.9992300899541722
# Diff between r2_score and cross_validation of model  GradientBoostingRegressor() is equal =  0.0003092259696046984
# R2_score of model  AdaBoostRegressor() is equal =  93.74155261051011
# Cross validation of model  5 is equal =  0.9330009422499547
# Diff between r2_score and cross_validation of model  AdaBoostRegressor() is equal =  0.004414583855146481
# R2_score of model  ExtraTreesRegressor() is equal =  100.0
# Cross validation of model  5 is equal =  1.0
# Diff between r2_score and cross_validation of model  ExtraTreesRegressor() is equal =  0.0
# R2_score of model  RandomForestRegressor() is equal =  100.0
# Cross validation of model  5 is equal =  1.0
# Diff between r2_score and cross_validation of model  RandomForestRegressor() is equal =  0.0
# R2_score of model  DecisionTreeRegressor() is equal =  100.0
# Cross validation of model  5 is equal =  1.0
# Diff between r2_score and cross_validation of model  DecisionTreeRegressor() is equal =  0.0
# R2_score of model  SVR() is equal =  -1.0017777449487397
# Cross validation of model  5 is equal =  -0.004260028331117405
# Diff between r2_score and cross_validation of model  SVR() is equal =  -0.005757749118369992
# R2_score of model  LinearRegression() is equal =  36.58122410891277
# Cross validation of model  6 is equal =  0.3896285289282429
# Diff between r2_score and cross_validation of model  LinearRegression() is equal =  -0.023816287839115213
# R2_score of model  KNeighborsRegressor() is equal =  100.0
# Cross validation of model  6 is equal =  1.0
# Diff between r2_score and cross_validation of model  KNeighborsRegressor() is equal =  0.0
# R2_score of model  GradientBoostingRegressor() is equal =  99.95393159237769
# Cross validation of model  6 is equal =  0.99922999631483
# Diff between r2_score and cross_validation of model  GradientBoostingRegressor() is equal =  0.0003093196089468675
# R2_score of model  AdaBoostRegressor() is equal =  93.18064675637056
# Cross validation of model  6 is equal =  0.9306382303718972
# Diff between r2_score and cross_validation of model  AdaBoostRegressor() is equal =  0.0011682371918084744
# R2_score of model  ExtraTreesRegressor() is equal =  100.0
# Cross validation of model  6 is equal =  1.0
# Diff between r2_score and cross_validation of model  ExtraTreesRegressor() is equal =  0.0
# R2_score of model  RandomForestRegressor() is equal =  100.0
# Cross validation of model  6 is equal =  1.0
# Diff between r2_score and cross_validation of model  RandomForestRegressor() is equal =  0.0
# R2_score of model  DecisionTreeRegressor() is equal =  100.0
# Cross validation of model  6 is equal =  1.0
# Diff between r2_score and cross_validation of model  DecisionTreeRegressor() is equal =  0.0
# R2_score of model  SVR() is equal =  -1.0017777449487397
# Cross validation of model  6 is equal =  -0.0057439585037726655
# Diff between r2_score and cross_validation of model  SVR() is equal =  -0.004273818945714732
# R2_score of model  LinearRegression() is equal =  36.58122410891277
# Cross validation of model  7 is equal =  0.39038467411115196
# Diff between r2_score and cross_validation of model  LinearRegression() is equal =  -0.024572433022024276
# R2_score of model  KNeighborsRegressor() is equal =  100.0
# Cross validation of model  7 is equal =  1.0
# Diff between r2_score and cross_validation of model  KNeighborsRegressor() is equal =  0.0
# R2_score of model  GradientBoostingRegressor() is equal =  99.95393159237769
# Cross validation of model  7 is equal =  0.9991532656491487
# Diff between r2_score and cross_validation of model  GradientBoostingRegressor() is equal =  0.0003860502746281247
# R2_score of model  AdaBoostRegressor() is equal =  93.46274729736686
# Cross validation of model  7 is equal =  0.933933353402889
# Diff between r2_score and cross_validation of model  AdaBoostRegressor() is equal =  0.0006941195707795833
# R2_score of model  ExtraTreesRegressor() is equal =  100.0
# Cross validation of model  7 is equal =  1.0
# Diff between r2_score and cross_validation of model  ExtraTreesRegressor() is equal =  0.0
# R2_score of model  RandomForestRegressor() is equal =  100.0
# Cross validation of model  7 is equal =  1.0
# Diff between r2_score and cross_validation of model  RandomForestRegressor() is equal =  0.0
# R2_score of model  DecisionTreeRegressor() is equal =  100.0
# Cross validation of model  7 is equal =  1.0
# Diff between r2_score and cross_validation of model  DecisionTreeRegressor() is equal =  0.0
# R2_score of model  SVR() is equal =  -1.0017777449487397
# Cross validation of model  7 is equal =  -0.006090879720658264
# Diff between r2_score and cross_validation of model  SVR() is equal =  -0.003926897728829133
# R2_score of model  LinearRegression() is equal =  36.58122410891277
# Cross validation of model  8 is equal =  0.3909804255948011
# Diff between r2_score and cross_validation of model  LinearRegression() is equal =  -0.02516818450567343
# R2_score of model  KNeighborsRegressor() is equal =  100.0
# Cross validation of model  8 is equal =  1.0
# Diff between r2_score and cross_validation of model  KNeighborsRegressor() is equal =  0.0
# R2_score of model  GradientBoostingRegressor() is equal =  99.95393159237769
# Cross validation of model  8 is equal =  0.9992868366679974
# Diff between r2_score and cross_validation of model  GradientBoostingRegressor() is equal =  0.0002524792557794253
# R2_score of model  AdaBoostRegressor() is equal =  92.17147181140997
# Cross validation of model  8 is equal =  0.9316610562893323
# Diff between r2_score and cross_validation of model  AdaBoostRegressor() is equal =  -0.009946338175232605
# R2_score of model  ExtraTreesRegressor() is equal =  100.0
# Cross validation of model  8 is equal =  1.0
# Diff between r2_score and cross_validation of model  ExtraTreesRegressor() is equal =  0.0
# R2_score of model  RandomForestRegressor() is equal =  100.0
# Cross validation of model  8 is equal =  1.0
# Diff between r2_score and cross_validation of model  RandomForestRegressor() is equal =  0.0
# R2_score of model  DecisionTreeRegressor() is equal =  100.0
# Cross validation of model  8 is equal =  1.0
# Diff between r2_score and cross_validation of model  DecisionTreeRegressor() is equal =  0.0
# R2_score of model  SVR() is equal =  -1.0017777449487397
# Cross validation of model  8 is equal =  -0.005659179723752045
# Diff between r2_score and cross_validation of model  SVR() is equal =  -0.0043585977257353525
# R2_score of model  LinearRegression() is equal =  36.58122410891277
# Cross validation of model  9 is equal =  0.38559822303346075
# Diff between r2_score and cross_validation of model  LinearRegression() is equal =  -0.019785981944333064
# R2_score of model  KNeighborsRegressor() is equal =  100.0
# Cross validation of model  9 is equal =  1.0
# Diff between r2_score and cross_validation of model  KNeighborsRegressor() is equal =  0.0
# R2_score of model  GradientBoostingRegressor() is equal =  99.95393159237769
# Cross validation of model  9 is equal =  0.9993753710199142
# Diff between r2_score and cross_validation of model  GradientBoostingRegressor() is equal =  0.00016394490386262284
# R2_score of model  AdaBoostRegressor() is equal =  94.10270409858393
# Cross validation of model  9 is equal =  0.933393414483148
# Diff between r2_score and cross_validation of model  AdaBoostRegressor() is equal =  0.007633626502691171
# R2_score of model  ExtraTreesRegressor() is equal =  100.0
# Cross validation of model  9 is equal =  1.0
# Diff between r2_score and cross_validation of model  ExtraTreesRegressor() is equal =  0.0
# R2_score of model  RandomForestRegressor() is equal =  100.0
# Cross validation of model  9 is equal =  1.0
# Diff between r2_score and cross_validation of model  RandomForestRegressor() is equal =  0.0
# R2_score of model  DecisionTreeRegressor() is equal =  100.0
# Cross validation of model  9 is equal =  1.0
# Diff between r2_score and cross_validation of model  DecisionTreeRegressor() is equal =  0.0
# R2_score of model  SVR() is equal =  -1.0017777449487397
# Cross validation of model  9 is equal =  -0.006735093302852639
# Diff between r2_score and cross_validation of model  SVR() is equal =  -0.0032826841466347583

# %% [markdown]
# # REGULARISATION

# %%
from sklearn.linear_model import Lasso,Ridge,ElasticNet
l=Lasso()
r=Ridge()
en=ElasticNet()

# %%
models=[l,r,en]
for i in models:
    i.fit(x_train,y_train)
    alpha=[0.001,0.001,0.01,0.1,1]
    for j in alpha:
        predmodel=i.predict(x_test)
        print('R2_score : ' ,(r2_score(y_test,predmodel))*100, 'at model ',i,'with alpha ',j)
        print(mean_squared_error(y_test,predmodel))
        print(mean_absolute_error(y_test,predmodel))
# Out:
# R2_score :  35.757806849940074 at model  Lasso() with alpha  0.001
# 139.7924094452451
# 10.126803763170058
# R2_score :  35.757806849940074 at model  Lasso() with alpha  0.001
# 139.7924094452451
# 10.126803763170058
# R2_score :  35.757806849940074 at model  Lasso() with alpha  0.01
# 139.7924094452451
# 10.126803763170058
# R2_score :  35.757806849940074 at model  Lasso() with alpha  0.1
# 139.7924094452451
# 10.126803763170058
# R2_score :  35.757806849940074 at model  Lasso() with alpha  1
# 139.7924094452451
# 10.126803763170058
# R2_score :  36.58806921189317 at model  Ridge() with alpha  0.001
# 137.98574048894073
# 9.857392190206095
# R2_score :  36.58806921189317 at model  Ridge() with alpha  0.001
# 137.98574048894073
# 9.857392190206095
# R2_score :  36.58806921189317 at model  Ridge() with alpha  0.01
# 137.98574048894073
# 9.857392190206095
# R2_score :  36.58806921189317 at model  Ridge() with alpha  0.1
# 137.98574048894073
# 9.857392190206095
# R2_score :  36.58806921189317 at model  Ridge() with alpha  1
# 137.98574048894073
# 9.857392190206095
# R2_score :  35.88517424925198 at model  ElasticNet() with alpha  0.001
# 139.5152552143334
# 10.10757725199971
# R2_score :  35.88517424925198 at model  ElasticNet() with alpha  0.001
# 139.5152552143334
# 10.10757725199971
# R2_score :  35.88517424925198 at model  ElasticNet() with alpha  0.01
# 139.5152552143334
# 10.10757725199971
# R2_score :  35.88517424925198 at model  ElasticNet() with alpha  0.1
# 139.5152552143334
# 10.10757725199971
# R2_score :  35.88517424925198 at model  ElasticNet() with alpha  1
# 139.5152552143334
# 10.10757725199971

# %% [markdown]
# # HYPERTUNING

# %%
from sklearn.model_selection import GridSearchCV

# %%
parameters={'n_estimators':[50,100,150,200],
            'criterion':['gini','squared_error'],
            'max_depth':[1,2,3],
            'max_features':['auto','sqrt','log2']}
gscv_gbr=GridSearchCV(estimator=gbr,param_grid=parameters)
gscv_gbr.fit(x_train,y_train)
# Out:
# GridSearchCV(estimator=GradientBoostingRegressor(),
#              param_grid={'criterion': ['gini', 'squared_error'],
#                          'max_depth': [1, 2, 3],
#                          'max_features': ['auto', 'sqrt', 'log2'],
#                          'n_estimators': [50, 100, 150, 200]})

# %%
print(gscv_gbr.best_score_)
print(gscv_gbr.best_params_)
print(gscv_gbr.best_estimator_)
# Out:
# 0.9999941022268815
# {'criterion': 'squared_error', 'max_depth': 3, 'max_features': 'auto', 'n_estimators': 200}
# GradientBoostingRegressor(criterion='squared_error', max_features='auto',
#                           n_estimators=200)

# %%
parameters={'n_estimators':[50,100,150,200],
            'criterion':['gini','squared_error'],
            'max_depth':[1,2,3],
            'max_features':['auto','sqrt','log2']}
gscv_etr=GridSearchCV(estimator=etr,param_grid=parameters)
gscv_etr.fit(x_train,y_train)
# Out:
# GridSearchCV(estimator=ExtraTreesRegressor(),
#              param_grid={'criterion': ['gini', 'squared_error'],
#                          'max_depth': [1, 2, 3],
#                          'max_features': ['auto', 'sqrt', 'log2'],
#                          'n_estimators': [50, 100, 150, 200]})

# %%
print(gscv_etr.best_score_)
print(gscv_etr.best_params_)
print(gscv_etr.best_estimator_)
# Out:
# 0.7290738280915158
# {'criterion': 'squared_error', 'max_depth': 3, 'max_features': 'auto', 'n_estimators': 150}
# ExtraTreesRegressor(max_depth=3, max_features='auto', n_estimators=150)

# %%
parameters={'n_estimators':[50,100,150,200],
            'criterion':['gini','squared_error'],
            'max_depth':[1,2,3],
            'max_features':['auto','sqrt','log2']}
gscv_rfr=GridSearchCV(estimator=rfr,param_grid=parameters)
gscv_rfr.fit(x_train,y_train)
# Out:
# GridSearchCV(estimator=RandomForestRegressor(),
#              param_grid={'criterion': ['gini', 'squared_error'],
#                          'max_depth': [1, 2, 3],
#                          'max_features': ['auto', 'sqrt', 'log2'],
#                          'n_estimators': [50, 100, 150, 200]})

# %%
print(gscv_rfr.best_score_)
print(gscv_rfr.best_params_)
print(gscv_rfr.best_estimator_)
# Out:
# 0.8149529873443873
# {'criterion': 'squared_error', 'max_depth': 3, 'max_features': 'auto', 'n_estimators': 200}
# RandomForestRegressor(max_depth=3, max_features='auto', n_estimators=200)

# %% [markdown]
# # ROC_CURVE

# %%
from sklearn.metrics import roc_curve,plot_roc_curve

# %%
gbr=GradientBoostingRegressor()
gbr.fit(x_train,y_train)
predgbr=gbr.predict(x_test)
score=r2_score(predgbr,y_test)
print(score)
# Out:
# 0.9995276534529854

# %%
etr=ExtraTreesRegressor()
etr.fit(x_train,y_train)
predetr=etr.predict(x_test)
score_a=r2_score(predetr,y_test)
print(score_a)
# Out:
# 1.0

# %%
rfr=RandomForestRegressor()
rfr.fit(x_train,y_train)
predrfr=rfr.predict(x_test)
score_b=r2_score(predrfr,y_test)
print(score_b)
# Out:
# 1.0

# %%
plt.scatter(predgbr,predetr,predrfr,y_test)
plt.plot(y_test,y_test,linewidth=4,color='Red')

# %% [markdown]
# # Above all methods of testing GRADIENT BOOSTING REGRESSOR is found to be the most suitable model as it gives the more accurate r2_score for predicting VOTES in the dataset,movie1,so we are saving it.

# %% [markdown]
# # SAVING THE BEST FITTED MODEL

# %%
import pickle
filename='movie1_votes.pkl'

# %%
pickle.dump(gbr,open(filename,'wb'))

# %% [markdown]
# # LOADING THE SAVED MODEL

# %%
pickle.load(open(filename,'rb'))
# Out:
# GradientBoostingRegressor()

# %% [markdown]
# # SPLITTING X1 AND Y1

# %%
x1=new.drop('Gross Collection',axis=1)
y1=new['Gross Collection']

# %%
x1.shape
# Out:
# (1548, 18)

# %%
y1.shape
# Out:
# (1548,)

# %% [markdown]
# # TRAINING AND TESTING

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
lr1=LinearRegression()
from sklearn.metrics import r2_score,mean_absolute_error,mean_squared_error

# %%
maxR21=0
maxRS1=0
for i in range(0,1000):
    x_train1,x_test1,y_train1,y_test1=train_test_split(x1,y1,test_size=0.20,random_state=i)
    lr1.fit(x_train1,y_train1)
    predlr1=lr1.predict(x_test1)
    score1=r2_score(y_test1,predlr1)
    print('R2_score of LinearRegression ' ,score1, 'at random_state ' ,i)
    if score1 > maxR21:
        maxR21=score
        maxRS1=i
    print('R2 score of lr1 ' ,maxR21*100, 'at random_state ' ,maxRS1)
# Out:
# R2_score of LinearRegression  0.3985667898104909 at random_state  0
# R2 score of lr1  99.95276534529854 at random_state  0
# R2_score of LinearRegression  0.4338232336404233 at random_state  1
# R2 score of lr1  99.95276534529854 at random_state  0
# R2_score of LinearRegression  0.4462048985044753 at random_state  2
# R2 score of lr1  99.95276534529854 at random_state  0
# R2_score of LinearRegression  0.4215397042434038 at random_state  3
# R2 score of lr1  99.95276534529854 at random_state  0
# R2_score of LinearRegression  0.4102476388835431 at random_state  4
# R2 score of lr1  99.95276534529854 at random_state  0
# R2_score of LinearRegression  0.3614557949614754 at random_state  5
# R2 score of lr1  99.95276534529854 at random_state  0
# R2_score of LinearRegression  0.43567498824211504 at random_state  6
# R2 score of lr1  99.95276534529854 at random_state  0
# R2_score of LinearRegression  0.4847308123160734 at random_state  7
# R2 score of lr1  99.95276534529854 at random_state  0
# R2_score of LinearRegression  0.4521607613554468 at random_state  8
# R2 score of lr1  99.95276534529854 at random_state  0
# R2_score of LinearRegression  0.42028349695899136 at random_state  9
# R2 score of lr1  99.95276534529854 at random_state  0
# R2_score of LinearRegression  0.4608033866748825 at random_state  10
# R2 score of lr1  99.95276534529854 at random_state  0
# R2_score of LinearRegression  0.4018645611515541 at random_state  11
# R2 score of lr1  99.95276534529854 at random_state  0
# R2_score of LinearRegression  0.4222086896314382 at random_state  12
# R2 score of lr1  99.95276534529854 at random_state  0
# R2_score of LinearRegression  0.4784777426944039 at random_state  13
# R2 score of lr1  99.95276534529854 at random_state  0
# R2_score of LinearRegression  0.4421824297854712 at random_state  14
# R2 score of lr1  99.95276534529854 at random_state  0
# R2_score of LinearRegression  0.4411288030393704 at random_state  15
# R2 score of lr1  99.95276534529854 at random_state  0
# R2_score of LinearRegression  0.41695862155738006 at random_state  16
# R2 score of lr1  99.95276534529854 at random_state  0
# R2_score of LinearRegression  0.414305703383261 at random_state  17
# R2 score of lr1  99.95276534529854 at random_state  0
# R2_score of LinearRegression  0.41816996571088627 at random_state  18
# R2 score of lr1  99.95276534529854 at random_state  0
# R2_score of LinearRegression  0.39384745582168335 at random_state  19
# R2 score of lr1  99.95276534529854 at random_state  0
# R2_score of LinearRegression  0.42036294953688713 at random_state  20
# R2 score of lr1  99.95276534529854 at random_state  0
# R2_score of LinearRegression  0.4520309922244271 at random_state  21
# R2 score of lr1  99.95276534529854 at random_state  0
# R2_score of LinearRegression  0.46451182084475506 at random_state  22
# R2 score of lr1  99.95276534529854 at random_state  0
# R2_score of LinearRegression  0.39771307562019886 at random_state  23
# R2 score of lr1  99.95276534529854 at random_state  0
# R2_score of LinearRegression  0.4238643548058102 at random_state  24
# R2 score of lr1  99.95276534529854 at random_state  0
# R2_score of LinearRegression  0.4323369350605848 at random_state  25
# R2 score of lr1  99.95276534529854 at random_state  0
# R2_score of LinearRegression  0.4316329535468735 at random_state  26
# R2 score of lr1  99.95276534529854 at random_state  0
# R2_score of LinearRegression  0.4009994684303466 at random_state  27
# R2 score of lr1  99.95276534529854 at random_state  0
# R2_score of LinearRegression  0.4367264127759267 at random_state  28
# R2 score of lr1  99.95276534529854 at random_state  0
# R2_score of LinearRegression  0.42226368477898857 at random_state  29
# R2 score of lr1  99.95276534529854 at random_state  0
# R2_score of LinearRegression  0.4505499871590156 at random_state  30
# R2 score of lr1  99.95276534529854 at random_state  0
# R2_score of LinearRegression  0.46396265033575534 at random_state  31
# R2 score of lr1  99.95276534529854 at random_state  0
# R2_score of LinearRegression  0.4409410656762752 at random_state  32
# R2 score of lr1  99.95276534529854 at random_state  0
# R2_score of LinearRegression  0.4042734704823655 at random_state  33
# R2 score of lr1  99.95276534529854 at random_state  0
# R2_score of LinearRegression  0.48486985696839713 at random_state  34
# R2 score of lr1  99.95276534529854 at random_state  0
# R2_score of LinearRegression  0.4518142792726676 at random_state  35
# R2 score of lr1  99.95276534529854 at random_state  0
# R2_score of LinearRegression  0.4035078196648274 at random_state  36
# R2 score of lr1  99.95276534529854 at random_state  0
# R2_score of LinearRegression  0.4124585228122922 at random_state  37
# R2 score of lr1  99.95276534529854 at random_state  0
# R2_score of LinearRegression  0.386367145880812 at random_state  38
# R2 score of lr1  99.95276534529854 at random_state  0
# R2_score of LinearRegression  0.41975208106759576 at random_state  39
# R2 score of lr1  99.95276534529854 at random_state  0
# R2_score of LinearRegression  0.4443701343962434 at random_state  40
# R2 score of lr1  99.95276534529854 at random_state  0
# R2_score of LinearRegression  0.35559366277139304 at random_state  41
# R2 score of lr1  99.95276534529854 at random_state  0
# R2_score of LinearRegression  0.4876351873715379 at random_state  42
# R2 score of lr1  99.95276534529854 at random_state  0
# R2_score of LinearRegression  0.4412923558317138 at random_state  43
# R2 score of lr1  99.95276534529854 at random_state  0
# R2_score of LinearRegression  0.4147819995437656 at random_state  44
# R2 score of lr1  99.95276534529854 at random_state  0
# R2_score of LinearRegression  0.41018186163657666 at random_state  45
# R2 score of lr1  99.95276534529854 at random_state  0
# R2_score of LinearRegression  0.44159618121706756 at random_state  46
# R2 score of lr1  99.95276534529854 at random_state  0
# R2_score of LinearRegression  0.47078140958615644 at random_state  47
# R2 score of lr1  99.95276534529854 at random_state  0
# R2_score of LinearRegression  0.46047520613426707 at random_state  48
# R2 score of lr1  99.95276534529854 at random_state  0
# R2_score of LinearRegression  0.4038213163953941 at random_state  49
# R2 score of lr1  99.95276534529854 at random_state  0
# R2_score of LinearRegression  0.45863691494165626 at random_state  50
# R2 score of lr1  99.95276534529854 at random_state  0
# R2_score of LinearRegression  0.4334061791729451 at random_state  51
# R2 score of lr1  99.95276534529854 at random_state  0
# R2_score of LinearRegression  0.43236821637496237 at random_state  52
# R2 score of lr1  99.95276534529854 at random_state  0
# R2_score of LinearRegression  0.4108347952933966 at random_state  53
# R2 score of lr1  99.95276534529854 at random_state  0
# R2_score of LinearRegression  0.44972554508794993 at random_state  54
# R2 score of lr1  99.95276534529854 at random_state  0
# R2_score of LinearRegression  0.4106848421679882 at random_state  55
# R2 score of lr1  99.95276534529854 at random_state  0
# R2_score of LinearRegression  0.41702608817967346 at random_state  56
# R2 score of lr1  99.95276534529854 at random_state  0
# R2_score of LinearRegression  0.4012733100265584 at random_state  57
# R2 score of lr1  99.95276534529854 at random_state  0
# R2_score of LinearRegression  0.3913731025955708 at random_state  58
# R2 score of lr1  99.95276534529854 at random_state  0
# R2_score of LinearRegression  0.40766568013046744 at random_state  59
# R2 score of lr1  99.95276534529854 at random_state  0
# R2_score of LinearRegression  0.4492557168477931 at random_state  60
# R2 score of lr1  99.95276534529854 at random_state  0
# R2_score of LinearRegression  0.453132189304161 at random_state  61
# R2 score of lr1  99.95276534529854 at random_state  0
# R2_score of LinearRegression  0.4209141221295408 at random_state  62
# R2 score of lr1  99.95276534529854 at random_state  0
# R2_score of LinearRegression  0.40183940061332446 at random_state  63
# R2 score of lr1  99.95276534529854 at random_state  0
# R2_score of LinearRegression  0.43017176303946536 at random_state  64
# R2 score of lr1  99.95276534529854 at random_state  0
# R2_score of LinearRegression  0.39267728987790473 at random_state  65
# R2 score of lr1  99.95276534529854 at random_state  0
# R2_score of LinearRegression  0.4056809452171045 at random_state  66
# R2 score of lr1  99.95276534529854 at random_state  0
# R2_score of LinearRegression  0.42154533983873865 at random_state  67
# R2 score of lr1  99.95276534529854 at random_state  0
# R2_score of LinearRegression  0.4176540495768071 at random_state  68
# R2 score of lr1  99.95276534529854 at random_state  0
# R2_score of LinearRegression  0.432797315834031 at random_state  69
# R2 score of lr1  99.95276534529854 at random_state  0
# R2_score of LinearRegression  0.4557062732173721 at random_state  70
# R2 score of lr1  99.95276534529854 at random_state  0
# R2_score of LinearRegression  0.46521202020489605 at random_state  71
# R2 score of lr1  99.95276534529854 at random_state  0
# R2_score of LinearRegression  0.46207782437797273 at random_state  72
# R2 score of lr1  99.95276534529854 at random_state  0
# R2_score of LinearRegression  0.39881498078187905 at random_state  73
# R2 score of lr1  99.95276534529854 at random_state  0
# R2_score of LinearRegression  0.408179518391802 at random_state  74
# R2 score of lr1  99.95276534529854 at random_state  0
# R2_score of LinearRegression  0.4546227098043716 at random_state  75
# R2 score of lr1  99.95276534529854 at random_state  0
# R2_score of LinearRegression  0.4738497265861461 at random_state  76
# R2 score of lr1  99.95276534529854 at random_state  0
# R2_score of LinearRegression  0.4529321908390742 at random_state  77
# R2 score of lr1  99.95276534529854 at random_state  0
# R2_score of LinearRegression  0.4074851170657393 at random_state  78
# R2 score of lr1  99.95276534529854 at random_state  0
# R2_score of LinearRegression  0.4267223445428848 at random_state  79
# R2 score of lr1  99.95276534529854 at random_state  0
# R2_score of LinearRegression  0.37248810987004777 at random_state  80
# R2 score of lr1  99.95276534529854 at random_state  0
# R2_score of LinearRegression  0.4455411877704346 at random_state  81
# R2 score of lr1  99.95276534529854 at random_state  0
# R2_score of LinearRegression  0.4463836081428151 at random_state  82
# R2 score of lr1  99.95276534529854 at random_state  0
# R2_score of LinearRegression  0.35106843684218014 at random_state  83
# R2 score of lr1  99.95276534529854 at random_state  0
# R2_score of LinearRegression  0.4294382479690523 at random_state  84
# R2 score of lr1  99.95276534529854 at random_state  0
# R2_score of LinearRegression  0.47269227187844 at random_state  85
# R2 score of lr1  99.95276534529854 at random_state  0
# R2_score of LinearRegression  0.4340997885608755 at random_state  86
# R2 score of lr1  99.95276534529854 at random_state  0
# R2_score of LinearRegression  0.42551138356466867 at random_state  87
# R2 score of lr1  99.95276534529854 at random_state  0
# R2_score of LinearRegression  0.3627853434070716 at random_state  88
# R2 score of lr1  99.95276534529854 at random_state  0
# R2_score of LinearRegression  0.4156979301465554 at random_state  89
# R2 score of lr1  99.95276534529854 at random_state  0
# R2_score of LinearRegression  0.3956354119627674 at random_state  90
# R2 score of lr1  99.95276534529854 at random_state  0
# R2_score of LinearRegression  0.4594469285090431 at random_state  91
# R2 score of lr1  99.95276534529854 at random_state  0
# R2_score of LinearRegression  0.41398167666842345 at random_state  92
# R2 score of lr1  99.95276534529854 at random_state  0
# R2_score of LinearRegression  0.4208990744562422 at random_state  93
# R2 score of lr1  99.95276534529854 at random_state  0
# R2_score of LinearRegression  0.4380748705345693 at random_state  94
# R2 score of lr1  99.95276534529854 at random_state  0
# R2_score of LinearRegression  0.45757909373857186 at random_state  95
# R2 score of lr1  99.95276534529854 at random_state  0
# R2_score of LinearRegression  0.4604764899270707 at random_state  96
# R2 score of lr1  99.95276534529854 at random_state  0
# R2_score of LinearRegression  0.45532108890105105 at random_state  97
# R2 score of lr1  99.95276534529854 at random_state  0
# R2_score of LinearRegression  0.4129590474884349 at random_state  98
# R2 score of lr1  99.95276534529854 at random_state  0
# R2_score of LinearRegression  0.4308806280052312 at random_state  99
# R2 score of lr1  99.95276534529854 at random_state  0
# R2_score of LinearRegression  0.4663847726746567 at random_state  100
# R2 score of lr1  99.95276534529854 at random_state  0
# R2_score of LinearRegression  0.44255649439198896 at random_state  101
# R2 score of lr1  99.95276534529854 at random_state  0
# R2_score of LinearRegression  0.4268698793250152 at random_state  102
# R2 score of lr1  99.95276534529854 at random_state  0
# R2_score of LinearRegression  0.4156287741816471 at random_state  103
# R2 score of lr1  99.95276534529854 at random_state  0
# R2_score of LinearRegression  0.43306610835861414 at random_state  104
# R2 score of lr1  99.95276534529854 at random_state  0
# R2_score of LinearRegression  0.5076165337087776 at random_state  105
# R2 score of lr1  99.95276534529854 at random_state  0
# R2_score of LinearRegression  0.409192890153673 at random_state  106
# R2 score of lr1  99.95276534529854 at random_state  0
# R2_score of LinearRegression  0.4259736188042116 at random_state  107
# R2 score of lr1  99.95276534529854 at random_state  0
# R2_score of LinearRegression  0.5171914772538687 at random_state  108
# R2 score of lr1  99.95276534529854 at random_state  0
# R2_score of LinearRegression  0.40804625980743736 at random_state  109
# R2 score of lr1  99.95276534529854 at random_state  0
# R2_score of LinearRegression  0.40501581709155254 at random_state  110
# R2 score of lr1  99.95276534529854 at random_state  0
# R2_score of LinearRegression  0.3861110047660167 at random_state  111
# R2 score of lr1  99.95276534529854 at random_state  0
# R2_score of LinearRegression  0.38888580562557606 at random_state  112
# R2 score of lr1  99.95276534529854 at random_state  0
# R2_score of LinearRegression  0.43030758809727365 at random_state  113
# R2 score of lr1  99.95276534529854 at random_state  0
# R2_score of LinearRegression  0.4314815569597028 at random_state  114
# R2 score of lr1  99.95276534529854 at random_state  0
# R2_score of LinearRegression  0.43908663477229926 at random_state  115
# R2 score of lr1  99.95276534529854 at random_state  0
# R2_score of LinearRegression  0.4460128618404633 at random_state  116
# R2 score of lr1  99.95276534529854 at random_state  0
# R2_score of LinearRegression  0.4560765285362458 at random_state  117
# R2 score of lr1  99.95276534529854 at random_state  0
# R2_score of LinearRegression  0.44245845418799445 at random_state  118
# R2 score of lr1  99.95276534529854 at random_state  0
# R2_score of LinearRegression  0.42363324657444434 at random_state  119
# R2 score of lr1  99.95276534529854 at random_state  0
# R2_score of LinearRegression  0.43306475730255156 at random_state  120
# R2 score of lr1  99.95276534529854 at random_state  0
# R2_score of LinearRegression  0.3987223183802785 at random_state  121
# R2 score of lr1  99.95276534529854 at random_state  0
# R2_score of LinearRegression  0.46109885440783993 at random_state  122
# R2 score of lr1  99.95276534529854 at random_state  0
# R2_score of LinearRegression  0.3947425744768148 at random_state  123
# R2 score of lr1  99.95276534529854 at random_state  0
# R2_score of LinearRegression  0.423044353675904 at random_state  124
# R2 score of lr1  99.95276534529854 at random_state  0
# R2_score of LinearRegression  0.41673511113384165 at random_state  125
# R2 score of lr1  99.95276534529854 at random_state  0
# R2_score of LinearRegression  0.4090764340680798 at random_state  126
# R2 score of lr1  99.95276534529854 at random_state  0
# R2_score of LinearRegression  0.42740833445775117 at random_state  127
# R2 score of lr1  99.95276534529854 at random_state  0
# R2_score of LinearRegression  0.43337640935695976 at random_state  128
# R2 score of lr1  99.95276534529854 at random_state  0
# R2_score of LinearRegression  0.3881511477982029 at random_state  129
# R2 score of lr1  99.95276534529854 at random_state  0
# R2_score of LinearRegression  0.4361177496282326 at random_state  130
# R2 score of lr1  99.95276534529854 at random_state  0
# R2_score of LinearRegression  0.4739793082054957 at random_state  131
# R2 score of lr1  99.95276534529854 at random_state  0
# R2_score of LinearRegression  0.4614139448974841 at random_state  132
# R2 score of lr1  99.95276534529854 at random_state  0
# R2_score of LinearRegression  0.4363721716887906 at random_state  133
# R2 score of lr1  99.95276534529854 at random_state  0
# R2_score of LinearRegression  0.38569417379018955 at random_state  134
# R2 score of lr1  99.95276534529854 at random_state  0
# R2_score of LinearRegression  0.4756627873882143 at random_state  135
# R2 score of lr1  99.95276534529854 at random_state  0
# R2_score of LinearRegression  0.44193724633360776 at random_state  136
# R2 score of lr1  99.95276534529854 at random_state  0
# R2_score of LinearRegression  0.4505764406735281 at random_state  137
# R2 score of lr1  99.95276534529854 at random_state  0
# R2_score of LinearRegression  0.4477806569409243 at random_state  138
# R2 score of lr1  99.95276534529854 at random_state  0
# R2_score of LinearRegression  0.4271585681086022 at random_state  139
# R2 score of lr1  99.95276534529854 at random_state  0
# R2_score of LinearRegression  0.45335688243163397 at random_state  140
# R2 score of lr1  99.95276534529854 at random_state  0
# R2_score of LinearRegression  0.4573613470837642 at random_state  141
# R2 score of lr1  99.95276534529854 at random_state  0
# R2_score of LinearRegression  0.38280313000289756 at random_state  142
# R2 score of lr1  99.95276534529854 at random_state  0
# R2_score of LinearRegression  0.447218567381636 at random_state  143
# R2 score of lr1  99.95276534529854 at random_state  0
# R2_score of LinearRegression  0.42945415773498297 at random_state  144
# R2 score of lr1  99.95276534529854 at random_state  0
# R2_score of LinearRegression  0.42143399094827416 at random_state  145
# R2 score of lr1  99.95276534529854 at random_state  0
# R2_score of LinearRegression  0.40210264070971424 at random_state  146
# R2 score of lr1  99.95276534529854 at random_state  0
# R2_score of LinearRegression  0.41080017069397556 at random_state  147
# R2 score of lr1  99.95276534529854 at random_state  0
# R2_score of LinearRegression  0.46894119356665953 at random_state  148
# R2 score of lr1  99.95276534529854 at random_state  0
# R2_score of LinearRegression  0.40768050388324883 at random_state  149
# R2 score of lr1  99.95276534529854 at random_state  0
# R2_score of LinearRegression  0.3747455215788107 at random_state  150
# R2 score of lr1  99.95276534529854 at random_state  0
# R2_score of LinearRegression  0.44087290147812597 at random_state  151
# R2 score of lr1  99.95276534529854 at random_state  0
# R2_score of LinearRegression  0.3817020516993995 at random_state  152
# R2 score of lr1  99.95276534529854 at random_state  0
# R2_score of LinearRegression  0.4148871760184967 at random_state  153
# R2 score of lr1  99.95276534529854 at random_state  0
# R2_score of LinearRegression  0.4475706230372558 at random_state  154
# R2 score of lr1  99.95276534529854 at random_state  0
# R2_score of LinearRegression  0.4572912107525744 at random_state  155
# R2 score of lr1  99.95276534529854 at random_state  0
# R2_score of LinearRegression  0.43890877220066504 at random_state  156
# R2 score of lr1  99.95276534529854 at random_state  0
# R2_score of LinearRegression  0.435664791233598 at random_state  157
# R2 score of lr1  99.95276534529854 at random_state  0
# R2_score of LinearRegression  0.4094488956509771 at random_state  158
# R2 score of lr1  99.95276534529854 at random_state  0
# R2_score of LinearRegression  0.43290128232205216 at random_state  159
# R2 score of lr1  99.95276534529854 at random_state  0
# R2_score of LinearRegression  0.4077349564158558 at random_state  160
# R2 score of lr1  99.95276534529854 at random_state  0
# R2_score of LinearRegression  0.43111397845973476 at random_state  161
# R2 score of lr1  99.95276534529854 at random_state  0
# R2_score of LinearRegression  0.38408906697459944 at random_state  162
# R2 score of lr1  99.95276534529854 at random_state  0
# R2_score of LinearRegression  0.4185033765877584 at random_state  163
# R2 score of lr1  99.95276534529854 at random_state  0
# R2_score of LinearRegression  0.41945876536705273 at random_state  164
# R2 score of lr1  99.95276534529854 at random_state  0
# R2_score of LinearRegression  0.46018119943292635 at random_state  165
# R2 score of lr1  99.95276534529854 at random_state  0
# R2_score of LinearRegression  0.4186314872176672 at random_state  166
# R2 score of lr1  99.95276534529854 at random_state  0
# R2_score of LinearRegression  0.45620411273529216 at random_state  167
# R2 score of lr1  99.95276534529854 at random_state  0
# R2_score of LinearRegression  0.4363339054491867 at random_state  168
# R2 score of lr1  99.95276534529854 at random_state  0
# R2_score of LinearRegression  0.4221833742369875 at random_state  169
# R2 score of lr1  99.95276534529854 at random_state  0
# R2_score of LinearRegression  0.47561712237912823 at random_state  170
# R2 score of lr1  99.95276534529854 at random_state  0
# R2_score of LinearRegression  0.37434611896390135 at random_state  171
# R2 score of lr1  99.95276534529854 at random_state  0
# R2_score of LinearRegression  0.4052377692178418 at random_state  172
# R2 score of lr1  99.95276534529854 at random_state  0
# R2_score of LinearRegression  0.3671623978240851 at random_state  173
# R2 score of lr1  99.95276534529854 at random_state  0
# R2_score of LinearRegression  0.4497366368411596 at random_state  174
# R2 score of lr1  99.95276534529854 at random_state  0
# R2_score of LinearRegression  0.4462267638714844 at random_state  175
# R2 score of lr1  99.95276534529854 at random_state  0
# R2_score of LinearRegression  0.4189401157499638 at random_state  176
# R2 score of lr1  99.95276534529854 at random_state  0
# R2_score of LinearRegression  0.4115202094315039 at random_state  177
# R2 score of lr1  99.95276534529854 at random_state  0
# R2_score of LinearRegression  0.4223918791583471 at random_state  178
# R2 score of lr1  99.95276534529854 at random_state  0
# R2_score of LinearRegression  0.4528227833365993 at random_state  179
# R2 score of lr1  99.95276534529854 at random_state  0
# R2_score of LinearRegression  0.4439061532111287 at random_state  180
# R2 score of lr1  99.95276534529854 at random_state  0
# R2_score of LinearRegression  0.4545749661348465 at random_state  181
# R2 score of lr1  99.95276534529854 at random_state  0
# R2_score of LinearRegression  0.4531629162134758 at random_state  182
# R2 score of lr1  99.95276534529854 at random_state  0
# R2_score of LinearRegression  0.4425522710577877 at random_state  183
# R2 score of lr1  99.95276534529854 at random_state  0
# R2_score of LinearRegression  0.43013447247234515 at random_state  184
# R2 score of lr1  99.95276534529854 at random_state  0
# R2_score of LinearRegression  0.4110836423409221 at random_state  185
# R2 score of lr1  99.95276534529854 at random_state  0
# R2_score of LinearRegression  0.3893339767541154 at random_state  186
# R2 score of lr1  99.95276534529854 at random_state  0
# R2_score of LinearRegression  0.44351726350425436 at random_state  187
# R2 score of lr1  99.95276534529854 at random_state  0
# R2_score of LinearRegression  0.4514959041829024 at random_state  188
# R2 score of lr1  99.95276534529854 at random_state  0
# R2_score of LinearRegression  0.38482973963211553 at random_state  189
# R2 score of lr1  99.95276534529854 at random_state  0
# R2_score of LinearRegression  0.46267508306425065 at random_state  190
# R2 score of lr1  99.95276534529854 at random_state  0
# R2_score of LinearRegression  0.4152807423138942 at random_state  191
# R2 score of lr1  99.95276534529854 at random_state  0
# R2_score of LinearRegression  0.4097041446686277 at random_state  192
# R2 score of lr1  99.95276534529854 at random_state  0
# R2_score of LinearRegression  0.44491321405784023 at random_state  193
# R2 score of lr1  99.95276534529854 at random_state  0
# R2_score of LinearRegression  0.4704785290018799 at random_state  194
# R2 score of lr1  99.95276534529854 at random_state  0
# R2_score of LinearRegression  0.47271302885673316 at random_state  195
# R2 score of lr1  99.95276534529854 at random_state  0
# R2_score of LinearRegression  0.3669065622230153 at random_state  196
# R2 score of lr1  99.95276534529854 at random_state  0
# R2_score of LinearRegression  0.3988783102530399 at random_state  197
# R2 score of lr1  99.95276534529854 at random_state  0
# R2_score of LinearRegression  0.4038177295219435 at random_state  198
# R2 score of lr1  99.95276534529854 at random_state  0
# R2_score of LinearRegression  0.4104419328162606 at random_state  199
# R2 score of lr1  99.95276534529854 at random_state  0
# R2_score of LinearRegression  0.4252414527551531 at random_state  200
# R2 score of lr1  99.95276534529854 at random_state  0
# R2_score of LinearRegression  0.4285821625910652 at random_state  201
# R2 score of lr1  99.95276534529854 at random_state  0
# R2_score of LinearRegression  0.42818932956476774 at random_state  202
# R2 score of lr1  99.95276534529854 at random_state  0
# R2_score of LinearRegression  0.4268803140171942 at random_state  203
# R2 score of lr1  99.95276534529854 at random_state  0
# R2_score of LinearRegression  0.4000775926492579 at random_state  204
# R2 score of lr1  99.95276534529854 at random_state  0
# R2_score of LinearRegression  0.45148099299949285 at random_state  205
# R2 score of lr1  99.95276534529854 at random_state  0
# R2_score of LinearRegression  0.4332345064543277 at random_state  206
# R2 score of lr1  99.95276534529854 at random_state  0
# R2_score of LinearRegression  0.41124118783584174 at random_state  207
# R2 score of lr1  99.95276534529854 at random_state  0
# R2_score of LinearRegression  0.4369528790455126 at random_state  208
# R2 score of lr1  99.95276534529854 at random_state  0
# R2_score of LinearRegression  0.41788001532898733 at random_state  209
# R2 score of lr1  99.95276534529854 at random_state  0
# R2_score of LinearRegression  0.4329734074435492 at random_state  210
# R2 score of lr1  99.95276534529854 at random_state  0
# R2_score of LinearRegression  0.40445126667626485 at random_state  211
# R2 score of lr1  99.95276534529854 at random_state  0
# R2_score of LinearRegression  0.45546585224870206 at random_state  212
# R2 score of lr1  99.95276534529854 at random_state  0
# R2_score of LinearRegression  0.4455023540109634 at random_state  213
# R2 score of lr1  99.95276534529854 at random_state  0
# R2_score of LinearRegression  0.4079323263447735 at random_state  214
# R2 score of lr1  99.95276534529854 at random_state  0
# R2_score of LinearRegression  0.4296217750612178 at random_state  215
# R2 score of lr1  99.95276534529854 at random_state  0
# R2_score of LinearRegression  0.3968850532621777 at random_state  216
# R2 score of lr1  99.95276534529854 at random_state  0
# R2_score of LinearRegression  0.3867908640301996 at random_state  217
# R2 score of lr1  99.95276534529854 at random_state  0
# R2_score of LinearRegression  0.41627732132948914 at random_state  218
# R2 score of lr1  99.95276534529854 at random_state  0
# R2_score of LinearRegression  0.4020749289971811 at random_state  219
# R2 score of lr1  99.95276534529854 at random_state  0
# R2_score of LinearRegression  0.40216190349611614 at random_state  220
# R2 score of lr1  99.95276534529854 at random_state  0
# R2_score of LinearRegression  0.4569100196481404 at random_state  221
# R2 score of lr1  99.95276534529854 at random_state  0
# R2_score of LinearRegression  0.39972896855984796 at random_state  222
# R2 score of lr1  99.95276534529854 at random_state  0
# R2_score of LinearRegression  0.4387055388541906 at random_state  223
# R2 score of lr1  99.95276534529854 at random_state  0
# R2_score of LinearRegression  0.37759433709639156 at random_state  224
# R2 score of lr1  99.95276534529854 at random_state  0
# R2_score of LinearRegression  0.4433446014793888 at random_state  225
# R2 score of lr1  99.95276534529854 at random_state  0
# R2_score of LinearRegression  0.442610533306092 at random_state  226
# R2 score of lr1  99.95276534529854 at random_state  0
# R2_score of LinearRegression  0.4367215629234865 at random_state  227
# R2 score of lr1  99.95276534529854 at random_state  0
# R2_score of LinearRegression  0.4203715585625746 at random_state  228
# R2 score of lr1  99.95276534529854 at random_state  0
# R2_score of LinearRegression  0.4262344164766566 at random_state  229
# R2 score of lr1  99.95276534529854 at random_state  0
# R2_score of LinearRegression  0.43317564901061845 at random_state  230
# R2 score of lr1  99.95276534529854 at random_state  0
# R2_score of LinearRegression  0.41028745361468 at random_state  231
# R2 score of lr1  99.95276534529854 at random_state  0
# R2_score of LinearRegression  0.445585303726165 at random_state  232
# R2 score of lr1  99.95276534529854 at random_state  0
# R2_score of LinearRegression  0.43203702488778684 at random_state  233
# R2 score of lr1  99.95276534529854 at random_state  0
# R2_score of LinearRegression  0.3839106638369938 at random_state  234
# R2 score of lr1  99.95276534529854 at random_state  0
# R2_score of LinearRegression  0.40935095345326933 at random_state  235
# R2 score of lr1  99.95276534529854 at random_state  0
# R2_score of LinearRegression  0.49270412314513856 at random_state  236
# R2 score of lr1  99.95276534529854 at random_state  0
# R2_score of LinearRegression  0.4494796277761587 at random_state  237
# R2 score of lr1  99.95276534529854 at random_state  0
# R2_score of LinearRegression  0.4075638186110626 at random_state  238
# R2 score of lr1  99.95276534529854 at random_state  0
# R2_score of LinearRegression  0.45943781674040696 at random_state  239
# R2 score of lr1  99.95276534529854 at random_state  0
# R2_score of LinearRegression  0.44888352807677523 at random_state  240
# R2 score of lr1  99.95276534529854 at random_state  0
# R2_score of LinearRegression  0.429058368334995 at random_state  241
# R2 score of lr1  99.95276534529854 at random_state  0
# R2_score of LinearRegression  0.43279765233837875 at random_state  242
# R2 score of lr1  99.95276534529854 at random_state  0
# R2_score of LinearRegression  0.4719431636909883 at random_state  243
# R2 score of lr1  99.95276534529854 at random_state  0
# R2_score of LinearRegression  0.43076956830293656 at random_state  244
# R2 score of lr1  99.95276534529854 at random_state  0
# R2_score of LinearRegression  0.43945891382364255 at random_state  245
# R2 score of lr1  99.95276534529854 at random_state  0
# R2_score of LinearRegression  0.4318374321383823 at random_state  246
# R2 score of lr1  99.95276534529854 at random_state  0
# R2_score of LinearRegression  0.4511093697329863 at random_state  247
# R2 score of lr1  99.95276534529854 at random_state  0
# R2_score of LinearRegression  0.48959326810600656 at random_state  248
# R2 score of lr1  99.95276534529854 at random_state  0
# R2_score of LinearRegression  0.40221792899551945 at random_state  249
# R2 score of lr1  99.95276534529854 at random_state  0
# R2_score of LinearRegression  0.36992504543263394 at random_state  250
# R2 score of lr1  99.95276534529854 at random_state  0
# R2_score of LinearRegression  0.43209105003298354 at random_state  251
# R2 score of lr1  99.95276534529854 at random_state  0
# R2_score of LinearRegression  0.4280522593216324 at random_state  252
# R2 score of lr1  99.95276534529854 at random_state  0
# R2_score of LinearRegression  0.3830072702644346 at random_state  253
# R2 score of lr1  99.95276534529854 at random_state  0
# R2_score of LinearRegression  0.44850079483445826 at random_state  254
# R2 score of lr1  99.95276534529854 at random_state  0
# R2_score of LinearRegression  0.3953574547410805 at random_state  255
# R2 score of lr1  99.95276534529854 at random_state  0
# R2_score of LinearRegression  0.4265982844712939 at random_state  256
# R2 score of lr1  99.95276534529854 at random_state  0
# R2_score of LinearRegression  0.43882387972560644 at random_state  257
# R2 score of lr1  99.95276534529854 at random_state  0
# R2_score of LinearRegression  0.3775854694345864 at random_state  258
# R2 score of lr1  99.95276534529854 at random_state  0
# R2_score of LinearRegression  0.45247622274359767 at random_state  259
# R2 score of lr1  99.95276534529854 at random_state  0
# R2_score of LinearRegression  0.39796633843506335 at random_state  260
# R2 score of lr1  99.95276534529854 at random_state  0
# R2_score of LinearRegression  0.38617365955134886 at random_state  261
# R2 score of lr1  99.95276534529854 at random_state  0
# R2_score of LinearRegression  0.4652187013544816 at random_state  262
# R2 score of lr1  99.95276534529854 at random_state  0
# R2_score of LinearRegression  0.3994186460566552 at random_state  263
# R2 score of lr1  99.95276534529854 at random_state  0
# R2_score of LinearRegression  0.4199059267791404 at random_state  264
# R2 score of lr1  99.95276534529854 at random_state  0
# R2_score of LinearRegression  0.43224611637977506 at random_state  265
# R2 score of lr1  99.95276534529854 at random_state  0
# R2_score of LinearRegression  0.38475032894341066 at random_state  266
# R2 score of lr1  99.95276534529854 at random_state  0
# R2_score of LinearRegression  0.4214696123466155 at random_state  267
# R2 score of lr1  99.95276534529854 at random_state  0
# R2_score of LinearRegression  0.38496589352359833 at random_state  268
# R2 score of lr1  99.95276534529854 at random_state  0
# R2_score of LinearRegression  0.4044541704875756 at random_state  269
# R2 score of lr1  99.95276534529854 at random_state  0
# R2_score of LinearRegression  0.4437483517377745 at random_state  270
# R2 score of lr1  99.95276534529854 at random_state  0
# R2_score of LinearRegression  0.3897691324518464 at random_state  271
# R2 score of lr1  99.95276534529854 at random_state  0
# R2_score of LinearRegression  0.40744646433210574 at random_state  272
# R2 score of lr1  99.95276534529854 at random_state  0
# R2_score of LinearRegression  0.44063191275010183 at random_state  273
# R2 score of lr1  99.95276534529854 at random_state  0
# R2_score of LinearRegression  0.46835292915578386 at random_state  274
# R2 score of lr1  99.95276534529854 at random_state  0
# R2_score of LinearRegression  0.44765061261645056 at random_state  275
# R2 score of lr1  99.95276534529854 at random_state  0
# R2_score of LinearRegression  0.42597775363301826 at random_state  276
# R2 score of lr1  99.95276534529854 at random_state  0
# R2_score of LinearRegression  0.42947322942367294 at random_state  277
# R2 score of lr1  99.95276534529854 at random_state  0
# R2_score of LinearRegression  0.39013948998539283 at random_state  278
# R2 score of lr1  99.95276534529854 at random_state  0
# R2_score of LinearRegression  0.39782020457839906 at random_state  279
# R2 score of lr1  99.95276534529854 at random_state  0
# R2_score of LinearRegression  0.38216406850348605 at random_state  280
# R2 score of lr1  99.95276534529854 at random_state  0
# R2_score of LinearRegression  0.4219227457482504 at random_state  281
# R2 score of lr1  99.95276534529854 at random_state  0
# R2_score of LinearRegression  0.4297417186802689 at random_state  282
# R2 score of lr1  99.95276534529854 at random_state  0
# R2_score of LinearRegression  0.4320597133697477 at random_state  283
# R2 score of lr1  99.95276534529854 at random_state  0
# R2_score of LinearRegression  0.47128055611814357 at random_state  284
# R2 score of lr1  99.95276534529854 at random_state  0
# R2_score of LinearRegression  0.4305182316816374 at random_state  285
# R2 score of lr1  99.95276534529854 at random_state  0
# R2_score of LinearRegression  0.40827885314104795 at random_state  286
# R2 score of lr1  99.95276534529854 at random_state  0
# R2_score of LinearRegression  0.4653918699303352 at random_state  287
# R2 score of lr1  99.95276534529854 at random_state  0
# R2_score of LinearRegression  0.34802617728586893 at random_state  288
# R2 score of lr1  99.95276534529854 at random_state  0
# R2_score of LinearRegression  0.4379639383502206 at random_state  289
# R2 score of lr1  99.95276534529854 at random_state  0
# R2_score of LinearRegression  0.4236197676856328 at random_state  290
# R2 score of lr1  99.95276534529854 at random_state  0
# R2_score of LinearRegression  0.46571478852945536 at random_state  291
# R2 score of lr1  99.95276534529854 at random_state  0
# R2_score of LinearRegression  0.3954928106714407 at random_state  292
# R2 score of lr1  99.95276534529854 at random_state  0
# R2_score of LinearRegression  0.4491022582130827 at random_state  293
# R2 score of lr1  99.95276534529854 at random_state  0
# R2_score of LinearRegression  0.34701458606158697 at random_state  294
# R2 score of lr1  99.95276534529854 at random_state  0
# R2_score of LinearRegression  0.4261497697158625 at random_state  295
# R2 score of lr1  99.95276534529854 at random_state  0
# R2_score of LinearRegression  0.41435525925099426 at random_state  296
# R2 score of lr1  99.95276534529854 at random_state  0
# R2_score of LinearRegression  0.3735571069145023 at random_state  297
# R2 score of lr1  99.95276534529854 at random_state  0
# R2_score of LinearRegression  0.4778845515639448 at random_state  298
# R2 score of lr1  99.95276534529854 at random_state  0
# R2_score of LinearRegression  0.3842215514102617 at random_state  299
# R2 score of lr1  99.95276534529854 at random_state  0
# R2_score of LinearRegression  0.44836221261373044 at random_state  300
# R2 score of lr1  99.95276534529854 at random_state  0
# R2_score of LinearRegression  0.42847127439942156 at random_state  301
# R2 score of lr1  99.95276534529854 at random_state  0
# R2_score of LinearRegression  0.43255167587373455 at random_state  302
# R2 score of lr1  99.95276534529854 at random_state  0
# R2_score of LinearRegression  0.43976000348248523 at random_state  303
# R2 score of lr1  99.95276534529854 at random_state  0
# R2_score of LinearRegression  0.3666225014259715 at random_state  304
# R2 score of lr1  99.95276534529854 at random_state  0
# R2_score of LinearRegression  0.4494112624882055 at random_state  305
# R2 score of lr1  99.95276534529854 at random_state  0
# R2_score of LinearRegression  0.3498160686955444 at random_state  306
# R2 score of lr1  99.95276534529854 at random_state  0
# R2_score of LinearRegression  0.40069101517542594 at random_state  307
# R2 score of lr1  99.95276534529854 at random_state  0
# R2_score of LinearRegression  0.40378661869627075 at random_state  308
# R2 score of lr1  99.95276534529854 at random_state  0
# R2_score of LinearRegression  0.4110155150331881 at random_state  309
# R2 score of lr1  99.95276534529854 at random_state  0
# R2_score of LinearRegression  0.40583964816887874 at random_state  310
# R2 score of lr1  99.95276534529854 at random_state  0
# R2_score of LinearRegression  0.4826830761187251 at random_state  311
# R2 score of lr1  99.95276534529854 at random_state  0
# R2_score of LinearRegression  0.43658995033507775 at random_state  312
# R2 score of lr1  99.95276534529854 at random_state  0
# R2_score of LinearRegression  0.45630070125470723 at random_state  313
# R2 score of lr1  99.95276534529854 at random_state  0
# R2_score of LinearRegression  0.37667429861789836 at random_state  314
# R2 score of lr1  99.95276534529854 at random_state  0
# R2_score of LinearRegression  0.38905866552700374 at random_state  315
# R2 score of lr1  99.95276534529854 at random_state  0
# R2_score of LinearRegression  0.43980842348088933 at random_state  316
# R2 score of lr1  99.95276534529854 at random_state  0
# R2_score of LinearRegression  0.40636728139462264 at random_state  317
# R2 score of lr1  99.95276534529854 at random_state  0
# R2_score of LinearRegression  0.41937907119138707 at random_state  318
# R2 score of lr1  99.95276534529854 at random_state  0
# R2_score of LinearRegression  0.4388621132455809 at random_state  319
# R2 score of lr1  99.95276534529854 at random_state  0
# R2_score of LinearRegression  0.3850891569586288 at random_state  320
# R2 score of lr1  99.95276534529854 at random_state  0
# R2_score of LinearRegression  0.41620494991234724 at random_state  321
# R2 score of lr1  99.95276534529854 at random_state  0
# R2_score of LinearRegression  0.4924362665123231 at random_state  322
# R2 score of lr1  99.95276534529854 at random_state  0
# R2_score of LinearRegression  0.4696362490657131 at random_state  323
# R2 score of lr1  99.95276534529854 at random_state  0
# R2_score of LinearRegression  0.38810091884397546 at random_state  324
# R2 score of lr1  99.95276534529854 at random_state  0
# R2_score of LinearRegression  0.4085544772360765 at random_state  325
# R2 score of lr1  99.95276534529854 at random_state  0
# R2_score of LinearRegression  0.4226902910608572 at random_state  326
# R2 score of lr1  99.95276534529854 at random_state  0
# R2_score of LinearRegression  0.45931676369031627 at random_state  327
# R2 score of lr1  99.95276534529854 at random_state  0
# R2_score of LinearRegression  0.45143103153266984 at random_state  328
# R2 score of lr1  99.95276534529854 at random_state  0
# R2_score of LinearRegression  0.44326097062334735 at random_state  329
# R2 score of lr1  99.95276534529854 at random_state  0
# R2_score of LinearRegression  0.42431713207140265 at random_state  330
# R2 score of lr1  99.95276534529854 at random_state  0
# R2_score of LinearRegression  0.38171094961679564 at random_state  331
# R2 score of lr1  99.95276534529854 at random_state  0
# R2_score of LinearRegression  0.4158583687723898 at random_state  332
# R2 score of lr1  99.95276534529854 at random_state  0
# R2_score of LinearRegression  0.4129815958636005 at random_state  333
# R2 score of lr1  99.95276534529854 at random_state  0
# R2_score of LinearRegression  0.406302519002684 at random_state  334
# R2 score of lr1  99.95276534529854 at random_state  0
# R2_score of LinearRegression  0.4307450958116944 at random_state  335
# R2 score of lr1  99.95276534529854 at random_state  0
# R2_score of LinearRegression  0.40734192178206585 at random_state  336
# R2 score of lr1  99.95276534529854 at random_state  0
# R2_score of LinearRegression  0.4741862810734433 at random_state  337
# R2 score of lr1  99.95276534529854 at random_state  0
# R2_score of LinearRegression  0.4181869613564746 at random_state  338
# R2 score of lr1  99.95276534529854 at random_state  0
# R2_score of LinearRegression  0.45884580899289074 at random_state  339
# R2 score of lr1  99.95276534529854 at random_state  0
# R2_score of LinearRegression  0.46068534520429316 at random_state  340
# R2 score of lr1  99.95276534529854 at random_state  0
# R2_score of LinearRegression  0.47946569069880696 at random_state  341
# R2 score of lr1  99.95276534529854 at random_state  0
# R2_score of LinearRegression  0.4802400574082447 at random_state  342
# R2 score of lr1  99.95276534529854 at random_state  0
# R2_score of LinearRegression  0.4053479197761958 at random_state  343
# R2 score of lr1  99.95276534529854 at random_state  0
# R2_score of LinearRegression  0.4609436548467125 at random_state  344
# R2 score of lr1  99.95276534529854 at random_state  0
# R2_score of LinearRegression  0.5058517991272191 at random_state  345
# R2 score of lr1  99.95276534529854 at random_state  0
# R2_score of LinearRegression  0.4234877353631493 at random_state  346
# R2 score of lr1  99.95276534529854 at random_state  0
# R2_score of LinearRegression  0.4166860865350709 at random_state  347
# R2 score of lr1  99.95276534529854 at random_state  0
# R2_score of LinearRegression  0.3978839885439427 at random_state  348
# R2 score of lr1  99.95276534529854 at random_state  0
# R2_score of LinearRegression  0.4569628708705331 at random_state  349
# R2 score of lr1  99.95276534529854 at random_state  0
# R2_score of LinearRegression  0.43729174993456665 at random_state  350
# R2 score of lr1  99.95276534529854 at random_state  0
# R2_score of LinearRegression  0.3997603907608134 at random_state  351
# R2 score of lr1  99.95276534529854 at random_state  0
# R2_score of LinearRegression  0.380801922091067 at random_state  352
# R2 score of lr1  99.95276534529854 at random_state  0
# R2_score of LinearRegression  0.43815654722331365 at random_state  353
# R2 score of lr1  99.95276534529854 at random_state  0
# R2_score of LinearRegression  0.47447940726129256 at random_state  354
# R2 score of lr1  99.95276534529854 at random_state  0
# R2_score of LinearRegression  0.4249536770548943 at random_state  355
# R2 score of lr1  99.95276534529854 at random_state  0
# R2_score of LinearRegression  0.46778451027636503 at random_state  356
# R2 score of lr1  99.95276534529854 at random_state  0
# R2_score of LinearRegression  0.4214776122098134 at random_state  357
# R2 score of lr1  99.95276534529854 at random_state  0
# R2_score of LinearRegression  0.4385217170679432 at random_state  358
# R2 score of lr1  99.95276534529854 at random_state  0
# R2_score of LinearRegression  0.3811080277865796 at random_state  359
# R2 score of lr1  99.95276534529854 at random_state  0
# R2_score of LinearRegression  0.48231909086003333 at random_state  360
# R2 score of lr1  99.95276534529854 at random_state  0
# R2_score of LinearRegression  0.38924250758889334 at random_state  361
# R2 score of lr1  99.95276534529854 at random_state  0
# R2_score of LinearRegression  0.41502765490989235 at random_state  362
# R2 score of lr1  99.95276534529854 at random_state  0
# R2_score of LinearRegression  0.39991309095405636 at random_state  363
# R2 score of lr1  99.95276534529854 at random_state  0
# R2_score of LinearRegression  0.40092364952885906 at random_state  364
# R2 score of lr1  99.95276534529854 at random_state  0
# R2_score of LinearRegression  0.4080568009191271 at random_state  365
# R2 score of lr1  99.95276534529854 at random_state  0
# R2_score of LinearRegression  0.42546077994476184 at random_state  366
# R2 score of lr1  99.95276534529854 at random_state  0
# R2_score of LinearRegression  0.4215774796374545 at random_state  367
# R2 score of lr1  99.95276534529854 at random_state  0
# R2_score of LinearRegression  0.44045941936131994 at random_state  368
# R2 score of lr1  99.95276534529854 at random_state  0
# R2_score of LinearRegression  0.4355417871182252 at random_state  369
# R2 score of lr1  99.95276534529854 at random_state  0
# R2_score of LinearRegression  0.4673081076766942 at random_state  370
# R2 score of lr1  99.95276534529854 at random_state  0
# R2_score of LinearRegression  0.3747675487889671 at random_state  371
# R2 score of lr1  99.95276534529854 at random_state  0
# R2_score of LinearRegression  0.4949525245717251 at random_state  372
# R2 score of lr1  99.95276534529854 at random_state  0
# R2_score of LinearRegression  0.3758342768074442 at random_state  373
# R2 score of lr1  99.95276534529854 at random_state  0
# R2_score of LinearRegression  0.43713693660942665 at random_state  374
# R2 score of lr1  99.95276534529854 at random_state  0
# R2_score of LinearRegression  0.4139316331373861 at random_state  375
# R2 score of lr1  99.95276534529854 at random_state  0
# R2_score of LinearRegression  0.40244936555521005 at random_state  376
# R2 score of lr1  99.95276534529854 at random_state  0
# R2_score of LinearRegression  0.43287369952301225 at random_state  377
# R2 score of lr1  99.95276534529854 at random_state  0
# R2_score of LinearRegression  0.46130305636043123 at random_state  378
# R2 score of lr1  99.95276534529854 at random_state  0
# R2_score of LinearRegression  0.42408126187577244 at random_state  379
# R2 score of lr1  99.95276534529854 at random_state  0
# R2_score of LinearRegression  0.4558839243655979 at random_state  380
# R2 score of lr1  99.95276534529854 at random_state  0
# R2_score of LinearRegression  0.4663554218749554 at random_state  381
# R2 score of lr1  99.95276534529854 at random_state  0
# R2_score of LinearRegression  0.4300379665071431 at random_state  382
# R2 score of lr1  99.95276534529854 at random_state  0
# R2_score of LinearRegression  0.4799469020651226 at random_state  383
# R2 score of lr1  99.95276534529854 at random_state  0
# R2_score of LinearRegression  0.40389519727899226 at random_state  384
# R2 score of lr1  99.95276534529854 at random_state  0
# R2_score of LinearRegression  0.39479852281024597 at random_state  385
# R2 score of lr1  99.95276534529854 at random_state  0
# R2_score of LinearRegression  0.40365623228157077 at random_state  386
# ...
# R2 score of lr1  99.95276534529854 at random_state  0
# R2_score of LinearRegression  0.4342715106428574 at random_state  872
# R2 score of lr1  99.95276534529854 at random_state  0
# R2_score of LinearRegression  0.4677879881084066 at random_state  873
# R2 score of lr1  99.95276534529854 at random_state  0
# R2_score of LinearRegression  0.37207009521395473 at random_state  874
# R2 score of lr1  99.95276534529854 at random_state  0
# R2_score of LinearRegression  0.42416930702713274 at random_state  875
# R2 score of lr1  99.95276534529854 at random_state  0
# R2_score of LinearRegression  0.41620384163296986 at random_state  876
# R2 score of lr1  99.95276534529854 at random_state  0
# R2_score of LinearRegression  0.39564091781012956 at random_state  877
# R2 score of lr1  99.95276534529854 at random_state  0
# R2_score of LinearRegression  0.42369527023001397 at random_state  878
# R2 score of lr1  99.95276534529854 at random_state  0
# R2_score of LinearRegression  0.36541458121777515 at random_state  879
# R2 score of lr1  99.95276534529854 at random_state  0
# R2_score of LinearRegression  0.4282301380038901 at random_state  880
# R2 score of lr1  99.95276534529854 at random_state  0
# R2_score of LinearRegression  0.38434639635259704 at random_state  881
# R2 score of lr1  99.95276534529854 at random_state  0
# R2_score of LinearRegression  0.43826994257416585 at random_state  882
# R2 score of lr1  99.95276534529854 at random_state  0
# R2_score of LinearRegression  0.45852556937215794 at random_state  883
# R2 score of lr1  99.95276534529854 at random_state  0
# R2_score of LinearRegression  0.47657702133502555 at random_state  884
# R2 score of lr1  99.95276534529854 at random_state  0
# R2_score of LinearRegression  0.39853041233802333 at random_state  885
# R2 score of lr1  99.95276534529854 at random_state  0
# R2_score of LinearRegression  0.3937455998784559 at random_state  886
# R2 score of lr1  99.95276534529854 at random_state  0
# R2_score of LinearRegression  0.42392063008246617 at random_state  887
# R2 score of lr1  99.95276534529854 at random_state  0
# R2_score of LinearRegression  0.4889617812991768 at random_state  888
# R2 score of lr1  99.95276534529854 at random_state  0
# R2_score of LinearRegression  0.44774034527031226 at random_state  889
# R2 score of lr1  99.95276534529854 at random_state  0
# R2_score of LinearRegression  0.4520751400021582 at random_state  890
# R2 score of lr1  99.95276534529854 at random_state  0
# R2_score of LinearRegression  0.42781257094035396 at random_state  891
# R2 score of lr1  99.95276534529854 at random_state  0
# R2_score of LinearRegression  0.49452006241705326 at random_state  892
# R2 score of lr1  99.95276534529854 at random_state  0
# R2_score of LinearRegression  0.43647316504541667 at random_state  893
# R2 score of lr1  99.95276534529854 at random_state  0
# R2_score of LinearRegression  0.42600624347180505 at random_state  894
# R2 score of lr1  99.95276534529854 at random_state  0
# R2_score of LinearRegression  0.4404351399336537 at random_state  895
# R2 score of lr1  99.95276534529854 at random_state  0
# R2_score of LinearRegression  0.44106014723032594 at random_state  896
# R2 score of lr1  99.95276534529854 at random_state  0
# R2_score of LinearRegression  0.42935734856926233 at random_state  897
# R2 score of lr1  99.95276534529854 at random_state  0
# R2_score of LinearRegression  0.43574998486211436 at random_state  898
# R2 score of lr1  99.95276534529854 at random_state  0
# R2_score of LinearRegression  0.4380704151249323 at random_state  899
# R2 score of lr1  99.95276534529854 at random_state  0
# R2_score of LinearRegression  0.4381713964528442 at random_state  900
# R2 score of lr1  99.95276534529854 at random_state  0
# R2_score of LinearRegression  0.4355026442754304 at random_state  901
# R2 score of lr1  99.95276534529854 at random_state  0
# R2_score of LinearRegression  0.47561458899511666 at random_state  902
# R2 score of lr1  99.95276534529854 at random_state  0
# R2_score of LinearRegression  0.42812542246398244 at random_state  903
# R2 score of lr1  99.95276534529854 at random_state  0
# R2_score of LinearRegression  0.4469761838890368 at random_state  904
# R2 score of lr1  99.95276534529854 at random_state  0
# R2_score of LinearRegression  0.42197393699658625 at random_state  905
# R2 score of lr1  99.95276534529854 at random_state  0
# R2_score of LinearRegression  0.45256994794166516 at random_state  906
# R2 score of lr1  99.95276534529854 at random_state  0
# R2_score of LinearRegression  0.410345952061959 at random_state  907
# R2 score of lr1  99.95276534529854 at random_state  0
# R2_score of LinearRegression  0.4159214030594951 at random_state  908
# R2 score of lr1  99.95276534529854 at random_state  0
# R2_score of LinearRegression  0.4111344593845908 at random_state  909
# R2 score of lr1  99.95276534529854 at random_state  0
# R2_score of LinearRegression  0.4289223769507772 at random_state  910
# R2 score of lr1  99.95276534529854 at random_state  0
# R2_score of LinearRegression  0.3740391781619036 at random_state  911
# R2 score of lr1  99.95276534529854 at random_state  0
# R2_score of LinearRegression  0.44238231470552114 at random_state  912
# R2 score of lr1  99.95276534529854 at random_state  0
# R2_score of LinearRegression  0.47686558398900847 at random_state  913
# R2 score of lr1  99.95276534529854 at random_state  0
# R2_score of LinearRegression  0.42744102414368956 at random_state  914
# R2 score of lr1  99.95276534529854 at random_state  0
# R2_score of LinearRegression  0.47149130296098096 at random_state  915
# R2 score of lr1  99.95276534529854 at random_state  0
# R2_score of LinearRegression  0.424535653817511 at random_state  916
# R2 score of lr1  99.95276534529854 at random_state  0
# R2_score of LinearRegression  0.43488271817312363 at random_state  917
# R2 score of lr1  99.95276534529854 at random_state  0
# R2_score of LinearRegression  0.43361509308112345 at random_state  918
# R2 score of lr1  99.95276534529854 at random_state  0
# R2_score of LinearRegression  0.4289962423543183 at random_state  919
# R2 score of lr1  99.95276534529854 at random_state  0
# R2_score of LinearRegression  0.44538277986677 at random_state  920
# R2 score of lr1  99.95276534529854 at random_state  0
# R2_score of LinearRegression  0.4526552294703281 at random_state  921
# R2 score of lr1  99.95276534529854 at random_state  0
# R2_score of LinearRegression  0.45770749388501974 at random_state  922
# R2 score of lr1  99.95276534529854 at random_state  0
# R2_score of LinearRegression  0.48209878034982556 at random_state  923
# R2 score of lr1  99.95276534529854 at random_state  0
# R2_score of LinearRegression  0.45766807811621535 at random_state  924
# R2 score of lr1  99.95276534529854 at random_state  0
# R2_score of LinearRegression  0.4257117508779362 at random_state  925
# R2 score of lr1  99.95276534529854 at random_state  0
# R2_score of LinearRegression  0.43459277163204524 at random_state  926
# R2 score of lr1  99.95276534529854 at random_state  0
# R2_score of LinearRegression  0.44034735716580964 at random_state  927
# R2 score of lr1  99.95276534529854 at random_state  0
# R2_score of LinearRegression  0.4137061156563199 at random_state  928
# R2 score of lr1  99.95276534529854 at random_state  0
# R2_score of LinearRegression  0.36707787492875565 at random_state  929
# R2 score of lr1  99.95276534529854 at random_state  0
# R2_score of LinearRegression  0.41421302123955517 at random_state  930
# R2 score of lr1  99.95276534529854 at random_state  0
# R2_score of LinearRegression  0.42240055871358384 at random_state  931
# R2 score of lr1  99.95276534529854 at random_state  0
# R2_score of LinearRegression  0.4642062109945073 at random_state  932
# R2 score of lr1  99.95276534529854 at random_state  0
# R2_score of LinearRegression  0.4347083185585068 at random_state  933
# R2 score of lr1  99.95276534529854 at random_state  0
# R2_score of LinearRegression  0.42329103434741466 at random_state  934
# R2 score of lr1  99.95276534529854 at random_state  0
# R2_score of LinearRegression  0.3810813392474627 at random_state  935
# R2 score of lr1  99.95276534529854 at random_state  0
# R2_score of LinearRegression  0.43251544213446036 at random_state  936
# R2 score of lr1  99.95276534529854 at random_state  0
# R2_score of LinearRegression  0.4013222606115079 at random_state  937
# R2 score of lr1  99.95276534529854 at random_state  0
# R2_score of LinearRegression  0.4534211135109736 at random_state  938
# R2 score of lr1  99.95276534529854 at random_state  0
# R2_score of LinearRegression  0.42404581819617393 at random_state  939
# R2 score of lr1  99.95276534529854 at random_state  0
# R2_score of LinearRegression  0.41549124823412176 at random_state  940
# R2 score of lr1  99.95276534529854 at random_state  0
# R2_score of LinearRegression  0.44830057615415375 at random_state  941
# R2 score of lr1  99.95276534529854 at random_state  0
# R2_score of LinearRegression  0.3977272360222175 at random_state  942
# R2 score of lr1  99.95276534529854 at random_state  0
# R2_score of LinearRegression  0.4692863713768771 at random_state  943
# R2 score of lr1  99.95276534529854 at random_state  0
# R2_score of LinearRegression  0.4684108833920485 at random_state  944
# R2 score of lr1  99.95276534529854 at random_state  0
# R2_score of LinearRegression  0.41333505926886716 at random_state  945
# R2 score of lr1  99.95276534529854 at random_state  0
# R2_score of LinearRegression  0.4309294842601885 at random_state  946
# R2 score of lr1  99.95276534529854 at random_state  0
# R2_score of LinearRegression  0.41096741956598204 at random_state  947
# R2 score of lr1  99.95276534529854 at random_state  0
# R2_score of LinearRegression  0.46654228839714706 at random_state  948
# R2 score of lr1  99.95276534529854 at random_state  0
# R2_score of LinearRegression  0.4211141950014379 at random_state  949
# R2 score of lr1  99.95276534529854 at random_state  0
# R2_score of LinearRegression  0.43703294038471596 at random_state  950
# R2 score of lr1  99.95276534529854 at random_state  0
# R2_score of LinearRegression  0.3971385136736688 at random_state  951
# R2 score of lr1  99.95276534529854 at random_state  0
# R2_score of LinearRegression  0.4667757813715634 at random_state  952
# R2 score of lr1  99.95276534529854 at random_state  0
# R2_score of LinearRegression  0.3857825109348194 at random_state  953
# R2 score of lr1  99.95276534529854 at random_state  0
# R2_score of LinearRegression  0.44331838183176897 at random_state  954
# R2 score of lr1  99.95276534529854 at random_state  0
# R2_score of LinearRegression  0.3674036246912995 at random_state  955
# R2 score of lr1  99.95276534529854 at random_state  0
# R2_score of LinearRegression  0.4269064737564787 at random_state  956
# R2 score of lr1  99.95276534529854 at random_state  0
# R2_score of LinearRegression  0.42508487783329774 at random_state  957
# R2 score of lr1  99.95276534529854 at random_state  0
# R2_score of LinearRegression  0.43515261904448854 at random_state  958
# R2 score of lr1  99.95276534529854 at random_state  0
# R2_score of LinearRegression  0.38584475924579253 at random_state  959
# R2 score of lr1  99.95276534529854 at random_state  0
# R2_score of LinearRegression  0.3934130798715604 at random_state  960
# R2 score of lr1  99.95276534529854 at random_state  0
# R2_score of LinearRegression  0.44159357321895387 at random_state  961
# R2 score of lr1  99.95276534529854 at random_state  0
# R2_score of LinearRegression  0.4291245755878179 at random_state  962
# R2 score of lr1  99.95276534529854 at random_state  0
# R2_score of LinearRegression  0.4144826199764129 at random_state  963
# R2 score of lr1  99.95276534529854 at random_state  0
# R2_score of LinearRegression  0.43131318062827584 at random_state  964
# R2 score of lr1  99.95276534529854 at random_state  0
# R2_score of LinearRegression  0.4358470895562693 at random_state  965
# R2 score of lr1  99.95276534529854 at random_state  0
# R2_score of LinearRegression  0.4470550230475083 at random_state  966
# R2 score of lr1  99.95276534529854 at random_state  0
# R2_score of LinearRegression  0.4353416139140539 at random_state  967
# R2 score of lr1  99.95276534529854 at random_state  0
# R2_score of LinearRegression  0.42001327216236517 at random_state  968
# R2 score of lr1  99.95276534529854 at random_state  0
# R2_score of LinearRegression  0.4095979042656437 at random_state  969
# R2 score of lr1  99.95276534529854 at random_state  0
# R2_score of LinearRegression  0.4435799980939137 at random_state  970
# R2 score of lr1  99.95276534529854 at random_state  0
# R2_score of LinearRegression  0.4125299156393798 at random_state  971
# R2 score of lr1  99.95276534529854 at random_state  0
# R2_score of LinearRegression  0.40320843254756944 at random_state  972
# R2 score of lr1  99.95276534529854 at random_state  0
# R2_score of LinearRegression  0.4246587197214171 at random_state  973
# R2 score of lr1  99.95276534529854 at random_state  0
# R2_score of LinearRegression  0.37590587362898154 at random_state  974
# R2 score of lr1  99.95276534529854 at random_state  0
# R2_score of LinearRegression  0.4357313838569048 at random_state  975
# R2 score of lr1  99.95276534529854 at random_state  0
# R2_score of LinearRegression  0.445579818103487 at random_state  976
# R2 score of lr1  99.95276534529854 at random_state  0
# R2_score of LinearRegression  0.42618137085911456 at random_state  977
# R2 score of lr1  99.95276534529854 at random_state  0
# R2_score of LinearRegression  0.4232640030619452 at random_state  978
# R2 score of lr1  99.95276534529854 at random_state  0
# R2_score of LinearRegression  0.45581015166479155 at random_state  979
# R2 score of lr1  99.95276534529854 at random_state  0
# R2_score of LinearRegression  0.42335776067742426 at random_state  980
# R2 score of lr1  99.95276534529854 at random_state  0
# R2_score of LinearRegression  0.435472700808762 at random_state  981
# R2 score of lr1  99.95276534529854 at random_state  0
# R2_score of LinearRegression  0.4169161936294621 at random_state  982
# R2 score of lr1  99.95276534529854 at random_state  0
# R2_score of LinearRegression  0.4739053616969121 at random_state  983
# R2 score of lr1  99.95276534529854 at random_state  0
# R2_score of LinearRegression  0.4287104702975225 at random_state  984
# R2 score of lr1  99.95276534529854 at random_state  0
# R2_score of LinearRegression  0.45537965266560576 at random_state  985
# R2 score of lr1  99.95276534529854 at random_state  0
# R2_score of LinearRegression  0.37870818781583104 at random_state  986
# R2 score of lr1  99.95276534529854 at random_state  0
# R2_score of LinearRegression  0.41797150385325244 at random_state  987
# R2 score of lr1  99.95276534529854 at random_state  0
# R2_score of LinearRegression  0.42075022295057973 at random_state  988
# R2 score of lr1  99.95276534529854 at random_state  0
# R2_score of LinearRegression  0.3655019044141835 at random_state  989
# R2 score of lr1  99.95276534529854 at random_state  0
# R2_score of LinearRegression  0.4464619997752094 at random_state  990
# R2 score of lr1  99.95276534529854 at random_state  0
# R2_score of LinearRegression  0.4473218891251617 at random_state  991
# R2 score of lr1  99.95276534529854 at random_state  0
# R2_score of LinearRegression  0.403201188782204 at random_state  992
# R2 score of lr1  99.95276534529854 at random_state  0
# R2_score of LinearRegression  0.4373673490960668 at random_state  993
# R2 score of lr1  99.95276534529854 at random_state  0
# R2_score of LinearRegression  0.40513602858267184 at random_state  994
# R2 score of lr1  99.95276534529854 at random_state  0
# R2_score of LinearRegression  0.42945448777300643 at random_state  995
# R2 score of lr1  99.95276534529854 at random_state  0
# R2_score of LinearRegression  0.45575236526753693 at random_state  996
# R2 score of lr1  99.95276534529854 at random_state  0
# R2_score of LinearRegression  0.45393308270242605 at random_state  997
# R2 score of lr1  99.95276534529854 at random_state  0
# R2_score of LinearRegression  0.4024358523719581 at random_state  998
# R2 score of lr1  99.95276534529854 at random_state  0
# R2_score of LinearRegression  0.44110383166569966 at random_state  999
# R2 score of lr1  99.95276534529854 at random_state  0

# %% [markdown]
# # REGULARISATION

# %%
from sklearn.linear_model import Lasso,Ridge,ElasticNet
l1=Lasso()
r1=Ridge()
en1=ElasticNet()

# %%
models1=[l,r,en]
for i in models1:
    i.fit(x_train1,y_train1)
    alpha1=[0.001,0.001,0.01,0.1,1]
    for j in alpha1:
        predmodel1=i.predict(x_test1)
        print('R2_score : ' ,(r2_score(y_test1,predmodel1))*100, 'at model ',i,'with alpha ',j)
        print(mean_squared_error(y_test1,predmodel1))
        print(mean_absolute_error(y_test1,predmodel1))
# Out:
# R2_score :  40.70417688046285 at model  Lasso() with alpha  0.001
# 93.2664927380339
# 8.252712204516971
# R2_score :  40.70417688046285 at model  Lasso() with alpha  0.001
# 93.2664927380339
# 8.252712204516971
# R2_score :  40.70417688046285 at model  Lasso() with alpha  0.01
# 93.2664927380339
# 8.252712204516971
# R2_score :  40.70417688046285 at model  Lasso() with alpha  0.1
# 93.2664927380339
# 8.252712204516971
# R2_score :  40.70417688046285 at model  Lasso() with alpha  1
# 93.2664927380339
# 8.252712204516971
# R2_score :  44.09462721254512 at model  Ridge() with alpha  0.001
# 87.93364811863562
# 7.749077042919173
# R2_score :  44.09462721254512 at model  Ridge() with alpha  0.001
# 87.93364811863562
# 7.749077042919173
# R2_score :  44.09462721254512 at model  Ridge() with alpha  0.01
# 87.93364811863562
# 7.749077042919173
# R2_score :  44.09462721254512 at model  Ridge() with alpha  0.1
# 87.93364811863562
# 7.749077042919173
# R2_score :  44.09462721254512 at model  Ridge() with alpha  1
# 87.93364811863562
# 7.749077042919173
# R2_score :  41.295539304622096 at model  ElasticNet() with alpha  0.001
# 92.33633785803154
# 8.157169967745798
# R2_score :  41.295539304622096 at model  ElasticNet() with alpha  0.001
# 92.33633785803154
# 8.157169967745798
# R2_score :  41.295539304622096 at model  ElasticNet() with alpha  0.01
# 92.33633785803154
# 8.157169967745798
# R2_score :  41.295539304622096 at model  ElasticNet() with alpha  0.1
# 92.33633785803154
# 8.157169967745798
# R2_score :  41.295539304622096 at model  ElasticNet() with alpha  1
# 92.33633785803154
# 8.157169967745798

# %% [markdown]
# # TESTING MORE MODELS

# %%
from sklearn.neighbors import KNeighborsRegressor
from sklearn.ensemble import GradientBoostingRegressor,AdaBoostRegressor,ExtraTreesRegressor,RandomForestRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.svm import SVR
knr1=KNeighborsRegressor()
gbr1=GradientBoostingRegressor()
abr1=AdaBoostRegressor()
etr1=ExtraTreesRegressor()
rfr1=RandomForestRegressor()
dtr1=DecisionTreeRegressor()
svr1=SVR()

# %%
model1=[knr1,gbr1,abr1,etr1,rfr1,dtr1,svr1]
for i in model1:
    i.fit(x_train1,y_train1)
    predi1=i.predict(x_test1)
    print('R2_score of model ' , i ,'is = ' ,r2_score(y_test1,predi1)*100)
# Out:
# R2_score of model  KNeighborsRegressor() is =  100.0
# R2_score of model  GradientBoostingRegressor() is =  99.91471534020363
# R2_score of model  AdaBoostRegressor() is =  91.98141434596536
# R2_score of model  ExtraTreesRegressor() is =  100.0
# R2_score of model  RandomForestRegressor() is =  100.0
# R2_score of model  DecisionTreeRegressor() is =  100.0
# R2_score of model  SVR() is =  1.2570386367924735

# %% [markdown]
# # CROSS_VALIDATION

# %%
from sklearn.model_selection import cross_val_score

# %%
for i in range(2,10):
    models1=[lr1,knr1,gbr1,abr1,etr1,rfr1,dtr1,svr1]
    for j in models1:
        j.fit(x_train1,y_train1)
        predj1=j.predict(x_test1)
        score1=r2_score(y_test1,predj1)
        cross1=cross_val_score(j,x_train1,y_train1,cv=i)
        print('R2_score of model ' ,j, 'is equal = ', score1*100)
        print('Cross validation of model ',i, 'is equal = ',cross1.mean())
        print('Diff between r2_score and cross_validation of model ' ,j,'is equal = ',score1-cross1.mean())
# Out:
# R2_score of model  LinearRegression() is equal =  44.11038316656997
# Cross validation of model  2 is equal =  0.41495582254349606
# Diff between r2_score and cross_validation of model  LinearRegression() is equal =  0.026148009122203608
# R2_score of model  KNeighborsRegressor() is equal =  100.0
# Cross validation of model  2 is equal =  1.0
# Diff between r2_score and cross_validation of model  KNeighborsRegressor() is equal =  0.0
# R2_score of model  GradientBoostingRegressor() is equal =  99.91471534020363
# Cross validation of model  2 is equal =  0.9993365023579026
# Diff between r2_score and cross_validation of model  GradientBoostingRegressor() is equal =  -0.00018934895586630862
# R2_score of model  AdaBoostRegressor() is equal =  91.43735245715374
# Cross validation of model  2 is equal =  0.9206079679227046
# Diff between r2_score and cross_validation of model  AdaBoostRegressor() is equal =  -0.006234443351167185
# R2_score of model  ExtraTreesRegressor() is equal =  100.0
# Cross validation of model  2 is equal =  1.0
# Diff between r2_score and cross_validation of model  ExtraTreesRegressor() is equal =  0.0
# R2_score of model  RandomForestRegressor() is equal =  100.0
# Cross validation of model  2 is equal =  1.0
# Diff between r2_score and cross_validation of model  RandomForestRegressor() is equal =  0.0
# R2_score of model  DecisionTreeRegressor() is equal =  100.0
# Cross validation of model  2 is equal =  1.0
# Diff between r2_score and cross_validation of model  DecisionTreeRegressor() is equal =  0.0
# R2_score of model  SVR() is equal =  1.2570386367924735
# Cross validation of model  2 is equal =  -0.010706803179809543
# Diff between r2_score and cross_validation of model  SVR() is equal =  0.02327718954773428
# R2_score of model  LinearRegression() is equal =  44.11038316656997
# Cross validation of model  3 is equal =  0.4131481337989813
# Diff between r2_score and cross_validation of model  LinearRegression() is equal =  0.027955697866718365
# R2_score of model  KNeighborsRegressor() is equal =  100.0
# Cross validation of model  3 is equal =  1.0
# Diff between r2_score and cross_validation of model  KNeighborsRegressor() is equal =  0.0
# R2_score of model  GradientBoostingRegressor() is equal =  99.91471534020363
# Cross validation of model  3 is equal =  0.9992067340995208
# Diff between r2_score and cross_validation of model  GradientBoostingRegressor() is equal =  -5.95806974844626e-05
# R2_score of model  AdaBoostRegressor() is equal =  92.74042444163067
# Cross validation of model  3 is equal =  0.914790191540069
# Diff between r2_score and cross_validation of model  AdaBoostRegressor() is equal =  0.012614052876237625
# R2_score of model  ExtraTreesRegressor() is equal =  100.0
# Cross validation of model  3 is equal =  1.0
# Diff between r2_score and cross_validation of model  ExtraTreesRegressor() is equal =  0.0
# R2_score of model  RandomForestRegressor() is equal =  100.0
# Cross validation of model  3 is equal =  1.0
# Diff between r2_score and cross_validation of model  RandomForestRegressor() is equal =  0.0
# R2_score of model  DecisionTreeRegressor() is equal =  100.0
# Cross validation of model  3 is equal =  1.0
# Diff between r2_score and cross_validation of model  DecisionTreeRegressor() is equal =  0.0
# R2_score of model  SVR() is equal =  1.2570386367924735
# Cross validation of model  3 is equal =  -0.015214128155364678
# Diff between r2_score and cross_validation of model  SVR() is equal =  0.027784514523289415
# R2_score of model  LinearRegression() is equal =  44.11038316656997
# Cross validation of model  4 is equal =  0.42081059648840435
# Diff between r2_score and cross_validation of model  LinearRegression() is equal =  0.02029323517729531
# R2_score of model  KNeighborsRegressor() is equal =  100.0
# Cross validation of model  4 is equal =  1.0
# Diff between r2_score and cross_validation of model  KNeighborsRegressor() is equal =  0.0
# R2_score of model  GradientBoostingRegressor() is equal =  99.91471534020363
# Cross validation of model  4 is equal =  0.9992122332439897
# Diff between r2_score and cross_validation of model  GradientBoostingRegressor() is equal =  -6.50798419533638e-05
# R2_score of model  AdaBoostRegressor() is equal =  92.68766583388025
# Cross validation of model  4 is equal =  0.9224652494408127
# Diff between r2_score and cross_validation of model  AdaBoostRegressor() is equal =  0.004411408897989855
# R2_score of model  ExtraTreesRegressor() is equal =  100.0
# Cross validation of model  4 is equal =  1.0
# Diff between r2_score and cross_validation of model  ExtraTreesRegressor() is equal =  0.0
# R2_score of model  RandomForestRegressor() is equal =  100.0
# Cross validation of model  4 is equal =  1.0
# Diff between r2_score and cross_validation of model  RandomForestRegressor() is equal =  0.0
# R2_score of model  DecisionTreeRegressor() is equal =  100.0
# Cross validation of model  4 is equal =  1.0
# Diff between r2_score and cross_validation of model  DecisionTreeRegressor() is equal =  0.0
# R2_score of model  SVR() is equal =  1.2570386367924735
# Cross validation of model  4 is equal =  -0.007742722151637571
# Diff between r2_score and cross_validation of model  SVR() is equal =  0.020313108519562306
# R2_score of model  LinearRegression() is equal =  44.11038316656997
# Cross validation of model  5 is equal =  0.4169865003010651
# Diff between r2_score and cross_validation of model  LinearRegression() is equal =  0.024117331364634564
# R2_score of model  KNeighborsRegressor() is equal =  100.0
# Cross validation of model  5 is equal =  1.0
# Diff between r2_score and cross_validation of model  KNeighborsRegressor() is equal =  0.0
# R2_score of model  GradientBoostingRegressor() is equal =  99.91471534020363
# Cross validation of model  5 is equal =  0.9990700797304648
# Diff between r2_score and cross_validation of model  GradientBoostingRegressor() is equal =  7.707367157150369e-05
# R2_score of model  AdaBoostRegressor() is equal =  91.95442287234131
# Cross validation of model  5 is equal =  0.9190577467040855
# Diff between r2_score and cross_validation of model  AdaBoostRegressor() is equal =  0.0004864820193276609
# R2_score of model  ExtraTreesRegressor() is equal =  100.0
# Cross validation of model  5 is equal =  1.0
# Diff between r2_score and cross_validation of model  ExtraTreesRegressor() is equal =  0.0
# R2_score of model  RandomForestRegressor() is equal =  100.0
# Cross validation of model  5 is equal =  1.0
# Diff between r2_score and cross_validation of model  RandomForestRegressor() is equal =  0.0
# R2_score of model  DecisionTreeRegressor() is equal =  100.0
# Cross validation of model  5 is equal =  1.0
# Diff between r2_score and cross_validation of model  DecisionTreeRegressor() is equal =  0.0
# R2_score of model  SVR() is equal =  1.2570386367924735
# Cross validation of model  5 is equal =  -0.0055133255414510085
# Diff between r2_score and cross_validation of model  SVR() is equal =  0.018083711909375744
# R2_score of model  LinearRegression() is equal =  44.11038316656997
# Cross validation of model  6 is equal =  0.4199754968671921
# Diff between r2_score and cross_validation of model  LinearRegression() is equal =  0.021128334798507564
# R2_score of model  KNeighborsRegressor() is equal =  100.0
# Cross validation of model  6 is equal =  1.0
# Diff between r2_score and cross_validation of model  KNeighborsRegressor() is equal =  0.0
# R2_score of model  GradientBoostingRegressor() is equal =  99.91471534020363
# Cross validation of model  6 is equal =  0.9992315324552741
# Diff between r2_score and cross_validation of model  GradientBoostingRegressor() is equal =  -8.437905323777084e-05
# R2_score of model  AdaBoostRegressor() is equal =  93.1898077843092
# Cross validation of model  6 is equal =  0.9174013391678018
# Diff between r2_score and cross_validation of model  AdaBoostRegressor() is equal =  0.014496738675290222
# R2_score of model  ExtraTreesRegressor() is equal =  100.0
# Cross validation of model  6 is equal =  1.0
# Diff between r2_score and cross_validation of model  ExtraTreesRegressor() is equal =  0.0
# R2_score of model  RandomForestRegressor() is equal =  100.0
# Cross validation of model  6 is equal =  1.0
# Diff between r2_score and cross_validation of model  RandomForestRegressor() is equal =  0.0
# R2_score of model  DecisionTreeRegressor() is equal =  100.0
# Cross validation of model  6 is equal =  1.0
# Diff between r2_score and cross_validation of model  DecisionTreeRegressor() is equal =  0.0
# R2_score of model  SVR() is equal =  1.2570386367924735
# Cross validation of model  6 is equal =  -0.0005318410182906056
# Diff between r2_score and cross_validation of model  SVR() is equal =  0.01310222738621534
# R2_score of model  LinearRegression() is equal =  44.11038316656997
# Cross validation of model  7 is equal =  0.4207439149667455
# Diff between r2_score and cross_validation of model  LinearRegression() is equal =  0.02035991669895415
# R2_score of model  KNeighborsRegressor() is equal =  100.0
# Cross validation of model  7 is equal =  1.0
# Diff between r2_score and cross_validation of model  KNeighborsRegressor() is equal =  0.0
# R2_score of model  GradientBoostingRegressor() is equal =  99.91471534020363
# Cross validation of model  7 is equal =  0.9991738287180593
# Diff between r2_score and cross_validation of model  GradientBoostingRegressor() is equal =  -2.667531602296158e-05
# R2_score of model  AdaBoostRegressor() is equal =  93.19489236181478
# Cross validation of model  7 is equal =  0.916701772699839
# Diff between r2_score and cross_validation of model  AdaBoostRegressor() is equal =  0.01524715091830875
# R2_score of model  ExtraTreesRegressor() is equal =  100.0
# Cross validation of model  7 is equal =  1.0
# Diff between r2_score and cross_validation of model  ExtraTreesRegressor() is equal =  0.0
# R2_score of model  RandomForestRegressor() is equal =  100.0
# Cross validation of model  7 is equal =  1.0
# Diff between r2_score and cross_validation of model  RandomForestRegressor() is equal =  0.0
# R2_score of model  DecisionTreeRegressor() is equal =  100.0
# Cross validation of model  7 is equal =  1.0
# Diff between r2_score and cross_validation of model  DecisionTreeRegressor() is equal =  0.0
# R2_score of model  SVR() is equal =  1.2570386367924735
# Cross validation of model  7 is equal =  -3.0073607702066747e-05
# Diff between r2_score and cross_validation of model  SVR() is equal =  0.012600459975626801
# R2_score of model  LinearRegression() is equal =  44.11038316656997
# Cross validation of model  8 is equal =  0.42063755833401517
# Diff between r2_score and cross_validation of model  LinearRegression() is equal =  0.020466273331684492
# R2_score of model  KNeighborsRegressor() is equal =  100.0
# Cross validation of model  8 is equal =  1.0
# Diff between r2_score and cross_validation of model  KNeighborsRegressor() is equal =  0.0
# R2_score of model  GradientBoostingRegressor() is equal =  99.91471534020363
# Cross validation of model  8 is equal =  0.9990438124515422
# Diff between r2_score and cross_validation of model  GradientBoostingRegressor() is equal =  0.00010334095049413516
# R2_score of model  AdaBoostRegressor() is equal =  93.3412714428788
# Cross validation of model  8 is equal =  0.9192036633279779
# Diff between r2_score and cross_validation of model  AdaBoostRegressor() is equal =  0.014209051100810166
# R2_score of model  ExtraTreesRegressor() is equal =  100.0
# Cross validation of model  8 is equal =  1.0
# Diff between r2_score and cross_validation of model  ExtraTreesRegressor() is equal =  0.0
# R2_score of model  RandomForestRegressor() is equal =  100.0
# Cross validation of model  8 is equal =  1.0
# Diff between r2_score and cross_validation of model  RandomForestRegressor() is equal =  0.0
# R2_score of model  DecisionTreeRegressor() is equal =  100.0
# Cross validation of model  8 is equal =  1.0
# Diff between r2_score and cross_validation of model  DecisionTreeRegressor() is equal =  0.0
# R2_score of model  SVR() is equal =  1.2570386367924735
# Cross validation of model  8 is equal =  -0.0008700670001813293
# Diff between r2_score and cross_validation of model  SVR() is equal =  0.013440453368106065
# R2_score of model  LinearRegression() is equal =  44.11038316656997
# Cross validation of model  9 is equal =  0.41863382768587154
# Diff between r2_score and cross_validation of model  LinearRegression() is equal =  0.022470003979828124
# R2_score of model  KNeighborsRegressor() is equal =  100.0
# Cross validation of model  9 is equal =  1.0
# Diff between r2_score and cross_validation of model  KNeighborsRegressor() is equal =  0.0
# R2_score of model  GradientBoostingRegressor() is equal =  99.91471534020363
# Cross validation of model  9 is equal =  0.9991769369324744
# Diff between r2_score and cross_validation of model  GradientBoostingRegressor() is equal =  -2.9783530438143302e-05
# R2_score of model  AdaBoostRegressor() is equal =  91.93769093069449
# Cross validation of model  9 is equal =  0.918041362932763
# Diff between r2_score and cross_validation of model  AdaBoostRegressor() is equal =  0.001335546374181873
# R2_score of model  ExtraTreesRegressor() is equal =  100.0
# Cross validation of model  9 is equal =  1.0
# Diff between r2_score and cross_validation of model  ExtraTreesRegressor() is equal =  0.0
# R2_score of model  RandomForestRegressor() is equal =  100.0
# Cross validation of model  9 is equal =  1.0
# Diff between r2_score and cross_validation of model  RandomForestRegressor() is equal =  0.0
# R2_score of model  DecisionTreeRegressor() is equal =  100.0
# Cross validation of model  9 is equal =  1.0
# Diff between r2_score and cross_validation of model  DecisionTreeRegressor() is equal =  0.0
# R2_score of model  SVR() is equal =  1.2570386367924735
# Cross validation of model  9 is equal =  -0.0027197699108513587
# Diff between r2_score and cross_validation of model  SVR() is equal =  0.015290156278776093

# %% [markdown]
# # HYPERTUNING

# %%
from sklearn.model_selection import GridSearchCV

# %%
parameters1={'fit_intercept':[False,True],
             'copy_X':[False,True],
             'n_jobs':[1,2],
             'positive':[False,True]}
gscv_lr1=GridSearchCV(estimator=lr1,param_grid=parameters1)
gscv_lr1.fit(x_train1,y_train1)
# Out:
# GridSearchCV(estimator=LinearRegression(),
#              param_grid={'copy_X': [False, True],
#                          'fit_intercept': [False, True], 'n_jobs': [1, 2],
#                          'positive': [False, True]})

# %%
print((gscv_lr1.best_score_)*1000)
print(gscv_lr1.best_params_)
print(gscv_lr1.best_estimator_)
# Out:
# 416.9865003010669
# {'copy_X': False, 'fit_intercept': False, 'n_jobs': 1, 'positive': False}
# LinearRegression(copy_X=False, fit_intercept=False, n_jobs=1)

# %%
parameters1={'n_estimators':[50,100,150,200],
            'criterion':['gini','squared_error'],
            'max_depth':[1,2,3],
            'max_features':['auto','sqrt','log2']}
gscv_gbr1=GridSearchCV(estimator=gbr1,param_grid=parameters1)
gscv_gbr1.fit(x_train1,y_train1)
# Out:
# GridSearchCV(estimator=GradientBoostingRegressor(),
#              param_grid={'criterion': ['gini', 'squared_error'],
#                          'max_depth': [1, 2, 3],
#                          'max_features': ['auto', 'sqrt', 'log2'],
#                          'n_estimators': [50, 100, 150, 200]})

# %%
print(gscv_gbr1.best_score_)
print(gscv_gbr1.best_params_)
print(gscv_gbr1.best_estimator_)
# Out:
# 0.99999177653931
# {'criterion': 'squared_error', 'max_depth': 3, 'max_features': 'auto', 'n_estimators': 200}
# GradientBoostingRegressor(criterion='squared_error', max_features='auto',
#                           n_estimators=200)

# %%
parameters1={'n_estimators':[50,100,150,200],
            'criterion':['gini','squared_error'],
            'max_depth':[1,2,3],
            'max_features':['auto','sqrt','log2']}
gscv_etr1=GridSearchCV(estimator=etr1,param_grid=parameters1)
gscv_etr1.fit(x_train1,y_train1)
# Out:
# GridSearchCV(estimator=ExtraTreesRegressor(),
#              param_grid={'criterion': ['gini', 'squared_error'],
#                          'max_depth': [1, 2, 3],
#                          'max_features': ['auto', 'sqrt', 'log2'],
#                          'n_estimators': [50, 100, 150, 200]})

# %%
print(gscv_etr1.best_score_)
print(gscv_etr1.best_params_)
print(gscv_etr1.best_estimator_)
# Out:
# 0.7234822190676885
# {'criterion': 'squared_error', 'max_depth': 3, 'max_features': 'auto', 'n_estimators': 200}
# ExtraTreesRegressor(max_depth=3, max_features='auto', n_estimators=200)

# %%
parameters1={'n_estimators':[50,100,150,200],
            'criterion':['gini','squared_error'],
            'max_depth':[1,2,3],
            'max_features':['auto','sqrt','log2']}
gscv_rfr1=GridSearchCV(estimator=rfr1,param_grid=parameters1)
gscv_rfr1.fit(x_train1,y_train1)
# Out:
# GridSearchCV(estimator=RandomForestRegressor(),
#              param_grid={'criterion': ['gini', 'squared_error'],
#                          'max_depth': [1, 2, 3],
#                          'max_features': ['auto', 'sqrt', 'log2'],
#                          'n_estimators': [50, 100, 150, 200]})

# %%
print(gscv_rfr1.best_score_)
print(gscv_rfr1.best_params_)
print(gscv_rfr1.best_estimator_)
# Out:
# 0.7767429689993274
# {'criterion': 'squared_error', 'max_depth': 3, 'max_features': 'log2', 'n_estimators': 150}
# RandomForestRegressor(max_depth=3, max_features='log2', n_estimators=150)

# %% [markdown]
# # ROC_CURVE

# %%
from sklearn.metrics import roc_curve,plot_roc_curve

# %%
plt.scatter(predlr1,y_test1)
plt.plot(y_test1,y_test1,linewidth=4,color='Red')

# %% [markdown]
# # Above all methods of testing we find LINEAR REGRESSION to be the most fitted model as it shows more accurate r2_score to predict GROSS_COLLECTION of the dataset movie2 so we are saving it.

# %% [markdown]
# # SAVING THE BEST FITTED MODEL

# %%
import pickle
filename='movie2_Gross_collection.pkl'

# %%
pickle.dump(lr1,open(filename,'wb'))

# %% [markdown]
# # LOADING THE SAVED MODEL

# %%
pickle.load(open(filename,'rb'))
# Out:
# LinearRegression()
